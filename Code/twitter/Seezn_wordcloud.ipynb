# %%
import pandas as pd
import numpy as np
from konlpy.tag import Okt
import nltk
m=Okt()

# %%
df=pd.read_csv('C:/Users/jminw/Desktop/media/twittertving.csv', encoding='CP949')

# %%
df.head(5)
# Out:
#                                              content
# 0                    @WGWorldCafe: [#소희/사진] 미씽 종아 스틸
# 1                          우리 종아 아직 중딩이에요... 풀어주세요..
# 2             종아 스틸도 풀어주세요.. https://t.co/onj7rSWFad
# 3  RT @lunamoth: 온라인동영상서비스(OTT) 월간활성이용자(MAU) 순위 (...
# 4                               1. 넷플릭스 : 755만8천292명

# %%
okt_test = df['content']; okt_test
# Out:
# 0                        @WGWorldCafe: [#소희/사진] 미씽 종아 스틸
# 1                              우리 종아 아직 중딩이에요... 풀어주세요..
# 2                 종아 스틸도 풀어주세요.. https://t.co/onj7rSWFad
# 3      RT @lunamoth: 온라인동영상서비스(OTT) 월간활성이용자(MAU) 순위 (...
# 4                                   1. 넷플릭스 : 755만8천292명
#                              ...
# 131                                    @nouk0716 오랜만이에요!
# 132                               저는 첫화부터 봐야하는 병에 걸려서ㅋㅋㅋ
# 133           저도 제대로 된 한글자막 보고 싶어요ㅠㅠ일단은 영자막으로 다 보긴 했는데??
# 134    최대한 웨이브나 티빙같은데 빨리 올라오기를 기다리는 중이에… https://t.co...
# 135    넷플릭스를 받아볼까... 이미 티빙, 웨이브를 구독하고 있어서 구독은 그렇고 한달만...
# Name: content, Length: 136, dtype: object

# %%
okt_list = okt_test.values.tolist()

print(len(okt_list))
okt_list
# Out:
# 136
# ['@WGWorldCafe: [#소희/사진] 미씽 종아 스틸',
#  '우리 종아 아직 중딩이에요... 풀어주세요..',
#  '종아 스틸도 풀어주세요.. https://t.co/onj7rSWFad',
#  'RT @lunamoth: 온라인동영상서비스(OTT) 월간활성이용자(MAU) 순위 (닐슨코리안클릭, 2020년 8월 기준 https://t.co/HcozccBu0U)',
#  '1. 넷플릭스 : 755만8천292명',
#  '2. 웨이브 : 387만9천730명',
#  '3. 티빙…',
#  'RT @OCN_ORIGINAL: [써치] 인물관계도 전격 공개!',
#  '(ft. 써치 공식 홈페이지 오픈??)',
#  '단결! 반갑다, 목격자 훈련병들??',
#  '진정한 군인의 자세는',
#  '지피지기 백전백승!',
#  '우리 특임대원들의 관계에 대해',
#  '미리 예습하도록 자료를 준비했다!',
#  '곧 자…',
#  '@jhk1215 아. 저도 이진욱일거라 생각은 했지만 혹시나 했습니다. 티빙 광고 진짜 해로워요.',
#  '아부지 폰으로 티비보게해줄라는데 요새도 티빙인가',
#  '허류ㅠ 티빙톡 터지기 직전ㅋㅋㄱ',
#  '@simnalamburt 한국은 티빙이나 웨이브로 되던기능이죠. UI는 잘만들었어요.  Fox TV VP아저씨 몇년전에 만났을 때 저 딜 관련되서 이야기 들었는데 구글이 계약하는라 고생꽤나 했더군요.',
#  '@NLAND_L 저희 엄마께서는 티빙으로 정주행채널? 그걸로 그냥 틈틈히 틀어두시고 보시더라구요 !',
#  '기억하고 함께해줘, 청춘기록 온라인 사진전 9월 7일부터 매주 (월,화) 밤 9시 tvN 방송 https://t.co/rRPFiQR9bw #청춘기록',
#  '왓챠에 나오면 좋겠다...',
#  '상당히 재미있는데 티빙에서만 볼 수 있다니...웨이브에라도 풀어주세요...',
#  '@lotusid 오 딱 원하던 거예요. 안 쓰던 티빙 계정도 방금 살렸습니다. 내일 봐야징.',
#  "@jimin1226 저거보려고 티빙 월정액 끊고 받는데 나는 ㅡㅡ'",
#  'RT @Baiyu_Honey: 야..이런 건 수입해도 될 것 같지 않닝. 웨이브나 티빙에서 보게 해 줘.',
#  '티빙 이용자들이 실시간 본 시청률이 50이래여',
#  'RT @Baiyu_Honey: 야..이런 건 수입해도 될 것 같지 않닝. 웨이브나 티빙에서 보게 해 줘.',
#  '티빙 뭐지... 노래 무대 영상만 화질이 이따위야',
#  '야..이런 건 수입해도 될 것 같지 않닝. 웨이브나 티빙에서 보게 해 줘.',
#  '@B_hundred_Hyun 배켜나 지금 티빙댓글 난리났어 ㅋㅋ큐ㅠㅋㅋㅋ',
#  '티빙 화질 왜 이래...',
#  '티빙식 720p https://t.co/a5YcSoFckL',
#  '안하는데...티빙에선 못보나ㅠ https://t.co/TNtNmaSRAc',
#  '「road to mountains」inspired by the BTS of CLOY located in Switzerland',
#  'September 25th, Happy Birthday! Hyunbin ssi!… https://t.co/9nHvvAaQYt',
#  '@Po_516 엇 넷플에 있었는데 사라졌나 보네요?',
#  '티빙이라는 다시 보기 앱에 있어요!',
#  '술 마시도 싶으니 이것도 봐야지ㅋㅋㅋㅋ',
#  '술 마시고 싶으니까 봐야지ㅋㅋㅋㅋ',
#  '오늘은 꼭 인더숲 본다 티빙 깐다',
#  '파판 티빙에 광고 넣은거 보니 돈마니 벌었구나 싶음',
#  '@redruinlife ㅁㅊ 나 왓챠 9월까진데 10월부턴 티빙볼까?ㅠㅠㅠㅠㅠㅠ',
#  '티비로 볼 수 없다는게 아쉽지만 그래도 티빙이 있어서 다행이네요 ㅠ 아이즈원 영원하자 !! #아이즈원츄_본방사수 https://t.co/h36fpTFpGP',
#  '1. 종종 언급했었지만 쿨타임 돌았으니 또',
#  '초4~중2때 밴드했었구, 여러 오디션 프로그램이나 공연 나갔었어요',
#  'https://t.co/4yg2pAp962',
#  '이거 초5때 코리아 갓 탤런트 2 나갔을때고, 젤 왼쪽에 엄준식 모자 쓴 애가 저임 ㅋㅋㅋ',
#  'RT @cuteLJG: 이렇게 좋은 날????',
#  '#대탈출 몰아보다가 3일 연속 새벽 3-4시 잠 자서 어제는 하루종일 누워있었는데 5시에 잠 ㄷㄷ',
#  '@HYEJI_05 티빙으로 tvN보면 광고 엄청 나와!!',
#  '\'18어게인\' 윤상현, "진짜 아빠라서 더 통했다"..공감甲 \'현실 남편\' https://t.co/GvhNY3m7zU #윤상현 #18',
#  '@SK_KANO0330 ㅇㅇ나도 티빙봐서 ㅋㅋㅋㅋ',
#  '고민했네',
#  '유투브 멥버십 전용은',
#  '티빙이랑 내용이 좀 다른가?? https://t.co/RSKIVOPm1m',
#  '내 생각에는 이것들 계략인 것 같아',
#  '서로 협의해서 치열한 시장에서 공존하기로 한 거지 최대한 각자 드라마',
#  '지니고 있어서 균형 맞추자고 합의한 거 야.......나 티빙만 결제하면 그 계략에 넘어가.........',
#  'RT @nangja101: 2016 MAMA 베스트 밴드 퍼포먼스 후보 &gt; 국카스텐 동영상',
#  '아...이걸 보고 있으니 진짜 펄스 가사처럼 가슴이 뛴다 ㅜㅜ',
#  'RT @nangja101: 2016 MAMA 베스트 밴드 퍼포먼스 후보 &gt; 국카스텐 동영상',
#  '아...이걸 보고 있으니 진짜 펄스 가사처럼 가슴이 뛴다 ㅜㅜ',
#  '출처 : https://t.co/K3rYuMFzGv https://t.co/JH99OroBog',
#  '티빙 중드 추천 받습니다??',
#  '요근래 머겜 관심이 줄어듦',
#  '이럴 때 딱 다시 봐야하는데',
#  '티빙 결제하긴 싫단 말야',
#  '이미 넷플 왓챠 웨이브 자주 보지도',
#  '않는데 작품 몇개땜에 끊었단 말야',
#  '티빙도 결제해버렸다....',
#  '드디어 본다....',
#  '@_hyok_ 유튜브에 올라와있던데 난 티빙있지롱',
#  '노트북으로 엠넷 티빙에서 실시간 볼수있나요?',
#  '집에 티비가 없어서ㅠㅠㅠ 꼭 아무나 답장부탁드립니다!!',
#  '@WGWorldCafe: [#소희/사진] 미씽 그들이 있었다 종아 스틸 9~10화',
#  '@JUNYOUNG_CLIP: OCN 수목드라마 &lt;미스터 기간제&gt;',
#  '넷플릭스, 웨이브, 티빙, 씨즌, 내년에는 디즈니까지 국내 OTT는 춘추전국시대인데, 멀티 유저들도 정말 많아지고',
#  '동영상 뉴스 닷새 동안 이어진 추석 연휴가 오늘로 마무리됩니다 . ',
#  '기존 강자인 넷플릭스와 왓챠에 더해 웨이브 티빙 시즌 등 다양한 장르와 접목을 시도하며 종합예술가적 면모를 드러냈다 . ',
#  '앞서 kbs는 강 장관의 배우자이기 때문에 출발 전 여행을 취',
#  '비숲2 티빙 실시간으로 봤더니 채팅 반응 너무 웃기네ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '엄마는 그래도 되는 줄 알았습니다',
#  '그러면 안 되는 거 ㅠ',
#  '와 오늘막방이여??????꼬박다챙겨봤는데ㅋㅋㅋ',
#  '브더사보느라 막방놓침ㅋㅋ하지만 티빙이있으니...!',
#  '티빙 렉 너무 심한데 클났네ㅠㅠ',
#  '@pibchaban 저도 유일하게 보는 티비가 노는언니 입니다!!! 본방 못보면 티빙으로 꼭 다시보기 합니다~~!!♡♡',
#  '곰팅이 진짜 보기 실타..(티빙 드가짐)',
#  '내 폰 드디어 맛 갈 대로 맛이 갔나벼.. 티빙 안 드가졐ㅋㅋㅋ',
#  '@lxrmdryd ㅇㅇ 재밌어 근데 티빙엔 뭐있는지몰라서 뭐라할수가없네..',
#  '비밀의 숲 2、TVING',
#  '구독료....일단 웨이브랑 티빙은 이번달 까지만 볼꺼고 넷플릭스는....계속가는걸로...유튜브프리미엄은 종신구독하기로 결정함 ㅋㅋㅋㅋㅋ',
#  '티빙 계정 쉐어  2명 모셔요',
#  '-1080p 화질 ',
#  '-월 2500원',
#  '티빙쉐어 티빙4인팟',
#  '#사이코지만괜찮아 ',
#  '와 연기 진짜 잘하네.??',
#  '#오정세배우님 ',
#  '#용돈주는_형 ',
#  '#사이코지만괜찮아 ',
#  '#드라마 #티빙 #tvN #cjenm ',
#  '#오정세 #김수현 #서예지 @Seoul, Korea https://t.co/i0vTQk6OSu',
#  '사이코지만 괜찮아.',
#  '일레인의 ‘wake up’ 너무 너무 너무 너무 좋아??',
#  '#일레인 ',
#  '#wakeup ',
#  '#사이코지만괜찮아 ',
#  '#서예지 #김수현 ',
#  '#드라마 #티빙 #tvN #cjenm @Seoul, Korea https://t.co/aLDLo6dXYS',
#  '20. 나 넷플릭스 티빙 웨이브 유튭프리미엄 다 있음 필요할 때 말하면 아이디비번 빌려줌',
#  '추석효도 스마트 버전. 안방에 크롬캐스트 설치 &amp; 엄마한테 웨이브, 티빙 설치 사용 안내. 재미있게 보떼엽.',
#  '아는 건 별로 없지만 가족입니다.',
#  '제목부터 너무나 현실적.',
#  '#강력추천드라마 ',
#  '#아는건별로없지만가족입니다 ',
#  '@ArtOfSuzy: [스타트업] 띵동♥ &lt;스타트업&gt; 배수지X남주혁X김선호X강한나의 추석 인사가 도착했습니다.',
#  '넷플 왓챠 티빙 웨이브 곧 디즈니플러스까지 ;;; 엔빵 진지하게 고민해봐야겠다',
#  '@littil_moon0613 저두 못봐서 티빙에 올라 올 줄알았는데 아직없네용 ??????????',
#  'RT @OCN_ORIGINAL: [써치] 인물관계도 전격 공개!',
#  '저번 인스타스토리에 귀멸의칼날 얘기 나왔을 때 볼까말까 했는데 이렇게 또 언급하면 봐야지 뭐... 오빠 좋아하는건 나도 좋아할테야?? 넷플 티빙만 쓰는데 다행히 티빙에 있으니 원나블 덕후 경력으로 달려본다??',
#  '@we_615 아 ㅇㅋㅇㅋ 티빙으로 볼수있나..?',
#  '티빙에 스캄프랑스가 나온다는데 그거 재밌나요? 몇번 탐라에서 본 것 같아서',
#  '@BOGUMMY 추석연휴를 맞이하여 OTT 정주행 리스트에 #청춘기록 있습니다. 티빙, 넷플릭스 등 다양한 채널에서 #사혜준 만나기! 이번 추석 필수 리스트네요! (역시나 휴일인 관계로…',
#  '@Soyul_0613 헉 제이티비씨 나우 또는 티빙이요',
#  '@vkong6 티빙으로 어떻게 봐요오?',
#  '@mogu_mogu_T1 전 티빙앱 깔았어요 실시간은 무료라네요??',
#  '@guzmaofficial: [유아넥스트] 같은 영화를 원하자 김봉석 샘이 추천해주신 영화 [레디 오어 낫]. 오늘 밤에 경건한 자세로 준비하고 보겠다. 죽었던 티빙 아이디까지 살렸다. 일부러 내용도 안 찾아봤는데 이미지만 봐도 흥미진진함. 사…',
#  '@lol_soo9 ㅜㅜ 그래도...어무니가 미리 알려주셔서 티빙 가입하니까 다행인거라 생각합니다요..????어무니 아부지의 너훈아를 이길 수 없기에..평소에 못한 효도 이걸로 한다 생각하겠습니다. ????수구님도 파이팅하시고 즐거운 한가위 되세요!????',
#  '왓챠 3일 무료면 머하나고 울집은 이미 돈 내고 있음..심지어 넷플도 있음....웨이브에 티빙도 있지만 그런거 볼 시간이 없어...ㅜㅜㅜㅜ',
#  '@nouk0716 오랜만이에요!',
#  '저는 첫화부터 봐야하는 병에 걸려서ㅋㅋㅋ',
#  '저도 제대로 된 한글자막 보고 싶어요ㅠㅠ일단은 영자막으로 다 보긴 했는데??',
#  '최대한 웨이브나 티빙같은데 빨리 올라오기를 기다리는 중이에… https://t.co/BUiAOYLWhN',
#  '넷플릭스를 받아볼까... 이미 티빙, 웨이브를 구독하고 있어서 구독은 그렇고 한달만 보고말까.']

# %%
import nltk
from konlpy.tag import Okt; t = Okt()

# %%
# 리스트 중 str 타입이 아닌 요소들이 존재함을 확인
for i in okt_list:
    if type(i) == float:
        i = str(i)
        print(i)

# %%
# str 타입이 아닌 요소들이 있으면 전부 str 타입으로 바꿔라!
for i in range(len(okt_list)):
    if type(okt_list[i]) != str:
        okt_list[i] = str(okt_list[i])

# %%
okt_text = ''

for each_line in okt_list[:2000]:
    okt_text = okt_text + each_line + '\n'

# %%
tokens_ko = t.morphs(okt_text)
tokens_ko
# Out:
# ['@WGWorldCafe',
#  ':',
#  '[#소희',
#  '/',
#  '사진',
#  ']',
#  '미씽',
#  '종',
#  '아',
#  '스틸',
#  '\n',
#  '우리',
#  '종',
#  '아',
#  '아직',
#  '중딩',
#  '이에요',
#  '...',
#  '풀어주세요',
#  '..',
#  '\n',
#  '종',
#  '아',
#  '스틸',
#  '도',
#  '풀어주세요',
#  '..',
#  'https://t.co/onj7rSWFad',
#  '\n',
#  'RT',
#  '@lunamoth',
#  ':',
#  '온라인',
#  '동영상',
#  '서비스',
#  '(',
#  'OTT',
#  ')',
#  '월간',
#  '활',
#  '성',
#  '이용자',
#  '(',
#  'MAU',
#  ')',
#  '순위',
#  '(',
#  '닐슨',
#  '코리안',
#  '클릭',
#  ',',
#  '2020년',
#  '8월',
#  '기준',
#  'https://t.co/HcozccBu0U',
#  ')',
#  '\n',
#  '1',
#  '.',
#  '넷플릭스',
#  ':',
#  '755만',
#  '8천',
#  '292',
#  '명',
#  '\n',
#  '2',
#  '.',
#  '웨이브',
#  ':',
#  '387만',
#  '9천',
#  '730',
#  '명',
#  '\n',
#  '3',
#  '.',
#  '티빙',
#  '…',
#  '\n',
#  'RT',
#  '@OCN_ORIGINAL',
#  ':',
#  '[',
#  '써치',
#  ']',
#  '인물관계도',
#  '전격',
#  '공개',
#  '!',
#  '\n',
#  '(',
#  'ft',
#  '.',
#  '써치',
#  '공식',
#  '홈페이지',
#  '오픈',
#  '??)',
#  '\n',
#  '단결',
#  '!',
#  '반갑다',
#  ',',
#  '목격자',
#  '훈련병',
#  '들',
#  '??',
#  '\n',
#  '진정한',
#  '군인',
#  '의',
#  '자세',
#  '는',
#  '\n',
#  '지피지기',
#  '백전백승',
#  '!',
#  '\n',
#  '우리',
#  '특',
#  '임대',
#  '원',
#  '들',
#  '의',
#  '관계',
#  '에',
#  '대해',
#  '\n',
#  '미리',
#  '예습',
#  '하도록',
#  '자료',
#  '를',
#  '준비',
#  '했다',
#  '!',
#  '\n',
#  '곧',
#  '자',
#  '…',
#  '\n',
#  '@jhk1215',
#  '아',
#  '.',
#  '저',
#  '도',
#  '이진욱',
#  '일거라',
#  '생각',
#  '은',
#  '했지만',
#  '혹시',
#  '나',
#  '했습니다',
#  '.',
#  '티빙',
#  '광고',
#  '진짜',
#  '해로워요',
#  '.',
#  '\n',
#  '아부지',
#  '폰',
#  '으로',
#  '티비',
#  '보게',
#  '해줄라는데',
#  '요새',
#  '도',
#  '티빙',
#  '인가',
#  '\n',
#  '허',
#  '류',
#  'ㅠ',
#  '티빙',
#  '톡',
#  '터지기',
#  '직전',
#  'ㅋㅋㄱ',
#  '\n',
#  '@simnalamburt',
#  '한국',
#  '은',
#  '티빙',
#  '이나',
#  '웨이브',
#  '로',
#  '되던',
#  '기능',
#  '이',
#  '죠',
#  '.',
#  'UI',
#  '는',
#  '잘',
#  '만들었어요',
#  '.',
#  'Fox',
#  'TV',
#  'VP',
#  '아저씨',
#  '몇',
#  '년전',
#  '에',
#  '만났을',
#  '때',
#  '저',
#  '딜',
#  '관련',
#  '되서',
#  '이야기',
#  '들었는데',
#  '구글',
#  '이',
#  '계약',
#  '하는라',
#  '고생',
#  '꽤',
#  '나',
#  '했더군요',
#  '.',
#  '\n',
#  '@NLAND_L',
#  '저희',
#  '엄마',
#  '께서는',
#  '티빙',
#  '으로',
#  '정',
#  '주행',
#  '채널',
#  '?',
#  '그',
#  '걸',
#  '로',
#  '그냥',
#  '틈틈히',
#  '틀어',
#  '두시',
#  '고',
#  '보시더라구요',
#  '!',
#  '\n',
#  '기억',
#  '하고',
#  '함께',
#  '해줘',
#  ',',
#  '청춘',
#  '기록',
#  '온라인',
#  '사진전',
#  '9월',
#  '7일',
#  '부터',
#  '매주',
#  '(',
#  '월',
#  ',',
#  '화',
#  ')',
#  '밤',
#  '9시',
#  'tvN',
#  '방송',
#  'https://t.co/rRPFiQR9bw',
#  '#청춘기록',
#  '\n',
#  '왓챠',
#  '에',
#  '나오면',
#  '좋겠다',
#  '...',
#  '\n',
#  '상당히',
#  '재미있는데',
#  '티빙',
#  '에서만',
#  '볼',
#  '수',
#  '있다니',
#  '...',
#  '웨이브',
#  '에라도',
#  '풀어주세요',
#  '...',
#  '\n',
#  '@lotusid',
#  '오',
#  '딱',
#  '원하던',
#  '거',
#  '예요',
#  '.',
#  '안',
#  '쓰던',
#  '티빙',
#  '계정',
#  '도',
#  '방금',
#  '살렸습니다',
#  '.',
#  '내일',
#  '봐야',
#  '징',
#  '.',
#  '\n',
#  '@jimin1226',
#  '저',
#  '거',
#  '보려고',
#  '티빙',
#  '월',
#  '정액',
#  '끊고',
#  '받는데',
#  '나',
#  '는',
#  'ㅡㅡ',
#  "'",
#  '\n',
#  'RT',
#  '@Baiyu_Honey',
#  ':',
#  '야',
#  '..',
#  '이런',
#  '건',
#  '수입',
#  '해도',
#  '될',
#  '것',
#  '같지',
#  '않닝',
#  '.',
#  '웨이브',
#  '나',
#  '티빙',
#  '에서',
#  '보게',
#  '해',
#  '줘',
#  '.',
#  '\n',
#  '티빙',
#  '이용자',
#  '들',
#  '이',
#  '실시간',
#  '본',
#  '시청률',
#  '이',
#  '50',
#  '이래여',
#  '\n',
#  'RT',
#  '@Baiyu_Honey',
#  ':',
#  '야',
#  '..',
#  '이런',
#  '건',
#  '수입',
#  '해도',
#  '될',
#  '것',
#  '같지',
#  '않닝',
#  '.',
#  '웨이브',
#  '나',
#  '티빙',
#  '에서',
#  '보게',
#  '해',
#  '줘',
#  '.',
#  '\n',
#  '티빙',
#  '뭐',
#  '지',
#  '...',
#  '노래',
#  '무대',
#  '영상',
#  '만',
#  '화질',
#  '이',
#  '이',
#  '따위',
#  '야',
#  '\n',
#  '야',
#  '..',
#  '이런',
#  '건',
#  '수입',
#  '해도',
#  '될',
#  '것',
#  '같지',
#  '않닝',
#  '.',
#  '웨이브',
#  '나',
#  '티빙',
#  '에서',
#  '보게',
#  '해',
#  '줘',
#  '.',
#  '\n',
#  '@B_hundred_Hyun',
#  '배켜',
#  '나',
#  '지금',
#  '티빙',
#  '댓글',
#  '난리',
#  '났어',
#  'ㅋㅋ',
#  '큐',
#  'ㅠㅋㅋㅋ',
#  '\n',
#  '티빙',
#  '화질',
#  '왜',
#  '이래',
#  '...',
#  '\n',
#  '티빙',
#  '식',
#  '720',
#  'p',
#  'https://t.co/a5YcSoFckL',
#  '\n',
#  '안',
#  '하는데',
#  '...',
#  '티빙',
#  '에선',
#  '못',
#  '보나',
#  'ㅠ',
#  'https://t.co/TNtNmaSRAc',
#  '\n',
#  '「',
#  'road',
#  'to',
#  'mountains',
#  '」',
#  'inspired',
#  'by',
#  'the',
#  'BTS',
#  'of',
#  'CLOY',
#  'located',
#  'in',
#  'Switzerland',
#  '\n',
#  'September',
#  '25',
#  'th',
#  ',',
#  'Happy',
#  'Birthday',
#  '!',
#  'Hyunbin',
#  'ssi',
#  '!…',
#  'https://t.co/9nHvvAaQYt',
#  '\n',
#  '@Po_516',
#  '엇',
#  '넷플',
#  '에',
#  '있었는데',
#  '사라졌나',
#  '보네요',
#  '?',
#  '\n',
#  '티빙',
#  '이라는',
#  '다시',
#  '보기',
#  '앱',
#  '에',
#  '있어요',
#  '!',
#  '\n',
#  '술',
#  '마시도',
#  '싶으니',
#  '이',
#  '것',
#  '도',
#  '봐야지',
#  'ㅋㅋㅋㅋ',
#  '\n',
#  '술',
#  '마시고',
#  '싶으니까',
#  '봐야지',
#  'ㅋㅋㅋㅋ',
#  '\n',
#  '오늘',
#  '은',
#  '꼭',
#  '인더숲',
#  '본다',
#  '티빙',
#  '깐다',
#  '\n',
#  '파판',
#  '티빙',
#  '에',
#  '광고',
#  '넣은거',
#  '보니',
#  '돈',
#  '마니',
#  '벌었구나',
#  '싶음',
#  '\n',
#  '@redruinlife',
#  'ㅁㅊ',
#  '나',
#  '왓챠',
#  '9월',
#  '까진데',
#  '10월',
#  '부턴',
#  '티빙',
#  '볼까',
#  '?',
#  'ㅠㅠㅠㅠㅠㅠ',
#  '\n',
#  '티비',
#  '로',
#  '볼',
#  '수',
#  '없다는게',
#  '아쉽지만',
#  '그래도',
#  '티빙',
#  '이',
#  '있어서',
#  '다행',
#  '이네',
#  '요',
#  'ㅠ',
#  '아이즈',
#  '원',
#  '영원하자',
#  '!!',
#  '#아이즈원츄_본방사수',
#  'https://t.co/h36fpTFpGP',
#  '\n',
#  '1',
#  '.',
#  '종종',
#  '언급',
#  '했었지만',
#  '쿨타임',
#  '돌았으니',
#  '또',
#  '\n',
#  '초',
#  '4',
#  '~',
#  '중',
#  '2',
#  '때',
#  '밴드',
#  '했었구',
#  ',',
#  '여러',
#  '오디션',
#  '프로그램',
#  '이나',
#  '공연',
#  '나갔었어요',
#  '\n',
#  'https://t.co/4yg2pAp962',
#  '\n',
#  '이',
#  '거',
#  '초',
#  '5',
#  '때',
#  '코리아',
#  '갓',
#  '탤런트',
#  '2',
#  '나갔을',
#  '때',
#  '고',
#  ',',
#  '젤',
#  '왼쪽',
#  '에',
#  '엄준',
#  '식',
#  '모자',
#  '쓴',
#  '애가',
#  '저',
#  '임',
#  'ㅋㅋㅋ',
#  '\n',
#  'RT',
#  '@cuteLJG',
#  ':',
#  '이렇게',
#  '좋은',
#  '날',
#  '????',
#  '\n',
#  '#대탈출',
#  '몰아보다',
#  '가',
#  '3일',
#  '연속',
#  '새벽',
#  '3-4시',
#  '잠',
#  '자서',
#  '어제',
#  '는',
#  '하루',
#  '종일',
#  '누워있었는데',
#  '5시',
#  '에',
#  '잠',
#  'ㄷㄷ',
#  '\n',
#  '@HYEJI_05',
#  '티빙',
#  '으로',
#  'tvN',
#  '보면',
#  '광고',
#  '엄청',
#  '나와',
#  '!!',
#  '\n',
#  "'",
#  '18',
#  '어게인',
#  "'",
#  '윤상현',
#  ',',
#  '"',
#  '진짜',
#  '아빠',
#  '라서',
#  '더',
#  '통',
#  '했다',
#  '"..',
#  '공감',
#  '甲',
#  "'",
#  '현실',
#  '남편',
#  "'",
#  'https://t.co/GvhNY3m7zU',
#  '#윤상현',
#  '#',
#  '18',
#  '\n',
#  '@SK_KANO0330',
#  'ㅇㅇ',
#  '나도',
#  '티빙',
#  '봐서',
#  'ㅋㅋㅋㅋ',
#  '\n',
#  '고민',
#  '했네',
#  '\n',
#  '유투브',
#  '멥버십',
#  '전용',
#  '은',
#  '\n',
#  '티빙',
#  '이랑',
#  '내용',
#  '이',
#  '좀',
#  '다른',
#  '가',
#  '??',
#  'https://t.co/RSKIVOPm1m',
#  '\n',
#  '내',
#  '생각',
#  '에는',
#  '이',
#  '것',
#  '들',
#  '계략',
#  '인',
#  '것',
#  '같아',
#  '\n',
#  '서로',
#  '협의',
#  '해서',
#  '치열한',
#  '시장',
#  '에서',
#  '공존',
#  '하기로',
#  '한',
#  '거지',
#  '최대한',
#  '각자',
#  '드라마',
#  '\n',
#  '지니',
#  '고',
#  '있어서',
#  '균형',
#  '맞추자고',
#  '합의',
#  '한',
#  '거',
#  '야',
#  '.......',
#  '나',
#  '티빙',
#  '만',
#  '결제',
#  '하면',
#  '그',
#  '계략',
#  '에',
#  '넘어가',
#  '.........',
#  '\n',
#  'RT',
#  '@nangja101',
#  ':',
#  '2016',
#  'MAMA',
#  '베스트',
#  '밴드',
#  '퍼포먼스',
#  '후보',
#  '&',
#  'gt',
#  ';',
#  '국카스텐',
#  '동영상',
#  '\n',
#  '아',
#  '...',
#  '이',
#  '걸',
#  '보고',
#  '있으니',
#  '진짜',
#  '펄스',
#  '가사',
#  '처럼',
#  '가슴',
#  '이',
#  '뛴다',
#  'ㅜㅜ',
#  '\n',
#  'RT',
#  '@nangja101',
#  ':',
#  '2016',
#  'MAMA',
#  '베스트',
#  '밴드',
#  '퍼포먼스',
#  '후보',
#  '&',
#  'gt',
#  ';',
#  '국카스텐',
#  '동영상',
#  '\n',
#  '아',
#  '...',
#  '이',
#  '걸',
#  '보고',
#  '있으니',
#  '진짜',
#  '펄스',
#  '가사',
#  '처럼',
#  '가슴',
#  '이',
#  '뛴다',
#  'ㅜㅜ',
#  '\n',
#  '출처',
#  ':',
#  'https://t.co/K3rYuMFzGv',
#  'https://t.co/JH99OroBog',
#  '\n',
#  '티빙',
#  '중드',
#  '추천',
#  '받습니다',
#  '??',
#  '\n',
#  '요',
#  '근래',
#  '머겜',
#  '관심',
#  '이',
#  '줄어듦',
#  '\n',
#  '이럴',
#  '때',
#  '딱',
#  '다시',
#  '봐야하는데',
#  '\n',
#  '티빙',
#  '결제',
#  '하긴',
#  '싫단',
#  '말',
#  '야',
#  '\n',
#  '이미',
#  '넷플',
#  '왓챠',
#  '웨이브',
#  '자주',
#  '보지',
#  '도',
#  '\n',
#  '않는데',
#  '작품',
#  '몇개',
#  '땜',
#  '에',
#  '끊었단',
#  '말',
#  '야',
#  '\n',
#  '티빙',
#  '도',
#  '결제',
#  '해',
#  '버렸다',
#  '....',
#  '\n',
#  '드디어',
#  '본다',
#  '....',
#  '\n',
#  '@_hyok_',
#  '유튜브',
#  '에',
#  '올라와있던데',
#  '난',
#  '티빙',
#  '있지',
#  '롱',
#  '\n',
#  '노트북',
#  '으로',
#  '엠넷',
#  '티빙',
#  '에서',
#  '실시간',
#  '볼수있나요',
#  '?',
#  '\n',
#  '집',
#  '에',
#  '티비',
#  '가',
#  '없어서',
#  'ㅠㅠㅠ',
#  '꼭',
#  '아무나',
#  '답장',
#  '부탁드립니다',
#  '!!',
#  '\n',
#  '@WGWorldCafe',
#  ':',
#  '[#소희',
#  '/',
#  '사진',
#  ']',
#  '미씽',
#  '그',
#  '들',
#  '이',
#  '있었다',
#  '종',
#  '아',
#  '스틸',
#  '9~10',
#  '화',
#  '\n',
#  '@JUNYOUNG_CLIP',
#  ':',
#  'OCN',
#  '수목드라마',
#  '&',
#  'lt',
#  ';',
#  '미스터',
#  '기간',
#  '제',
#  '&',
#  'gt',
#  ';',
#  '\n',
#  '넷플릭스',
#  ',',
#  '웨이브',
#  ',',
#  '티빙',
#  ',',
#  '씨즌',
#  ',',
#  '내년',
#  '에는',
#  '디즈니',
#  '까지',
#  '국내',
#  'OTT',
#  '는',
#  '춘추전국시대',
#  '인데',
#  ',',
#  '멀티',
#  '유저',
#  '들',
#  '도',
#  '정말',
#  '많아지고',
#  '\n',
#  '동영상',
#  '뉴스',
#  '닷새',
#  '동안',
#  '이어진',
#  '추석',
#  '연휴',
#  '가',
#  '오늘',
#  '로',
#  '마무리',
#  '됩니다',
#  '.',
#  '기존',
#  '강',
#  '자',
#  '인',
#  '넷플릭스',
#  '와',
#  '왓챠',
#  '에',
#  '더해',
#  '웨이브',
#  '티빙',
#  '시즌',
#  '등',
#  '다양한',
#  '장르',
#  '와',
#  '접목',
#  '을',
#  '시도',
#  '하며',
#  '종합',
#  '예술가',
#  '적',
#  '면모',
#  '를',
#  '드러냈다',
#  '.',
#  '앞서',
#  'kbs',
#  '는',
#  '강',
#  '장관',
#  '의',
#  '배우자',
#  '이기',
#  '때문',
#  ...]

# %%
ko = nltk.Text(tokens_ko)
ko.vocab().most_common(100)    # 가장 많이 나온 단어 100개
# Out:
# [('\n', 122),
#  ('티빙', 62),
#  ('.', 36),
#  ('에', 25),
#  ('이', 24),
#  (',', 18),
#  (':', 16),
#  ('웨이브', 16),
#  ('...', 14),
#  ('도', 14),
#  ('나', 12),
#  ('!', 11),
#  ('은', 10),
#  ('으로', 10),
#  ('..', 9),
#  ('는', 9),
#  ('가', 9),
#  ('아', 8),
#  ('RT', 8),
#  ('??', 8),
#  ('의', 8),
#  ('저', 8),
#  ('로', 8),
#  ('넷플릭스', 7),
#  ('를', 7),
#  ('때', 7),
#  ('야', 7),
#  ('것', 7),
#  ('에서', 7),
#  ('&', 7),
#  (';', 7),
#  (']', 6),
#  ('(', 6),
#  ('2', 6),
#  ('들', 6),
#  ('진짜', 6),
#  ('?', 6),
#  ('왓챠', 6),
#  ('너무', 6),
#  (')', 5),
#  ('…', 5),
#  ('[', 5),
#  ('거', 5),
#  ('안', 5),
#  ("'", 5),
#  ('만', 5),
#  ('넷플', 5),
#  ('요', 5),
#  ('....', 5),
#  ('추석', 5),
#  ('종', 4),
#  ('동영상', 4),
#  ('생각', 4),
#  ('티비', 4),
#  ('보게', 4),
#  ('ㅠ', 4),
#  ('걸', 4),
#  ('볼', 4),
#  ('건', 4),
#  ('해', 4),
#  ('실시간', 4),
#  ('못', 4),
#  ('오늘', 4),
#  ('ㅋㅋㅋ', 4),
#  ('한', 4),
#  ('gt', 4),
#  ('있으니', 4),
#  ('와', 4),
#  ('스틸', 3),
#  ('풀어주세요', 3),
#  ('OTT', 3),
#  ('명', 3),
#  ('써치', 3),
#  ('광고', 3),
#  ('엄마', 3),
#  ('그', 3),
#  ('고', 3),
#  ('하고', 3),
#  ('부터', 3),
#  ('월', 3),
#  ('화', 3),
#  ('수', 3),
#  ('이런', 3),
#  ('수입', 3),
#  ('해도', 3),
#  ('될', 3),
#  ('같지', 3),
#  ('않닝', 3),
#  ('줘', 3),
#  ('뭐', 3),
#  ('화질', 3),
#  ('다시', 3),
#  ('보기', 3),
#  ('봐야지', 3),
#  ('ㅋㅋㅋㅋ', 3),
#  ('꼭', 3),
#  ('본다', 3),
#  ('그래도', 3),
#  ('있어서', 3),
#  ('!!', 3)]

# %%
# 불용어 : 인터넷 검색 시 검색 용어로 사용하지 않는 단어. 관사, 전치사, 조사, 접속사 등 검색 색인 단어로 의미가 없는 단어
stop_words = [')','?','1','"(', '_', ')/','\n','.',',', '<','!','(','(', '??','..', '4', '|', '>', '?(', '"…', '#', '&', '・', "']",'.',' ','/',"'",'’','”','“','·', '[','!','\n','·','‘','"','\n ',']',':','…',')','(','-', 'nan','가','요','답변','...','을','수','에','질문','제','를','이','도',
                      '좋','1','는','로','으로','2','것','은','다',',','니다','대','들',
                      '2017','들','데','..','의','때','겠','고','게','네요','한','일','할',
                      '10','?','하는','06','주','려고','인데','거','좀','는데','~','ㅎㅎ',
                      '하나','이상','20','뭐','까','있는','잘','습니다','다면','했','주려',
                      '지','있','못','후','중','줄','6','과','어떤','기본','!!',
                      '단어','라고','중요한','합','가요','....','보이','네','무지']

tokens_ko = [each_word for each_word in tokens_ko
             if each_word not in stop_words]

ko = nltk.Text(tokens_ko)
ko.vocab().most_common(100)
# Out:
# [('티빙', 62),
#  ('웨이브', 16),
#  ('나', 12),
#  ('아', 8),
#  ('RT', 8),
#  ('저', 8),
#  ('넷플릭스', 7),
#  ('야', 7),
#  ('에서', 7),
#  (';', 7),
#  ('진짜', 6),
#  ('왓챠', 6),
#  ('너무', 6),
#  ('안', 5),
#  ('만', 5),
#  ('넷플', 5),
#  ('추석', 5),
#  ('종', 4),
#  ('동영상', 4),
#  ('생각', 4),
#  ('티비', 4),
#  ('보게', 4),
#  ('ㅠ', 4),
#  ('걸', 4),
#  ('볼', 4),
#  ('건', 4),
#  ('해', 4),
#  ('실시간', 4),
#  ('오늘', 4),
#  ('ㅋㅋㅋ', 4),
#  ('gt', 4),
#  ('있으니', 4),
#  ('와', 4),
#  ('스틸', 3),
#  ('풀어주세요', 3),
#  ('OTT', 3),
#  ('명', 3),
#  ('써치', 3),
#  ('광고', 3),
#  ('엄마', 3),
#  ('그', 3),
#  ('하고', 3),
#  ('부터', 3),
#  ('월', 3),
#  ('화', 3),
#  ('이런', 3),
#  ('수입', 3),
#  ('해도', 3),
#  ('될', 3),
#  ('같지', 3),
#  ('않닝', 3),
#  ('줘', 3),
#  ('화질', 3),
#  ('다시', 3),
#  ('보기', 3),
#  ('봐야지', 3),
#  ('ㅋㅋㅋㅋ', 3),
#  ('꼭', 3),
#  ('본다', 3),
#  ('그래도', 3),
#  ('있어서', 3),
#  ('밴드', 3),
#  ('인', 3),
#  ('결제', 3),
#  ('하면', 3),
#  ('보고', 3),
#  ('ㅜㅜ', 3),
#  ('말', 3),
#  ('이미', 3),
#  ('까지', 3),
#  ('구독', 3),
#  ('#사이코지만괜찮아', 3),
#  ('있음', 3),
#  ('X', 3),
#  ('@WGWorldCafe', 2),
#  ('[#소희', 2),
#  ('사진', 2),
#  ('미씽', 2),
#  ('우리', 2),
#  ('아직', 2),
#  ('온라인', 2),
#  ('이용자', 2),
#  ('@OCN_ORIGINAL', 2),
#  ('인물관계도', 2),
#  ('전격', 2),
#  ('공개', 2),
#  ('자세', 2),
#  ('원', 2),
#  ('관계', 2),
#  ('미리', 2),
#  ('준비', 2),
#  ('했다', 2),
#  ('곧', 2),
#  ('자', 2),
#  ('했습니다', 2),
#  ('아부지', 2),
#  ('폰', 2),
#  ('이나', 2),
#  ('정', 2),
#  ('주행', 2)]

# %%
content_new=[]
for i in range(len(df)):
    content_new.append(str(df["content"][i]))
content_new[:1]
df["content_new"]=content_new

# %%
import re 
# '한글'을 제외한 다른 문자 모두 제거
remove_except_ko = re.compile(r"[^가-힣ㄱ-ㅎㅏ-ㅣ\\s|A-Za-z]")
def preprocess(text):
    text = re.sub(remove_except_ko,' ',text).strip()
    return text

df['clean_doc'] = df['content_new'].map(lambda x : preprocess(x))
df.head(5)
# Out:
#                                              content  \
# 0                    @WGWorldCafe: [#소희/사진] 미씽 종아 스틸
# 1                          우리 종아 아직 중딩이에요... 풀어주세요..
# 2             종아 스틸도 풀어주세요.. https://t.co/onj7rSWFad
# 3  RT @lunamoth: 온라인동영상서비스(OTT) 월간활성이용자(MAU) 순위 (...
# 4                               1. 넷플릭스 : 755만8천292명
#
#                                          content_new  \
# 0                    @WGWorldCafe: [#소희/사진] 미씽 종아 스틸
# 1                          우리 종아 아직 중딩이에요... 풀어주세요..
# 2             종아 스틸도 풀어주세요.. https://t.co/onj7rSWFad
# 3  RT @lunamoth: 온라인동영상서비스(OTT) 월간활성이용자(MAU) 순위 (...
# 4                               1. 넷플릭스 : 755만8천292명
#
#                                            clean_doc
# 0                     WGWorldCafe    소희 사진  미씽 종아 스틸
# 1                            우리 종아 아직 중딩이에요    풀어주세요
# 2             종아 스틸도 풀어주세요   https   t co onj rSWFad
# 3  RT  lunamoth  온라인동영상서비스 OTT  월간활성이용자 MAU  순위  ...
# 4                                  넷플릭스      만 천   명

# %%
from konlpy.tag import Okt
m=Okt()

# %%
stop_word = [')','?','1','"(', '_', ')/','\n','.',',', '<','!','(','(', '??','..', '4', '|', '>', '?(', '"…', '#', '&', '・', "']",'.',' ','/',"'",'’','”','“','·', '[','!','\n','·','‘','"','\n ',']',
             ':','…',')','(','-', 'nan','가','요','답변','...','을','수','에','질문','제','를','이','도','좋','1','는','로','으로','2','것','은','다',',','니다','대','들',
            '2017','들','데','..','의','때','겠','고','게','네요','한','일','할','10','?','하는','06','주','려고','인데','거','좀','는데','~','ㅎㅎ',
             '하나','이상','20','뭐','까','있는','잘','습니다','다면','했','주려','지','있','못','후','중','줄','6','과','어떤','기본','!!',
             '단어','라고','중요한','합','가요','....','보이','네','무지','안녕하세요','께서','에서','이다','에게','으로','이랑','까지','부터','하다','습니다','https','com',')',
             '?','1','"(', '_', ')/','\n','.',',', '<','!','(','(', '??','..', '4', '|', '>', '?(', '"…', '#', 
             '&', '・', "']",'.',' ','/',"'",'’','”','“','·', '[','!','\n','·','‘','"','\n ',']',':','…',')',
             '(','-', 'nan','가','요','답변','...','을','수','에','질문','제','를','이','도',
             '좋','1','는','로','으로','2','것','은','다',',','니다','대','들',
             '2017','들','데','..','의','때','겠','고','게','네요','한','일','할',
             '10','?','하는','06','주','려고','인데','거','좀','는데','~','ㅎㅎ','때문','없어',
             '하나','이상','20','뭐','까','있는','잘','습니다','다면','했','주려','되어','하면','싶어서','미하','Name','FSNsL','했는데','먼저','이고','만에','읽혀','Ht','dtype','있다고밖엔','클리어','co','보다','않음',
             '지','있','못','후','중','줄','6','과','어떤','기본','!!','에서','나','만','안','아','라','왜','더','같지',
             '단어','라고','중요한','합','가요','....','보이','네','무지','께서','에서','이다','에게','으로','이랑','까지','부터','하다','습니다','https','com',
            '안녕','수목','이루어지','새로이','이것','비디오','컨텐츠','배경','이용권','배경','재밌','형식','웨이브','이벤트','결합','드디어',
             '근래','차일피일','wavve','우리','하세','oksus','끝나','코로나','모드','세포','보시','이야기','맞추','po','Name','작품','추석','빙상','준비',
             '언급','포함','많이','무료','보내','찾아오','부가','챙기','오늘','소비','진행','모든','oksusu','이미', '자기','관심','방송','서비스','통하','배우',
             '오랜만','스마트','모아','제공','챙기','시간','dtype','부가세','통하','오랜만','계시','소개','정말','아니','기웃거','따지','보리','진행하',
             '보내','이렇','안되','두고','끝나','다라','까먹','돌리'',ㅠㅠ,''남기','오랜만','안녕','유독','진행하','다음주','과의','아름','까먹','kcl','이렇',
             '진짜','쐐면','오진','그러','반하','정말','독하','금인','몸살','지나','미리','세사','abject','naver','다가오','그동안','나중','그렇','아쉽','이리',
             '여리','갈대','직무','바로','예방','보리','주사','독감','대통령','기준','돌리','요즘','얼마','미리','렌즈','갈대','아름','문제','결국','드디어','못하','하세','ㅠㅠ',
             'Length','tokens','ㅎㅎ','ㅋㅋㅋ','고르','그렇','평소','진짜','이후','다시','즐기','비교','높이','이렇','보통','object','챙기','기사','엄청','고민','vs','dtype','현재',
             '안녕','Name','알아보','바벨','바디','진행','여러분','와이','하자','그렇','어느','앳되','끝내','이런','해소','해보','직전','말하','얼마','질리','확인','울리','기다리','한지','누르',
             '빠지','궁금하','ㅠㅠ','요금','버튼','하기','경보','저번','저의','하세','크리','알아보','직전','오래되','일보','object','dtype','Name','Length','JJ','dtype','Name','squale','youtu',
             '그동안','length','Play','KIMU','object','net','그동안','ㅋㅋㅋ','status','hwanair','saintpain','andy','ndminialbum','weibo','twitter',
             'theqoo','XHhni','나의','안녕', 'tokens','KrXOnM','Length','대해','becici','Staff','이야','텐데요','궁금하셨을','MqlklfFGR','입니다','tfZee',
            'tFZee','해줘요','하신거라','정액', '풀어주세요','lunamoth','RT','걸려서','중딩','onj','이에요','rSWFad','에요','WGWorldCafe','nouk','만이','MAU','BUiAOYLWhN','HcozccBu',
            '야하는','넷플릭스']

stopPos = ['JKS','JKC','JKG','JKO','JKM','JKI','JKQ','JC','JX','EPH','EPT'
           ,'EPP','EFN','EFQ','EFO','EFA','EFI','EFR','ECE','ECS','ECD','ETN','ETD','XPN','XPV',
            'XSN','XSV','XSA','XR','SF','SE','SS','SP','SO','SW','OH','ON','UN','MAC',"NNB","NNM","VXV","VV"]
def token_mecab(text):
    text = m.pos(text)
    text = [i for i in text if len(i[0])>1]
    text = [i for i in text if i[0] not in stop_word]
    text = [i[0] for i in text if i[1] not in stopPos]
    return text

# %%
df.head(5)
# Out:
#                                              content  \
# 0                    @WGWorldCafe: [#소희/사진] 미씽 종아 스틸
# 1                          우리 종아 아직 중딩이에요... 풀어주세요..
# 2             종아 스틸도 풀어주세요.. https://t.co/onj7rSWFad
# 3  RT @lunamoth: 온라인동영상서비스(OTT) 월간활성이용자(MAU) 순위 (...
# 4                               1. 넷플릭스 : 755만8천292명
#
#                                          content_new  \
# 0                    @WGWorldCafe: [#소희/사진] 미씽 종아 스틸
# 1                          우리 종아 아직 중딩이에요... 풀어주세요..
# 2             종아 스틸도 풀어주세요.. https://t.co/onj7rSWFad
# 3  RT @lunamoth: 온라인동영상서비스(OTT) 월간활성이용자(MAU) 순위 (...
# 4                               1. 넷플릭스 : 755만8천292명
#
#                                            clean_doc  \
# 0                     WGWorldCafe    소희 사진  미씽 종아 스틸
# 1                            우리 종아 아직 중딩이에요    풀어주세요
# 2             종아 스틸도 풀어주세요   https   t co onj rSWFad
# 3  RT  lunamoth  온라인동영상서비스 OTT  월간활성이용자 MAU  순위  ...
# 4                                  넷플릭스      만 천   명
#
#                             tokens
# 0                      소희 사진 미씽 스틸
# 1                               아직
# 2                               스틸
# 3  온라인 동영상 OTT 월간 이용자 순위 닐슨 코리안 클릭
# 4                             넷플릭스

# %%
# 토큰화 + 토큰리스트 생성 
def make_tokens(df):
    df['tokens'] = ''
    tokens_list=[]
    for i, row in df.iterrows():
        if i%10000==0:
            print(i,'/',len(df))
        token = token_mecab(df['clean_doc'][i])
        df['tokens'][i] = ' '.join(token)
    return df

# %%
df = make_tokens(df)
# Out:
# 0 / 136

# %%
df.head(3)
# Out:
#                                   content  \
# 0         @WGWorldCafe: [#소희/사진] 미씽 종아 스틸
# 1               우리 종아 아직 중딩이에요... 풀어주세요..
# 2  종아 스틸도 풀어주세요.. https://t.co/onj7rSWFad
#
#                               content_new  \
# 0         @WGWorldCafe: [#소희/사진] 미씽 종아 스틸
# 1               우리 종아 아직 중딩이에요... 풀어주세요..
# 2  종아 스틸도 풀어주세요.. https://t.co/onj7rSWFad
#
#                                 clean_doc       tokens
# 0          WGWorldCafe    소희 사진  미씽 종아 스틸  소희 사진 미씽 스틸
# 1                 우리 종아 아직 중딩이에요    풀어주세요           아직
# 2  종아 스틸도 풀어주세요   https   t co onj rSWFad           스틸

# %%
tokenized_doc=df["tokens"].apply(lambda x: x.split());tokenized_doc
tokenized_docs=tokenized_doc.apply(lambda x : ' '.join ([item for item in x if item not in stop_word]))

# %%
type(tokenized_docs)
# Out:
# pandas.core.series.Series

# %%
from wordcloud import WordCloud

# %%
df["tokens"]
# Out:
# 0                          소희 사진 미씽 스틸
# 1                                   아직
# 2                                   스틸
# 3      온라인 동영상 OTT 월간 이용자 순위 닐슨 코리안 클릭
# 4
#                     ...
# 131                                 오랜
# 132
# 133          제대로 한글 자막 보고 싶어요 일단 자막 보긴
# 134        최대한 티빙 같은데 빨리 올라오기를 기다리는 중이
# 135     받아 볼까 티빙 구독 하고 있어서 구독 그렇고 보고말까
# Name: tokens, Length: 136, dtype: object

# %%
for i in range(len(df)):
    b=str(df['tokens'])

# %%
b
# Out:
# '0                          소희 사진 미씽 스틸\n1                                   아직\n2                                   스틸\n3      온라인 동영상 OTT 월간 이용자 순위 닐슨 코리안 클릭\n4                                     \n                    ...               \n131                                 오랜\n132                                   \n133          제대로 한글 자막 보고 싶어요 일단 자막 보긴\n134        최대한 티빙 같은데 빨리 올라오기를 기다리는 중이\n135     받아 볼까 티빙 구독 하고 있어서 구독 그렇고 보고말까\nName: tokens, Length: 136, dtype: object'

# %%
wordcloud = WordCloud(font_path='malgun.ttf',max_font_size=100,background_color='white').generate(b)

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(13,13))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)
