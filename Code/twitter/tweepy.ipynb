# %% [markdown]
# <a href="https://colab.research.google.com/github/jmins33/OTT_project/blob/master/Code/twitter/tweepy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### tweepy API 입력

# %%
import os        

import sys

# %%
import tweepy

# 트위터 앱의 Keys and Access Tokens 탭 참조(자신의 설정 값을 넣어준다)
consumer_key = "
consumer_secret = ""

# %%
# 1. 인증요청(1차) : 개인 앱 정보 
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)

access_token = ""
access_token_secret= ""

# %%
# 2. access 토큰 요청(2차) - 인증요청 참조변수 이용
auth.set_access_token(access_token, access_token_secret)

# %%
# 3. twitter API 생성  
api = tweepy.API(auth)

# %% [markdown]
# ### 키워드 입력 및 txt 파일 저장

# %%
location = "%s,%s,%s" % ("35.95", "128.25", "1000km")  # 검색기준(대한민국 중심) 좌표, 반지름  

keyword = "넷플 OR 냇플"                                # OR 로 검색어 묶어줌, 검색어 5개(반드시 OR 대문자로)                               # api 생성

wfile = open(os.getcwd()+"/twitter.txt", mode='w', encoding='utf-8')     # 쓰기 모드



# twitter 검색 cursor 선언

cursor = tweepy.Cursor(api.search, 

                       q=keyword,

                       since='2020-01-01', # 2020-01-01 이후에 작성된 트윗들로 가져옴

                       count=100,  # 페이지당 반환할 트위터 수 최대 100

                       geocode=location,
                       
                       include_entities=True)

for i, tweet in enumerate(cursor.items()):

    print("{}: {}".format(i, tweet.text))

    wfile.write(tweet.text + '\n')

wfile.close()
# Out:
# 0: 넷플 공포영화 추천좀
# 좀바 개조음
#
# 킹덤 이틀만에 클리어
# 1: 솔까말...미하 수준이고, 이 정도로 바로 넷플 공개면 난 차기작 결제할 것 같지않음. 넷플 정기결제인지라(...)
# 2: 넷플 왓챠에 비하면 넘 기본이 안 되어 있다고밖엔..
# 3: 애플,디즈니,HBO맥스 국내 진출 준비 https://t.co/psuP63YJsK
# 곧 넷플에 있는 워너IP들도 다 내리겠네.....;;;;;
# OTT가 너무 많아지는 거 아냐?
# 4: 넷플은 만화읍냐
# 5: @cafe_yotsuba HBO에서 제작한거라 넷플엔 안올라 올 듯 하고 저는 웹하드에서 다운 받아 봤어요
# 6: 부산에 왔지만 집 밖에 나가지 않는 이시국 집콕러
# 나 왜 부산왔더라? ㅋㅋ 넷플이나 봐야지ㅋㅋ https://t.co/COCVJfiGiU
# 7: 보고싶은대...
# 이거하나 때문에...
# 넷플 질러야하나?ㅠㅠ https://t.co/Ht6FSNsL7R
# 8: 魔法科高校の劣等生 来訪者編
# 10월 3일 도쿄 MX
# 無能なナナ
# 10月4日 디아니메
# 憂国のモリアーティ
# 10月11日 디아니메 / 12일 넷플
# ラブライブ！虹ヶ咲学園スクールアイドル同好会
# 10월 3일 도쿄 MX
# レヱル… https://t.co/9qPmvcr8VJ
# 9: 秘密結社 鷹の爪 ～ゴールデン・スペル～
# 10月5日 디아니메
# 100万の命の上に俺は立っている
# 10月2日디아니메
# まえせつ！
# 10月4日 디아니메
# 魔王城でおやすみ
# 디아니메 미정 / 10월 12일 넷플릭스
# 禍つヴァールハ… https://t.co/cClBVxsBqX
# 10: 土下座で頼んでみた
# 10月14日 디아니메
# トニカクカワイイ
# 10月7日 디아니메 10월 2일 도쿄 MX
# ドラゴンクエスト ダイの大冒険
# 10月4日 디아니메
# NOBLESSE -ノブレス-
# 2020年10月7日도쿄MX
# ハイ… https://t.co/Jp94NNtP08
# ...

# %% [markdown]
# - 파일 위치 : C:\Users\user
