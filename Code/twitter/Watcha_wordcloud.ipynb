# %%
import pandas as pd
import numpy as np
from konlpy.tag import Okt
import nltk
m=Okt()

# %%
df=pd.read_csv('C:/Users/jminw/Desktop/media/twitterwatcha.csv', encoding='CP949')

# %%
df.head(5)
# Out:
#                       content
# 0  @OLT_jeju: 왓챠에 9분만 투자해주세오.
# 1         단편에니메이션 “별이 빛나는 밤에”
# 2               나 이거 뒷북인지 몰라도
# 3               한명이라도 더 보시라고.
# 4               정말 아름답고 따뜻하다.

# %%
okt_test = df['content']; okt_test
# Out:
# 0             @OLT_jeju: 왓챠에 9분만 투자해주세오.
# 1                    단편에니메이션 “별이 빛나는 밤에”
# 2                          나 이거 뒷북인지 몰라도
# 3                          한명이라도 더 보시라고.
# 4                          정말 아름답고 따뜻하다.
#                      ...
# 470     넷플에도 왓챠에도 보고싶은게 딱히 없어서 ㅋ ㅋ ㅋ ㅋ 후
# 471        넷플이나 왓챠에서 볼만한 영화나 드라마 추천해주세요~
# 472          일단 장난스런 키스랑 말할수없는 비밀은 다시볼거임
# 473    왓챠 왜 튕기는데 .... 나도 한자와 나오키 볼거야!!!!
# 474                @drywriting 왓챠 볼만한가요?
# Name: content, Length: 475, dtype: object

# %%
okt_list = okt_test.values.tolist()

print(len(okt_list))
okt_list
# Out:
# 475
# ['@OLT_jeju: 왓챠에 9분만 투자해주세오.',
#  '단편에니메이션 “별이 빛나는 밤에”',
#  '나 이거 뒷북인지 몰라도',
#  '한명이라도 더 보시라고.',
#  '정말 아름답고 따뜻하다.',
#  '정보없이 틀었다가 감독이름 한국분이라 더 놀랐어.왠지 한국식 작화 비슷하게 흐르는 어…',
#  'RT @wikitree: 당장 가입하겠습니다 https://t.co/DThr8P56A5 #왓챠 #추석 #WATCHA',
#  'RT @Talong_Monica: 왓챠에도 어플몬 https://t.co/5WvKxPP0So',
#  'RT @watcha_kr: 누가 적이고 동지인지 알 수 없었던 시대의 서스펜스!',
#  '영화 ?밀정? 10월 1일 왓챠 공개!',
#  '#송강호 #공유 #김지운 #왓챠 #밀정 https://t.co/KCxKRO7R9t',
#  '@nyongchicken 맞아요...맛잘알 꼴잘알 듕귁넘덜..',
#  '넷플에도 왓챠에도 보고싶은게 딱히 없어서 ㅋ ㅋ ㅋ ㅋ 후',
#  '@rlaala_ https://t.co/IWRnfzfpR5 이거 평소에도 들으시는 거 알지만 이번 주 에피 꼭 들으시고 안전거리를 확보하셨으면 합니다. 피 같은 시간 프로그래밍 언어와 넷플릭스 왓챠 불경에… https://t.co/IHzSe1DrcQ',
#  '넷플이나 왓챠에서 볼만한 영화나 드라마 추천해주세요~',
#  '일단 장난스런 키스랑 말할수없는 비밀은 다시볼거임',
#  'RT @LeegitItsAlyssa: @LeegitItsSam Aㅏ악!!!!!!!',
#  '#SamKim in the Toy Soldiers 2',
#  '??10월1일 20시 가짜사나이2??',
#  '??피지컬갤러리&amp;왓챠&amp;카카오TV',
#  '??Source : 유튜브 피지컬갤러리 ',
#  '티저보고…',
#  '왓챠 왜 튕기는데 .... 나도 한자와 나오키 볼거야!!!!',
#  '@drywriting 왓챠 볼만한가요?',
#  '@ongsim4 시험 끝나자마자 왓챠 끊는다 씨발,',
#  'RT @watcha_kr: 담당자가 진심으로 만든 ',
#  '찐 일분 이보 영상 화보집',
#  '왓챠 단독 공개!',
#  '〈배니도세계지전 : 너와 세상 끝까지〉',
#  '감상하기',
#  'RT @lunamoth: 온라인동영상서비스(OTT) 월간활성이용자(MAU) 순위 (닐슨코리안클릭, 2020년 8월 기준 https://t.co/HcozccBu0U)',
#  '1. 넷플릭스 : 755만8천292명',
#  '2. 웨이브 : 387만9천730명',
#  '3. 티빙…',
#  '@drywriting 티빙,왓챠,넷플릭스,책으로 매일을 함께 할거예요???♀?????',
#  'RT @watcha_kr: 1분 동안 당신의 치아를 건조하게 만들',
#  '9천 개 댓글의 주인공 도경수!',
#  '덕질을 위한 콘텐츠 #새로세로',
#  '#긍정이체질 지금, 왓챠!',
#  '▶? https://t.co/tCpA0jB5oT',
#  '#됴경수 #됴배우 #weareoneEX…',
#  'RT @watcha_kr: 왓챠파티에 여러분을 초대합니다 ??',
#  '이제는 친구와 왓챠에서 콘텐츠를 함께 보며 실시간으로 대화할 수 있어요!',
#  '#왓챠파티 시작하기 ??https://t.co/q6ciE9DGg9',
#  '??왓챠파티 이용 주의사항',
#  '??왓챠파티는 현재 PC…',
#  'RT @watcha_kr: 누가 적이고 동지인지 알 수 없었던 시대의 서스펜스!',
#  '영화 ?밀정? 10월 1일 왓챠 공개!',
#  '#송강호 #공유 #김지운 #왓챠 #밀정 https://t.co/KCxKRO7R9t',
#  '온라인동영상서비스(OTT) 월간활성이용자(MAU) 순위 (닐슨코리안클릭, 2020년 8월 기준 https://t.co/HcozccBu0U)',
#  '1. 넷플릭스 : 755만8천292명',
#  '2. 웨이브 : 387만9천… https://t.co/8vR64iTfny',
#  'RT @watcha_kr: 축하합니다! ?미세스 아메리카?의 배우 우조 아두바가 제72회 에미상에서 여우조연상을 수상했습니다!',
#  '왓챠 익스클루시브 ?미세스 아메리카? 감상하기 ▶? https://t.co/5MEGjDtbP1 https://t.co/cQ…',
#  'RT @chillypark: 왓챠에서 수입한 영화들은 언제 업데이트 되는 거지? 수입했다던 리틀 조, 상어, 화이트 라이, 마법에 빠졌어요, 오 머시, 스왈로우, 아담, 사르가소해의 기적 등 소식이 없네.',
#  '넷플 끊고 왓챠로 갈까봐 넷플에 없는 한드 사극 많네 독립영화도 많고 2주 무료로 보고 있는데 탐색하면서 이게 있다고?? 연발 중 ㅋㅋㅋㅋㅋ',
#  '왓챠에 액시트 올라왔다!!!',
#  '왓챠 쿠폰 등록은 한 달 미뤄야지 ^^~',
#  '덕질을 위한 콘텐츠, #새로세로',
#  '#상견니 #허광한 감상하기 ▶? https://t.co/1mcx6noFal https://t.co/8nsJwqig…',
#  'OTT(Over The Top)서비스중',
#  '(넷플릭스)만 쓰다가',
#  '최근에 아는분한테 (왓챠) 아이디를 공유받아서 ',
#  '3일 써봤는데 ',
#  '일본애니메이션이 넷플릭스보다 많아서 애니메이션 위주로 감상하실려는 분들은 왓챠가… https://t.co/KAOZYkr0x9',
#  '잼는..왓챠나..넷플 영화 추천해주실분..?',
#  '저도 추천해드리겠어요',
#  '다이버전트-얼리전트(??)-인서전트 시리즈작 넘 잼써용...여성서사...',
#  '글구 진격거..정말 잼써요...',
#  'RT @watcha_kr: 왓챠 계정주 진심입니다.',
#  '이미 상견니 허광한에 과몰입한 상태...???♀?',
#  'RT @watcha_kr: “열심히 일한 자 열심히 놀아라! ”',
#  '추석 연휴 꽉 채워 놀 수 있도록 왓챠가 준비한 스케줄! 새로 들어오는 작품까지 놓치지 말아요??',
#  ' #추석 지금, #왓챠 ',
#  '#히트맨 #데브스 #닥터후 #한자와나오키 #명절 #커피프린스1호…',
#  '이번 추석엔 바클라바를 사다 먹으며 위대한 세기를 집에서 보고 싶은데...',
#  '왜 왓챠랑 웨이브에선 지원하는데 넷플릭스엔 없나요... tv로 보고싶은데... 넷플릭스밖에 지원을 안해 우리집 기가지니는...(；ω；) 타블렛 밖에 없다규',
#  'RT @watcha_kr: 구독하면 마음이 든-든한',
#  '왓챠 1년 이용권이 99,000원?! (방청객: 워우~',
#  '9/26(토) GS SHOP에서 18:40부터',
#  '한 시간동안 진행되는 TV라이브에서 만나보세요!',
#  '*9/22(화)~10/4(일) GS SHO…',
#  '왓챠 결제 해야 하나 https://t.co/iUOkQ6Hf1R',
#  '어제 프란시스 하 너무 좋아서 왓챠에 얼른 내리기 전에 노아 바움백 감독 영화 있는거 얼른 봐야겠다',
#  '@DAYFORNEUL 왓챠 하신다면 미란다, 킬링 이브 꼭 봐보세요!! 특히 미란다 제 인생 영드에요ㅜㅜ 존잼',
#  '여려분 닥터후 즌12 보러 왓챠 끊으면 휴먼스도 봐주라',
#  'RT @LeegitItsAlyssa: Sexyyy Backkk??',
#  "뒷모습만 봐도.. 우디건지다 :')",
#  '건지오빠 하이띵??',
#  '@73737_ATM__ 사실 보고싶은 일드가 꽤 있어서요 ㅠㅠㅠㅠ. 왓챠... 기다려조... 꼭 스나님은 퇴사를 해올게...',
#  '혹시... 꼭두각시 서커스 &lt; 이것두 있을까요... 8ㅁ8 정말 보고싶던건데 한국에 판권이 없나봐요 ㅠㅠㅠ.',
#  '어뜨케 ㅠㅜ 왓챠 밥로스아져시 ㅠㅜ ',
#  '더빙판이야 ㅠㅜ',
#  '예전에 보던 더빙판인거 같운데????????',
#  '@73737_ATM__ 앗 그래요? 그건 잘 되었네요! 안그래도 퇴사 하고나면 왓챠 볼 예정이였는데!!!',
#  '왓챠에 프란시스 하 있는 줄 알았는데 내렸군 오늘 보고 오길 정말 잘했으!! 재밌고 좋고 아주 좋았음!!이게 2012년 영화 였다니!! 아담드라이버 잠깐 나왔는데 못생김의 대명사 같았는데 잠깐 흑백에 나올때… https://t.co/1UsSD1WuwZ',
#  '왓챠 이용권 받았는데',
#  '어머 왓챠에 교열걸 코노 에츠코 있네??',
#  '@toxicalice 나 엊그제 왓챠에서 김남길 베드신만 찾아봤는데 나만 그러는 게 아니었구나 다행이다',
#  '와카코와 술 시즌 5 드디어 왓챠에 업데이트. 이따 맥주 마시면서 봐야지.',
#  '@510_marvin 왓챠에서 실수로 2화부터 재생했는데 첨보고  잭블랙인줄 알았습니다ㅋ',
#  '#샤오잔 #이보 #위무선 #남망기 https://t.co/AqV1zewNpZ',
#  '여러분 왓챠에서 데브스보자.',
#  '양자이론에 의거해서 실제세계에서 거시적으로 증명하려는 그런 회사의 어떤 음모같은',
#  '하튼 존나 재밌음 https://t.co/UivhuTNBNI',
#  '왓챠에서 보고픈 리스트 반은 지웠는데 벤 애플릭 때문이었고. 난 다시는 배우 덕질은 하지 않을 거야',
#  '@92Tars 왓챠에 삼부작 전에피소드 다있는거같내요',
#  '@bmod3lw 왓챠 일본에서 재생 돼요?',
#  '가짜 사나이 시즌2가 왓챠에 들어가네ㅋㅋㅋㅋㅋ',
#  'RT @chillypark: 왓챠에서 세바스티앙 리프쉬츠의 리틀 걸 Little Girl을 수입했다고. 7살 사샤는 남자로 태어났지만 항상 본인이 여자라는 걸 알고 있다. 사샤가 다른 또래 아이들과 같은 취급을 받지 못하자 사샤의 가족은 그 다름이…',
#  '아까 보니까 ocn이었나 레디 플레이어 원 해주던데',
#  '힘 좀 내봐요 왓챠나 넷플릭스...',
#  '@_hiddencatch 아직 왓챠 안버렸는데... 저거 길지않냐눔',
#  '왓챠에서 세바스티앙 리프쉬츠의 리틀 걸 Little Girl을 수입했다고. 7살 사샤는 남자로 태어났지만 항상 본인이 여자라는 걸 알고 있다. 사샤가 다른 또래 아이들과 같은 취급을 받지 못하자 사샤의 가족… https://t.co/69oqwDWtEG',
#  '몇 년 전부터 넷플릭스를 비롯하여 왓차, 유튜브 레드 등 미디어 정기구독 서비스들이 등장하면서 보다 손쉽고 다양하게 사람들이 미디어 작품을 접할 수 있게 되었습니다.',
#  'RT @hhgbe: 왓챠 둘러다가 와 찐 재미 드라마 찾았는데. 설정오류가 좀 있긴하지만 진짜 머리 아플 정도로 다시 보고 돌려봐야 이해가 되는 듯 하다가 이거 이상한데 라고 궁금증을 가지게 만드는, 그거 하나로 찐재미... https://t.co/…',
#  '@heaven_of_1981 깔깔깔 여중여고에는 홈친녀들이 많지요... 누가 넷플이나 왓챠로 틀면 다같이 보고...',
#  '@pang_chairman 왓챠 있었지',
#  '왓챠랑 넷플에 오료 나오는거 뭐뭐 있을까요..왓챠 왜 배우 검색이 안돼????',
#  '@redruinlife ㅁㅊ 나 왓챠 9월까진데 10월부턴 티빙볼까?ㅠㅠㅠㅠㅠㅠ',
#  '어제 저녁 만들면서 왓챠에서 &lt;귀&gt;(옴니버스 공포) 봤는데 솔직히 2000년대 후반의 인터넷 괴담에 가깝다는 느낌을 받았다. 아무튼 그 중의 &lt;내 곁에 있어줘&gt;를 보면서 백합의 향기를 느꼈고.... 마지막에… https://t.co/3rjm46WdCj',
#  '코우노도리 재밌나...왓챠에 있던디',
#  '넷플릭스는 진정령을 내놔라..!!!! 내가 왓챠랑 웨이브랑 다 결제하면서 봐야겠냐!!!!',
#  '@nutpineofhorror 저기요 ㅋㅋㅋ sbs 앱에 로긴해서 보면 꽁짜거든요ㅡㅡ; 님 왓챠에서 보냈지요?날 속이려면 이정도론안되죠;;;',
#  '@_suga_mode_39 우유 왓차 어쩌고저쩌고 썰렁한 농담(부끄',
#  '수사극 원하지 않으시나요지금바로언내추럴-언내추럴',
#  '왓챠가잇으시다면당신은행운의주인공-!!',
#  '쉬츠크릭은 한국에서 어케 보는 건가 하고 어디서 하나 궁금해만 하고 찾아보지 않고 지나간 적이 두 번 있었는데 ㅋㅋㅋㅋ 뭐냐고 왓챠에 시즌5개 올라와 있잖앜ㅋㅋㅋ',
#  '왓챠에 나의 눈부신 친구.&lt;- 라는 드라마 보고있는데 와... 내 정서로는 이해를 못하겠다. 주인공 태도도 친구의 태도도. 이건 스토리 진행의 문제가 아니고 주인공 이입도 안되고. 시대적 배경이 있다고 치더… https://t.co/3H8mGfBlQn',
#  '콰르텟 본 이유는...',
#  '왓챠에서 &lt;언젠가 이 사랑을 떠올리면 분명 울어버릴 것 같아&gt; 이 일드를 봄. 이삿짐 센터 양아치역으로 나왔지만 타카하시 잇세이 목소리와 연기에 치임 =&gt; 필모 섭렵 준비 드릉드릉… https://t.co/9Xuj7qcmxB',
#  '@pang_chairman 왓챠 가자',
#  'RT @meunghaejun6: 아 진짜 머겜 이젠 슬슬 넷플에',
#  '들어오는 척이라도 해라',
#  '좀 사 돈 좀 제대로 써 넷플',
#  '왓챠야 걍 너가 먼저 해라',
#  '독점해 머겜!!!!',
#  '에미상 기념으로',
#  '왓챠는 얼른 유포리아 석세션 https://t.co/tiOvw7xZ8F',
#  '왓챠 담당자님 상견니랑 왓챠랑 콜라보해서 굿즈좀 내줘요 ㅠㅠ https://t.co/2PSc65Yunu',
#  'HBO가 싹 쓸었답니다. 왓챠 @watcha_kr 님! 준비해주십시오! https://t.co/VEzQmWzazw',
#  'RT @watcha_kr: 상견니 보다가 중독된다는 그 노래의 첫 구절',
#  '반복해 들어볼까요? ',
#  '@wanggahy_ongji 왓챠 되는 거 알게 되면 저도 알려주세요ㅋㅋㅋㅋ',
#  '왓챠에 있는 옐로우스톤 다큐 시리즈도 다 봤다. 단순히 그 지역의 동물들이 살아가는 이야기가 아닌 지금의 기후변화가 그곳의 자연에 어떤 영향을 끼치고 있는지 상세히 다뤄줘서 너무 좋았다.',
#  '@wanggahy_ongji 2번 선택하고 파이어스틱4K 쓰면, 넷플릭스 유투브 바로 볼 수 있어요. 웨이브는 미러링 가능. 왓챠는 미러링 안 됨. 크롬캐스트는 안 써봐서 비교는 못 하지만 제가 파이어스틱 쓰고 있어서 참고하시라고 달아요.',
#  '@Josh40GOC 오 견딜만한 어두움인가 보군요 왓챠에 안올라오려나요 나오는 새럼들이 그렇게 아름답다고 하던데??젠데이아 연기 넘 궁금하고요!!',
#  '왓치맨 에미상 수상했구나 이참에 왓챠에서 수입하면 좋겠다 (기승전왓챠',
#  '@konanrubber 왓챠보다 좋은가보죠? ?',
#  '왓챠 볼거',
#  '휴먼스',
#  '이어즈앤이어즈',
#  '리틀드러머걸',
#  '빅리라',
#  '와이우먼킬',
#  '@since201605 제가 그래서 아침공복유산소를 시작했어요',
#  '타트체리쥬스값 본전 뽑으려고ㅋㅋㅋ',
#  '이제 왓챠 끊어서 보면 그 본전도 뽑아야죠',
#  '실내자전거값은 중고로 4만원에 샀고요',
#  'RT @sunwoo_hoon: 왓챠에서 영화 &lt;메기&gt;를 봣는데 너무 완벽했다 ㅠㅠ 세상 최고의 영화다',
#  'RT @OLT_jeju: 요즘 왓챠의 연애시대 다시 보는데.',
#  '시대를 앞서간 쿨한 만남이 잦아 깜짝깜짝 놀란다.',
#  '예를 들어...',
#  '이혼한 전 부인이 만나는 남자와 함께 이혼해 주지않는 그 부인을 만난다거나....',
#  '옛스러움을 깨우치는것은',
#  '단비트 휴대폰 음…',
#  '왓챠에서 르슈포프의 숙녀들이라는 해사한 영화를 보는데 도입부 좀 지나서 나오는 단체 댄스씬이 레뷰 보는것같음',
#  '과격하고 흥미로운 드라마.',
#  '좀 늦었지만 추석쿠폰으로',
#  '왓챠는 2주무료이용이 가능하다니까 부담없이 먼저 보시기 좋겠네요. ??',
#  "@maliasylwia 음... '왓챠'라고 다른 사이트가 있어요! 여기는 넷플릭스랑은 다른 특징이 있는데 일드 한드 중드나 영화가 많다고 들었어요. 미드도 확실히 있어요. 다만 제가 왓챠는 쓰지를 않아서… https://t.co/VwyHwOIa8o",
#  '추석연휴',
#  '왓챠 3일 쿠폰으로',
#  '“언내추럴”를 드디어 봤고',
#  '완전 멋진 드라마였다.',
#  '라온마 프랑스판은 도대체 삭제를 얼마나 했길래 8장짜리 딥디가 6장짜리로 발매되었는가........ 왓챠보다 더 잘린건 알고있는데........ 도대체 다들 왜그러냐',
#  '영화 #하트어택 과 함께 하루를 ',
#  '건강한 에너지를 뿜뿜 전해받았던 오늘 ????????',
#  '#heartattack #이충현감독 #이성경배우 @heybiblee aka #건강천재 @watcha_kr #왓챠 에서 볼 수… https://t.co/J3RWdgPrHp',
#  "왓챠 대당여법의 오프닝때 '지난이야기' 보여줄때 틀어주는 노래가 너무좋은데 대체 중드 오에스티는 어디서 들음",
#  '@lambert078 왓챠 3닐무료인가 하던데 빨리 보시라구요 넉살은 없지만...',
#  '왓챠를 실수로 처음 프리미엄 무료 이용을 iOS로 선택해 버렸었는데 무료기간 끝나고 쓰려고 사둔 1년 이용권... iOS에서 프리미엄 캔슬하고 다른 OS에서 넣으면 쓸 수 있겠지...? (안 써지면 망함)',
#  '사랑하는 사람의 멈춘 심장을 다시 뛰게 하기 위해 100번의 시간을 돌리는 여자의 이야기 &lt;하트어택&gt;',
#  'RT @watcha_kr: 왓챠에서 볼 수 있는 이시하라 사토미의 작품들 ',
#  '?언내추럴? ?실연 쇼콜라티에? ?5시부터 9시까지 ~나를 사랑한 스님~? 등등',
#  'RT @orBackInTime: 원래 313 오프닝은 이건데... 왓챠랑 kbs는 삭제하엿다... 왜지 국뽕국이 국뽕국 갬성으로 행성뽕질을 해서 그런걸까',
#  '지구에 오는 왹져가 애초에 있긴함...? 눈곱만큼 있어봐야 우주 뿡뿡이 불법체류자들 정도 뿐인데…',
#  'RT @orBackInTime: 즌3 kbc&amp;왓챠 마사 삭제분(스포주의)',
#  '@1717mmmmmmmm 왓챠에 있는 거 봐야되서 없더라구요ㅠㅠ',
#  '@1717mmmmmmmm 왓챠에 있는 죠필 다 깰거에요!',
#  '@happysong67 그냥 넷플릭스나 왓챠를 뒤져보게 되더라구요 요새는 ㅋㅋㅋ',
#  '@L1F30NM4RS_1988 아 근데 그... 왓챠 결제 되있는 사람은 안되용',
#  '@L1F30NM4RS_1988 추석엔왓챠? 엿나? 인스타에 가면 있어요!!',
#  '왓챠에 이준혁 필모 뭐 있죠..?',
#  '오랜만에 다시 왓챠 구독 활성화 된 덕분에 전부터 궁금했던 #DEVS 봤다. 과학으로 끌고가던 스토리에 철학을 던지고 끝남. 소재도 그렇고 영상이나 음악도 그렇고 재미있게 봤다.',
#  '왓챠 달리는 중........',
#  '왓챠 추석3일 이용권 이벤트 중',
#  "쿠폰란에 '올추석엔왓챠' 쓰면 됨. 한자와나오키 시즌2 있네 +_+",
#  '@2rang_rang 기기마다 앱 스토어 배포 속도가 달라 최신 버전의 앱 버전이 보여지는 데 시간 차이가 있을 수 있습니다. 앱 스토어에서 왓챠 앱 iOS 1.9.86버전 여부 확인해주시면 됩니다.',
#  '추석 연휴 꽉 채워 놀 수 있도록 왓챠가 준비한 스케줄! 새로 들어오는 작품까지 놓치지 말아요??',
#  '@Upgrade_MyLife 왓챠 써보니 넷플릭스보다 한참 느립니다. HBO컨텐츠는 못보게 되어 있고',
#  '결정적으로 그냥 신규가입해도 2주 무료 관람인데 추석3일 공짜 보자고 가입한게 너무 억울하네요',
#  '그레이 아나토미 마저 보고싶은데 왓챠 배속 기능 대체 왜 없는겨...... 젭알 타임푸어 현대인을 위한 정주행 필수기능 아닌지 ㅠ',
#  '포켓몬 영상 보고나서 오 하고 왓챠를 켯는데 메인에 스탠 바이 미가 떡하니 있어서 뭐지 이거 노리고 올려놓은건가 싶었음',
#  '왓챠 2개월 끊었더니 넷플...넷플도 지른다',
#  '왓챠 망하는 소리가 들려오는구나 ㅠㅠ https://t.co/41ecYjo8pv',
#  '아 언내추럴 실트라 시즌2인줄 알고 헐레벌떡 들어갔다가 나왔어... 저는... 이미 언내추럴 때문에 왓챠를 정기구독중이라 3일 무료가 노상관이라구요...(게다가 타이밍 좋게 레몬 듣고 있었음',
#  'RT @watcha_kr: 내 인생 좀 놔줘요',
#  '내 인생을 안 놔주는 #진정령 을 #왓챠플레이 에서 감상해보세요 ??  https://t.co/TzfnE8txMr https://t.co/oaZiwjA3gK',
#  'RT @lunamoth: 왓챠 3일 무료라는듯. 코드는 ',
#  '올추석엔왓챠',
#  '내가 쉬는 날 더 바쁘다고 하면 도대체 집구석에서 뭐하냐고들 하는데 나는 고영 2마리와 함께 살고 넷플, 왓챠, 웨이브를 구독중에 있으며 안 읽은 책이 더 많고 아이패드와 노트북과 4개의 외장하드를 가진 오타쿠라고요',
#  '왓챠,,,나는 코우노도리 추천한다,,,,일단 보봐라',
#  '넷플은 들어가기전에 카드번호 입력하라고 해서 막혔는데.. ',
#  '왓챠는 카드번호 입력을 안 해두 되는거야ㅡ.?',
#  '왓챠 가입 안 되있는대.. 3일이 되는건강..? ',
#  '가입 되있는 사람들만 된느 거겠지..',
#  '이 모든것은 티비로 넷플릭스랑 왓챠를 다 보기위한 노력..',
#  '히야 왓챠 깜짝놀랐네 걍 넷플릭스 카피 아니냐',
#  '왓챠 쿠폰으로 중드보고 싶은데 넘 길어서 잘못된 선택이 3일을 날릴 수 있단 걸 아니까 신중해진다...',
#  'RT @wikitree: 유쾌 상쾌 통쾌한 드라마라고 합니다 https://t.co/lCWDd8sLwl #왓챠 #한자와나오키 #추석',
#  'RT @chillypark: 왓챠에서 수입한 영화들은 언제 업데이트 되는 거지? 수입했다던 리틀 조, 상어, 화이트 라이, 마법에 빠졌어요, 오 머시, 스왈로우, 아담, 사르가소해의 기적 등 소식이 없네.',
#  '왓챠가 29일부터 3일동안 무료 왓챠를 할 수 있게 이벤트를 열었어요 다들 트위터에 왓챠를 치고 왓챠 계정의 추석 링크로 들어가서 3일동안 왓챠를 즐기세요!!! https://t.co/m0hnyNc7r1',
#  '나도 추석에 왓챠나 보고싶다.....',
#  '왓챠 쿠폰으로 3일동안 언내추럴 정주행 하자 언내추럴언내추럴언내추럴언내추럴 https://t.co/pEN7xYjH9k',
#  '왓챠가 3일 무료라 평소 보고 싶었던 교열걸을 보기로 했어요',
#  '넷플 왓챠 라프텔 애니플러스 웨이브 아마존프라임을 하나로 통합 시켜달라는 건… 전 토렌트를 쓰고 싶어요~로 들리는 내가 삐딱한 거겠지.',
#  '왓챠 청각장애인용 자막이 없는데 물어보니깐 있는건 있는데 없는건 없대 진짜 주먹구구식이구나 ... 응 안써',
#  '눈팅중 발견! 왓챠 추석 3일 무료 이용권입니다  #놀것 #핫딜 #지름 #알구몬 https://t.co/G3FgJoGy0m',
#  '와 왓챠 ...!!! 커프도 보고 볼 수 있으면 타카네노하나도 보고 3일동안 왈랄랄 해버릴거야',
#  '왓챠로 우선 한자와나오키 시즌1 복습해야지',
#  '@dored95 헤헤 공각재미있죠. 오시이마모루판 극장2연작(공각기동대,이노센스)그리고 리부트판 어라이즈(ova4편을 편집한 티비버전aaa,신극장판)도 추천해드립니다. 왓챠에서 보실수있어요! 추석3일무료 티켓도 푸렸으니 즐겨주시길!',
#  '파리의딜릴리봤는데... 왓챠 코멘트 진짜 ㅋㅋㅋㅋㅋ저급이다ㅋㅋ ',
#  '누구나 쉽게 볼수있는 애니메이션으로 만든거같은데 득달같이 달려들어서는...',
#  '추하다 ㅋ 그성별인게 더웃김 물론 비판할 수는 있는데 저렇게 죽자살… https://t.co/HqmHqQmTQ9',
#  '“스마트폰-PC서는 이용 가능”…왓챠, 아이패드서 로그인 에러 발생해 복구 작업 나서 #왓챠 #아이패드 #오류 https://t.co/tKxnVCByru',
#  'RT @wikitree: 당장 가입하겠습니다 https://t.co/DThr8P56A5 #왓챠 #추석 #WATCHA',
#  '추석을 맞아 고대하고 고대하던 위대한 세기를 보기 시작했고 1시즌이 일단 50화가 넘는데서 부터 대륙의 패기를 느꼈다...',
#  '그리고 왓챠는 오프닝 건너뛰기를 제공을 안하는구나. 겁나 귀찮다. 넷플릭스 반성해라… https://t.co/rXy4vS52oE',
#  '헐!! #왓챠 에 드롭데드디바가 있다 ㅜㅜㅜㅜㅜㅜㅜ',
#  '@nyongchicken 맞아요...맛잘알 꼴잘알 듕귁넘덜..',
#  '넷플에도 왓챠에도 보고싶은게 딱히 없어서 ㅋ ㅋ ㅋ ㅋ 후',
#  '넷플이나 왓챠에서 볼만한 영화나 드라마 추천해주세요~',
#  '일단 장난스런 키스랑 말할수없는 비밀은 다시볼거임',
#  '왓챠 왜 튕기는데 .... 나도 한자와 나오키 볼거야!!!!',
#  '@drywriting 왓챠 볼만한가요?']

# %%
import nltk
from konlpy.tag import Okt; t = Okt()

# %%
# 리스트 중 str 타입이 아닌 요소들이 존재함을 확인
for i in okt_list:
    if type(i) == float:
        i = str(i)
        print(i)

# %%
# str 타입이 아닌 요소들이 있으면 전부 str 타입으로 바꿔라!
for i in range(len(okt_list)):
    if type(okt_list[i]) != str:
        okt_list[i] = str(okt_list[i])

# %%
okt_text = ''

for each_line in okt_list[:2000]:
    okt_text = okt_text + each_line + '\n'

# %%
tokens_ko = t.morphs(okt_text)
tokens_ko
# Out:
# ['@OLT_jeju',
#  ':',
#  '왓챠',
#  '에',
#  '9분',
#  '만',
#  '투자',
#  '해주세오',
#  '.',
#  '\n',
#  '단편',
#  '에',
#  '니',
#  '메이',
#  '션',
#  '“',
#  '별',
#  '이',
#  '빛나는',
#  '밤',
#  '에',
#  '”',
#  '\n',
#  '나',
#  '이',
#  '거',
#  '뒷북',
#  '인지',
#  '몰라도',
#  '\n',
#  '한',
#  '명',
#  '이라도',
#  '더',
#  '보시',
#  '라고',
#  '.',
#  '\n',
#  '정말',
#  '아름답고',
#  '따뜻하다',
#  '.',
#  '\n',
#  '정보',
#  '없이',
#  '틀었다가',
#  '감독',
#  '이름',
#  '한국',
#  '분',
#  '이라',
#  '더',
#  '놀랐어',
#  '.',
#  '왠지',
#  '한국',
#  '식',
#  '작화',
#  '비슷하게',
#  '흐르는',
#  '어',
#  '…',
#  '\n',
#  'RT',
#  '@wikitree',
#  ':',
#  '당장',
#  '가입',
#  '하겠습니다',
#  'https://t.co/DThr8P56A5',
#  '#왓챠',
#  '#추석',
#  '#WATCHA',
#  '\n',
#  'RT',
#  '@Talong_Monica',
#  ':',
#  '왓챠',
#  '에도',
#  '어플',
#  '몬',
#  'https://t.co/5WvKxPP0So',
#  '\n',
#  'RT',
#  '@watcha_kr',
#  ':',
#  '누가',
#  '적',
#  '이고',
#  '동지',
#  '인지',
#  '알',
#  '수',
#  '없었던',
#  '시대',
#  '의',
#  '서스펜스',
#  '!',
#  '\n',
#  '영화',
#  '?',
#  '밀정',
#  '?',
#  '10월',
#  '1일',
#  '왓챠',
#  '공개',
#  '!',
#  '\n',
#  '#송강호',
#  '#공유',
#  '#김지운',
#  '#왓챠',
#  '#밀정',
#  'https://t.co/KCxKRO7R9t',
#  '\n',
#  '@nyongchicken',
#  '맞아요',
#  '...',
#  '맛',
#  '잘알',
#  '꼴',
#  '잘알',
#  '듕귁',
#  '넘',
#  '덜',
#  '..',
#  '\n',
#  '넷플',
#  '에도',
#  '왓챠',
#  '에도',
#  '보고',
#  '싶은게',
#  '딱히',
#  '없어서',
#  'ㅋ',
#  'ㅋ',
#  'ㅋ',
#  'ㅋ',
#  '후',
#  '\n',
#  '@rlaala_',
#  'https://t.co/IWRnfzfpR5',
#  '이',
#  '거',
#  '평소',
#  '에도',
#  '들으시는',
#  '거',
#  '알',
#  '지만',
#  '이번',
#  '주',
#  '에피',
#  '꼭',
#  '들으시고',
#  '안전',
#  '거리',
#  '를',
#  '확보',
#  '하셨으면',
#  '합니다',
#  '.',
#  '피',
#  '같은',
#  '시간',
#  '프로그래밍',
#  '언어',
#  '와',
#  '넷플릭스',
#  '왓챠',
#  '불경',
#  '에',
#  '…',
#  'https://t.co/IHzSe1DrcQ',
#  '\n',
#  '넷플',
#  '이나',
#  '왓챠',
#  '에서',
#  '볼',
#  '만',
#  '한',
#  '영화',
#  '나',
#  '드라마',
#  '추천',
#  '해주세요',
#  '~',
#  '\n',
#  '일단',
#  '장난스런',
#  '키스',
#  '랑',
#  '말',
#  '할수',
#  '없는',
#  '비밀',
#  '은',
#  '다시',
#  '볼거',
#  '임',
#  '\n',
#  'RT',
#  '@LeegitItsAlyssa',
#  ':',
#  '@LeegitItsSam',
#  'A',
#  'ㅏ',
#  '악',
#  '!!!!!!!',
#  '\n',
#  '#SamKim',
#  'in',
#  'the',
#  'Toy',
#  'Soldiers',
#  '2',
#  '\n',
#  '??',
#  '10월',
#  '1일',
#  '20시',
#  '가짜',
#  '사나이',
#  '2',
#  '??',
#  '\n',
#  '??',
#  '피지',
#  '컬',
#  '갤러리',
#  '&',
#  'amp',
#  ';',
#  '왓챠',
#  '&',
#  'amp',
#  ';',
#  '카카오',
#  'TV',
#  '\n',
#  '??',
#  'Source',
#  ':',
#  '유튜브',
#  '피지',
#  '컬',
#  '갤러리',
#  '티저',
#  '보고',
#  '…',
#  '\n',
#  '왓챠',
#  '왜',
#  '튕',
#  '기는데',
#  '....',
#  '나도',
#  '한자',
#  '와',
#  '나오키',
#  '볼거야',
#  '!!!!',
#  '\n',
#  '@drywriting',
#  '왓챠',
#  '볼',
#  '만',
#  '한',
#  '가요',
#  '?',
#  '\n',
#  '@ongsim4',
#  '시험',
#  '끝나자마자',
#  '왓챠',
#  '끊는다',
#  '씨발',
#  ',',
#  '\n',
#  'RT',
#  '@watcha_kr',
#  ':',
#  '담당자',
#  '가',
#  '진심',
#  '으로',
#  '만든',
#  '찐',
#  '일분',
#  '이보',
#  '영상',
#  '화보',
#  '집',
#  '\n',
#  '왓챠',
#  '단독',
#  '공개',
#  '!',
#  '\n',
#  '〈',
#  '배니도',
#  '세계',
#  '지',
#  '전',
#  ':',
#  '너',
#  '와',
#  '세상',
#  '끝',
#  '까지',
#  '〉',
#  '\n',
#  '감상',
#  '하기',
#  '\n',
#  'RT',
#  '@lunamoth',
#  ':',
#  '온라인',
#  '동영상',
#  '서비스',
#  '(',
#  'OTT',
#  ')',
#  '월간',
#  '활',
#  '성',
#  '이용자',
#  '(',
#  'MAU',
#  ')',
#  '순위',
#  '(',
#  '닐슨',
#  '코리안',
#  '클릭',
#  ',',
#  '2020년',
#  '8월',
#  '기준',
#  'https://t.co/HcozccBu0U',
#  ')',
#  '\n',
#  '1',
#  '.',
#  '넷플릭스',
#  ':',
#  '755만',
#  '8천',
#  '292',
#  '명',
#  '\n',
#  '2',
#  '.',
#  '웨이브',
#  ':',
#  '387만',
#  '9천',
#  '730',
#  '명',
#  '\n',
#  '3',
#  '.',
#  '티빙',
#  '…',
#  '\n',
#  '@drywriting',
#  '티빙',
#  ',',
#  '왓챠',
#  ',',
#  '넷플릭스',
#  ',',
#  '책',
#  '으로',
#  '매일',
#  '을',
#  '함께',
#  '할거예요',
#  '???',
#  '♀',
#  '?????',
#  '\n',
#  'RT',
#  '@watcha_kr',
#  ':',
#  '1분',
#  '동안',
#  '당신',
#  '의',
#  '치아',
#  '를',
#  '건조하게',
#  '만들',
#  '\n',
#  '9천',
#  '개',
#  '댓글',
#  '의',
#  '주인공',
#  '도경수',
#  '!',
#  '\n',
#  '덕질',
#  '을',
#  '위',
#  '한',
#  '콘텐츠',
#  '#새로세로',
#  '\n',
#  '#긍정이체질',
#  '지금',
#  ',',
#  '왓챠',
#  '!',
#  '\n',
#  '▶',
#  '?',
#  'https://t.co/tCpA0jB5oT',
#  '\n',
#  '#됴경수',
#  '#됴배우',
#  '#weareoneEX',
#  '…',
#  '\n',
#  'RT',
#  '@watcha_kr',
#  ':',
#  '왓챠파티',
#  '에',
#  '여러분',
#  '을',
#  '초대',
#  '합니다',
#  '??',
#  '\n',
#  '이제',
#  '는',
#  '친구',
#  '와',
#  '왓챠',
#  '에서',
#  '콘텐츠',
#  '를',
#  '함께',
#  '보며',
#  '실시간',
#  '으로',
#  '대화',
#  '할',
#  '수',
#  '있어요',
#  '!',
#  '\n',
#  '#왓챠파티',
#  '시작',
#  '하기',
#  '?',
#  '?https://t.co/q6ciE9DGg9',
#  '\n',
#  '??',
#  '왓챠',
#  '파티',
#  '이용',
#  '주의',
#  '사항',
#  '\n',
#  '??',
#  '왓챠파티',
#  '는',
#  '현재',
#  'PC',
#  '…',
#  '\n',
#  'RT',
#  '@watcha_kr',
#  ':',
#  '누가',
#  '적',
#  '이고',
#  '동지',
#  '인지',
#  '알',
#  '수',
#  '없었던',
#  '시대',
#  '의',
#  '서스펜스',
#  '!',
#  '\n',
#  '영화',
#  '?',
#  '밀정',
#  '?',
#  '10월',
#  '1일',
#  '왓챠',
#  '공개',
#  '!',
#  '\n',
#  '#송강호',
#  '#공유',
#  '#김지운',
#  '#왓챠',
#  '#밀정',
#  'https://t.co/KCxKRO7R9t',
#  '\n',
#  '온라인',
#  '동영상',
#  '서비스',
#  '(',
#  'OTT',
#  ')',
#  '월간',
#  '활',
#  '성',
#  '이용자',
#  '(',
#  'MAU',
#  ')',
#  '순위',
#  '(',
#  '닐슨',
#  '코리안',
#  '클릭',
#  ',',
#  '2020년',
#  '8월',
#  '기준',
#  'https://t.co/HcozccBu0U',
#  ')',
#  '\n',
#  '1',
#  '.',
#  '넷플릭스',
#  ':',
#  '755만',
#  '8천',
#  '292',
#  '명',
#  '\n',
#  '2',
#  '.',
#  '웨이브',
#  ':',
#  '387만',
#  '9천',
#  '…',
#  'https://t.co/8vR64iTfny',
#  '\n',
#  'RT',
#  '@watcha_kr',
#  ':',
#  '축하',
#  '합니다',
#  '!',
#  '?',
#  '미세',
#  '스',
#  '아메리카',
#  '?',
#  '의',
#  '배우',
#  '우조',
#  '아두',
#  '바',
#  '가',
#  '제',
#  '72회',
#  '에미상',
#  '에서',
#  '여우',
#  '조',
#  '연상',
#  '을',
#  '수상했습니다',
#  '!',
#  '\n',
#  '왓챠',
#  '익스',
#  '클루',
#  '시브',
#  '?',
#  '미세',
#  '스',
#  '아메리카',
#  '?',
#  '감상',
#  '하기',
#  '▶',
#  '?',
#  'https://t.co/5MEGjDtbP1',
#  'https://t.co/cQ',
#  '…',
#  '\n',
#  'RT',
#  '@chillypark',
#  ':',
#  '왓챠',
#  '에서',
#  '수입',
#  '한',
#  '영화',
#  '들',
#  '은',
#  '언제',
#  '업데이트',
#  '되는',
#  '거지',
#  '?',
#  '수입',
#  '했다던',
#  '리틀',
#  '조',
#  ',',
#  '상어',
#  ',',
#  '화이트',
#  '라이',
#  ',',
#  '마법',
#  '에',
#  '빠졌어요',
#  ',',
#  '오',
#  '머시',
#  ',',
#  '스왈로우',
#  ',',
#  '아담',
#  ',',
#  '사르가소',
#  '해',
#  '의',
#  '기적',
#  '등',
#  '소식',
#  '이',
#  '없네',
#  '.',
#  '\n',
#  '넷플',
#  '끊고',
#  '왓챠',
#  '로',
#  '갈까봐',
#  '넷플',
#  '에',
#  '없는',
#  '한드',
#  '사극',
#  '많네',
#  '독립영화',
#  '도',
#  '많고',
#  '2',
#  '주',
#  '무료',
#  '로',
#  '보고',
#  '있는데',
#  '탐색',
#  '하면서',
#  '이',
#  '게',
#  '있다고',
#  '??',
#  '연발',
#  '중',
#  'ㅋㅋㅋㅋㅋ',
#  '\n',
#  '왓챠',
#  '에',
#  '액',
#  '시트',
#  '올라왔다',
#  '!!!',
#  '\n',
#  '왓챠',
#  '쿠폰',
#  '등록',
#  '은',
#  '한',
#  '달',
#  '미뤄야지',
#  '^^~',
#  '\n',
#  '덕질',
#  '을',
#  '위',
#  '한',
#  '콘텐츠',
#  ',',
#  '#새로세로',
#  '\n',
#  '#상견니',
#  '#허광한',
#  '감상',
#  '하기',
#  '▶',
#  '?',
#  'https://t.co/1mcx6noFal',
#  'https://t.co/8nsJwqig',
#  '…',
#  '\n',
#  'OTT',
#  '(',
#  'Over',
#  'The',
#  'Top',
#  ')',
#  '서비스',
#  '중',
#  '\n',
#  '(',
#  '넷플릭스',
#  ')',
#  '만',
#  '쓰다가',
#  '\n',
#  '최근',
#  '에',
#  '아는',
#  '분',
#  '한테',
#  '(',
#  '왓챠',
#  ')',
#  '아이디',
#  '를',
#  '공유',
#  '받아서',
#  '3일',
#  '써',
#  '봤는데',
#  '일',
#  '본',
#  '애니메이션',
#  '이',
#  '넷플릭스',
#  '보다',
#  '많아서',
#  '애니메이션',
#  '위주',
#  '로',
#  '감상',
#  '하실려는',
#  '분',
#  '들',
#  '은',
#  '왓챠',
#  '가',
#  '…',
#  'https://t.co/KAOZYkr0x9',
#  '\n',
#  '잼는',
#  '..',
#  '왓챠',
#  '나',
#  '..',
#  '넷플',
#  '영화',
#  '추천',
#  '해주실',
#  '분',
#  '..?',
#  '\n',
#  '저',
#  '도',
#  '추천',
#  '해드리겠어요',
#  '\n',
#  '다이버전트',
#  '-',
#  '얼리전트',
#  '(??)-',
#  '인서전트',
#  '시리즈',
#  '작',
#  '넘',
#  '잼',
#  '써용',
#  '...',
#  '여성',
#  '서사',
#  '...',
#  '\n',
#  '글구',
#  '진격',
#  '거',
#  '..',
#  '정말',
#  '잼',
#  '써요',
#  '...',
#  '\n',
#  'RT',
#  '@watcha_kr',
#  ':',
#  '왓챠',
#  '계정',
#  '주',
#  '진심',
#  '입니다',
#  '.',
#  '\n',
#  '이미',
#  '상견',
#  '니',
#  '허',
#  '광',
#  '한에',
#  '과',
#  '몰입',
#  '한',
#  '상태',
#  '...???',
#  '♀',
#  '?',
#  '\n',
#  'RT',
#  '@watcha_kr',
#  ':',
#  '“',
#  '열심히',
#  '일',
#  '한',
#  '자',
#  '열심히',
#  '놀아라',
#  '!',
#  '”',
#  '\n',
#  '추석',
#  '연휴',
#  '꽉',
#  '채워',
#  '놀',
#  '수',
#  '있도록',
#  '왓챠',
#  '가',
#  '준비',
#  '한',
#  '스케줄',
#  '!',
#  '새로',
#  '들어오는',
#  '작품',
#  '까지',
#  '놓치지',
#  '말아요',
#  '??',
#  '\n ',
#  '#추석',
#  '지금',
#  ',',
#  '#왓챠',
#  '#히트맨',
#  '#데브스',
#  '#닥터후',
#  '#한자와나오키',
#  '#명절',
#  '#커피프린스1호',
#  '…',
#  '\n',
#  '이번',
#  '추석',
#  '엔',
#  '바클라바',
#  '를',
#  '사다',
#  '먹으며',
#  '위대한',
#  '세기',
#  '를',
#  '집',
#  '에서',
#  '보고',
#  '싶은데',
#  '...',
#  '\n',
#  '왜',
#  '왓챠',
#  '랑',
#  '웨이브',
#  '에선',
#  '지원',
#  '하는데',
#  '넷플릭스',
#  '엔',
#  '없나요',
#  '...',
#  'tv',
#  '로',
#  '보고싶은데',
#  '...',
#  '넷플릭스',
#  '밖에',
#  '지원',
#  '을',
#  '안해',
#  '우리',
#  '집',
#  '기',
#  '가',
#  '지니는',
#  '...(',
#  '；ω；',
#  ')',
#  '타블렛',
#  '밖에',
#  '없다',
#  '규',
#  '\n',
#  'RT',
#  '@watcha_kr',
#  ':',
#  '구독',
#  '하면',
#  '마음',
#  '이',
#  '든',
#  '-',
#  '든한',
#  '\n',
#  '왓챠',
#  '1년',
#  '이용권',
#  '이',
#  '99,000원',
#  '?!',
#  '(',
#  '방청객',
#  ':',
#  '워',
#  '우',
#  '~',
#  '\n',
#  '9/26',
#  '(',
#  '토',
#  ')',
#  'GS',
#  'SHOP',
#  '에서',
#  '18:40',
#  '부터',
#  '\n',
#  '한',
#  '시간',
#  '동안',
#  '진행',
#  '되는',
#  'TV',
#  '라이브',
#  '에서',
#  '만나',
#  '보세요',
#  '!',
#  '\n',
#  '*',
#  '9/22',
#  '(',
#  '화',
#  ')~',
#  '10/4',
#  '(',
#  '일',
#  ')',
#  'GS',
#  'SHO',
#  '…',
#  '\n',
#  '왓챠',
#  '결제',
#  '해야',
#  '하나',
#  'https://t.co/iUOkQ6Hf1R',
#  '\n',
#  '어제',
#  '프란시스',
#  '하',
#  '너무',
#  '좋아서',
#  '왓챠',
#  '에',
#  '얼른',
#  '내',
#  '리기',
#  '전',
#  '에',
#  '노아',
#  '바움',
#  '백',
#  '감독',
#  '영화',
#  ...]

# %%
ko = nltk.Text(tokens_ko)
ko.vocab().most_common(100)    # 가장 많이 나온 단어 100개
# Out:
# [('\n', 447),
#  ('왓챠', 311),
#  ('에', 146),
#  ('.', 110),
#  ('이', 102),
#  ('...', 82),
#  ('가', 74),
#  ('의', 69),
#  ('를', 68),
#  (',', 66),
#  ('에서', 65),
#  ('?', 64),
#  (':', 60),
#  ('는', 59),
#  ('도', 57),
#  ('을', 52),
#  ('…', 50),
#  ('들', 48),
#  ('로', 48),
#  ('..', 46),
#  ('RT', 43),
#  ('은', 42),
#  ('한', 40),
#  ('!', 40),
#  ('다', 39),
#  ('나', 37),
#  ('넷플릭스', 37),
#  ('안', 36),
#  ('와', 34),
#  ('3일', 31),
#  ('영화', 30),
#  ('넷플', 30),
#  ('보고', 30),
#  ('??', 29),
#  ('&', 29),
#  (';', 29),
#  ('만', 27),
#  ('2', 27),
#  (')', 27),
#  ('거', 26),
#  ('볼', 25),
#  ('으로', 25),
#  ('(', 25),
#  ('@watcha_kr', 24),
#  ('수', 23),
#  ('까지', 23),
#  ('무료', 23),
#  ('추석', 22),
#  ('랑', 21),
#  ('아', 21),
#  ('그', 20),
#  ('중', 18),
#  ('시즌', 18),
#  ('하고', 18),
#  ('왜', 17),
#  ('전', 17),
#  ('내', 16),
#  ('좀', 16),
#  ('#왓챠', 15),
#  ('추천', 15),
#  ('있는데', 15),
#  ('너무', 15),
#  ('못', 15),
#  ('ㅋㅋㅋ', 15),
#  ('고', 15),
#  ('언', 15),
#  ('드라마', 14),
#  ('해', 14),
#  ('해서', 14),
#  ('웨이브', 13),
#  ('게', 13),
#  ('쿠폰', 13),
#  ('저', 13),
#  ('lt', 13),
#  ('것', 13),
#  ('진짜', 13),
#  ('내추럴', 13),
#  ('더', 12),
#  ('에도', 12),
#  ('~', 12),
#  ('1', 12),
#  ('개', 12),
#  ('지금', 12),
#  ('연휴', 12),
#  ('!!', 12),
#  ('gt', 12),
#  ('요', 12),
#  ('....', 11),
#  ('이용권', 11),
#  ('부터', 11),
#  ('오늘', 11),
#  ('때', 11),
#  ('걸', 11),
#  ('인', 11),
#  ('진정', 11),
#  ('령', 11),
#  ('라', 11),
#  ('ㅋ', 10),
#  ('다시', 10),
#  ('집', 10)]

# %%
# 불용어 : 인터넷 검색 시 검색 용어로 사용하지 않는 단어. 관사, 전치사, 조사, 접속사 등 검색 색인 단어로 의미가 없는 단어
stop_words = [')','?','1','"(', '_', ')/','\n','.',',', '<','!','(','(', '??','..', '4', '|', '>', '?(', '"…', '#', '&', '・', "']",'.',' ','/',"'",'’','”','“','·', '[','!','\n','·','‘','"','\n ',']',':','…',')','(','-', 'nan','가','요','답변','...','을','수','에','질문','제','를','이','도',
                      '좋','1','는','로','으로','2','것','은','다',',','니다','대','들',
                      '2017','들','데','..','의','때','겠','고','게','네요','한','일','할',
                      '10','?','하는','06','주','려고','인데','거','좀','는데','~','ㅎㅎ',
                      '하나','이상','20','뭐','까','있는','잘','습니다','다면','했','주려',
                      '지','있','못','후','중','줄','6','과','어떤','기본','!!',
                      '단어','라고','중요한','합','가요','....','보이','네','무지']

tokens_ko = [each_word for each_word in tokens_ko
             if each_word not in stop_words]

ko = nltk.Text(tokens_ko)
ko.vocab().most_common(100)
# Out:
# [('왓챠', 311),
#  ('에서', 65),
#  ('RT', 43),
#  ('나', 37),
#  ('넷플릭스', 37),
#  ('안', 36),
#  ('와', 34),
#  ('3일', 31),
#  ('영화', 30),
#  ('넷플', 30),
#  ('보고', 30),
#  (';', 29),
#  ('만', 27),
#  ('볼', 25),
#  ('@watcha_kr', 24),
#  ('까지', 23),
#  ('무료', 23),
#  ('추석', 22),
#  ('랑', 21),
#  ('아', 21),
#  ('그', 20),
#  ('시즌', 18),
#  ('하고', 18),
#  ('왜', 17),
#  ('전', 17),
#  ('내', 16),
#  ('#왓챠', 15),
#  ('추천', 15),
#  ('있는데', 15),
#  ('너무', 15),
#  ('ㅋㅋㅋ', 15),
#  ('언', 15),
#  ('드라마', 14),
#  ('해', 14),
#  ('해서', 14),
#  ('웨이브', 13),
#  ('쿠폰', 13),
#  ('저', 13),
#  ('lt', 13),
#  ('진짜', 13),
#  ('내추럴', 13),
#  ('더', 12),
#  ('에도', 12),
#  ('개', 12),
#  ('지금', 12),
#  ('연휴', 12),
#  ('gt', 12),
#  ('이용권', 11),
#  ('부터', 11),
#  ('오늘', 11),
#  ('걸', 11),
#  ('인', 11),
#  ('진정', 11),
#  ('령', 11),
#  ('라', 11),
#  ('ㅋ', 10),
#  ('다시', 10),
#  ('집', 10),
#  ('동안', 10),
#  ('사람', 10),
#  ('니', 9),
#  ('가입', 9),
#  ('적', 9),
#  ('넘', 9),
#  ('시간', 9),
#  ('가짜', 9),
#  ('사나이', 9),
#  ('오', 9),
#  ('작품', 9),
#  ('엔', 9),
#  ('느낌', 9),
#  ('ㅠㅠ', 9),
#  ('분', 8),
#  ('공개', 8),
#  ('같은', 8),
#  ('3', 8),
#  ('있어요', 8),
#  ('등', 8),
#  ('야', 8),
#  ('보는데', 8),
#  ('함', 8),
#  ('다른', 8),
#  ('정말', 7),
#  ('알', 7),
#  ('일단', 7),
#  ('함께', 7),
#  ('주인공', 7),
#  ('수입', 7),
#  ('화', 7),
#  ('결제', 7),
#  ('봐', 7),
#  ('했는데', 7),
#  ('고민', 7),
#  ('앱', 7),
#  ('난', 7),
#  ('왓차', 7),
#  ('근데', 7),
#  ('보기', 7),
#  ('한국', 6),
#  ('이나', 6)]

# %%
content_new=[]
for i in range(len(df)):
    content_new.append(str(df["content"][i]))
content_new[:1]
df["content_new"]=content_new

# %%
import re 
# '한글'을 제외한 다른 문자 모두 제거
remove_except_ko = re.compile(r"[^가-힣ㄱ-ㅎㅏ-ㅣ\\s|A-Za-z]")
def preprocess(text):
    text = re.sub(remove_except_ko,' ',text).strip()
    return text

df['clean_doc'] = df['content_new'].map(lambda x : preprocess(x))
df.head(5)
# Out:
#                       content                 content_new  \
# 0  @OLT_jeju: 왓챠에 9분만 투자해주세오.  @OLT_jeju: 왓챠에 9분만 투자해주세오.
# 1         단편에니메이션 “별이 빛나는 밤에”         단편에니메이션 “별이 빛나는 밤에”
# 2               나 이거 뒷북인지 몰라도               나 이거 뒷북인지 몰라도
# 3               한명이라도 더 보시라고.               한명이라도 더 보시라고.
# 4               정말 아름답고 따뜻하다.               정말 아름답고 따뜻하다.
#
#                   clean_doc
# 0  OLT jeju  왓챠에  분만 투자해주세오
# 1        단편에니메이션  별이 빛나는 밤에
# 2             나 이거 뒷북인지 몰라도
# 3              한명이라도 더 보시라고
# 4              정말 아름답고 따뜻하다

# %%
from konlpy.tag import Okt
m=Okt()

# %%
stop_word = [')','?','1','"(', '_', ')/','\n','.',',', '<','!','(','(', '??','..', '4', '|', '>', '?(', '"…', '#', '&', '・', "']",'.',' ','/',"'",'’','”','“','·', '[','!','\n','·','‘','"','\n ',']',
             ':','…',')','(','-', 'nan','가','요','답변','...','을','수','에','질문','제','를','이','도','좋','1','는','로','으로','2','것','은','다',',','니다','대','들',
            '2017','들','데','..','의','때','겠','고','게','네요','한','일','할','10','?','하는','06','주','려고','인데','거','좀','는데','~','ㅎㅎ',
             '하나','이상','20','뭐','까','있는','잘','습니다','다면','했','주려','지','있','못','후','중','줄','6','과','어떤','기본','!!',
             '단어','라고','중요한','합','가요','....','보이','네','무지','안녕하세요','께서','에서','이다','에게','으로','이랑','까지','부터','하다','습니다','https','com',')',
             '?','1','"(', '_', ')/','\n','.',',', '<','!','(','(', '??','..', '4', '|', '>', '?(', '"…', '#', 
             '&', '・', "']",'.',' ','/',"'",'’','”','“','·', '[','!','\n','·','‘','"','\n ',']',':','…',')',
             '(','-', 'nan','가','요','답변','...','을','수','에','질문','제','를','이','도',
             '좋','1','는','로','으로','2','것','은','다',',','니다','대','들',
             '2017','들','데','..','의','때','겠','고','게','네요','한','일','할',
             '10','?','하는','06','주','려고','인데','거','좀','는데','~','ㅎㅎ','때문','없어',
             '하나','이상','20','뭐','까','있는','잘','습니다','다면','했','주려','되어','하면','싶어서','미하','Name','FSNsL','했는데','먼저','이고','만에','읽혀','Ht','dtype','있다고밖엔','클리어','co','보다','않음',
             '지','있','못','후','중','줄','6','과','어떤','기본','!!','에서','나','만','안','아','라','왜','더','같지',
             '단어','라고','중요한','합','가요','....','보이','네','무지','께서','에서','이다','에게','으로','이랑','까지','부터','하다','습니다','https','com',
            '안녕','수목','이루어지','새로이','이것','비디오','컨텐츠','배경','이용권','배경','재밌','형식','웨이브','이벤트','결합','드디어',
             '근래','차일피일','wavve','우리','하세','oksus','끝나','코로나','모드','세포','보시','이야기','맞추','po','Name','작품','추석','빙상','준비',
             '언급','포함','많이','무료','보내','찾아오','부가','챙기','오늘','소비','진행','모든','oksusu','이미', '자기','관심','방송','서비스','통하','배우',
             '오랜만','스마트','모아','제공','챙기','시간','dtype','부가세','통하','오랜만','계시','소개','정말','아니','기웃거','따지','보리','진행하',
             '보내','이렇','안되','두고','끝나','다라','까먹','돌리'',ㅠㅠ,''남기','오랜만','안녕','유독','진행하','다음주','과의','아름','까먹','kcl','이렇',
             '진짜','쐐면','오진','그러','반하','정말','독하','금인','몸살','지나','미리','세사','abject','naver','다가오','그동안','나중','그렇','아쉽','이리',
             '여리','갈대','직무','바로','예방','보리','주사','독감','대통령','기준','돌리','요즘','얼마','미리','렌즈','갈대','아름','문제','결국','드디어','못하','하세','ㅠㅠ',
             'Length','tokens','ㅎㅎ','ㅋㅋㅋ','고르','그렇','평소','진짜','이후','다시','즐기','비교','높이','이렇','보통','object','챙기','기사','엄청','고민','vs','dtype','현재',
             '안녕','Name','알아보','바벨','바디','진행','여러분','와이','하자','그렇','어느','앳되','끝내','이런','해소','해보','직전','말하','얼마','질리','확인','울리','기다리','한지','누르',
             '빠지','궁금하','ㅠㅠ','요금','버튼','하기','경보','저번','저의','하세','크리','알아보','직전','오래되','일보','object','dtype','Name','Length','JJ','dtype','Name','squale','youtu',
             '그동안','length','Play','KIMU','object','net','그동안','ㅋㅋㅋ','status','hwanair','saintpain','andy','ndminialbum','weibo','twitter',
             'theqoo','XHhni','나의','안녕', 'tokens','KrXOnM','Length','대해','becici','Staff','이야','텐데요','궁금하셨을','MqlklfFGR','입니다','tfZee',
            'tFZee','해줘요','하신거라','정액', '풀어주세요','lunamoth','RT','걸려서','중딩','onj','이에요','rSWFad','에요','WGWorldCafe','nouk','만이','MAU','BUiAOYLWhN','HcozccBu',
            '야하는','에도','없어서','몰라도','이라도','분만','인지','싶은게','메이','기는데','할수','이나','해주세오','yitian','qZwRRnbj','민국','OLT']

stopPos = ['JKS','JKC','JKG','JKO','JKM','JKI','JKQ','JC','JX','EPH','EPT'
           ,'EPP','EFN','EFQ','EFO','EFA','EFI','EFR','ECE','ECS','ECD','ETN','ETD','XPN','XPV',
            'XSN','XSV','XSA','XR','SF','SE','SS','SP','SO','SW','OH','ON','UN','MAC',"NNB","NNM","VXV","VV"]
def token_mecab(text):
    text = m.pos(text)
    text = [i for i in text if len(i[0])>1]
    text = [i for i in text if i[0] not in stop_word]
    text = [i[0] for i in text if i[1] not in stopPos]
    return text

# %%
df.head(5)
# Out:
#                       content                 content_new  \
# 0  @OLT_jeju: 왓챠에 9분만 투자해주세오.  @OLT_jeju: 왓챠에 9분만 투자해주세오.
# 1         단편에니메이션 “별이 빛나는 밤에”         단편에니메이션 “별이 빛나는 밤에”
# 2               나 이거 뒷북인지 몰라도               나 이거 뒷북인지 몰라도
# 3               한명이라도 더 보시라고.               한명이라도 더 보시라고.
# 4               정말 아름답고 따뜻하다.               정말 아름답고 따뜻하다.
#
#                   clean_doc           tokens
# 0  OLT jeju  왓챠에  분만 투자해주세오  jeju 왓챠 투자 해주세오
# 1        단편에니메이션  별이 빛나는 밤에           단편 빛나는
# 2             나 이거 뒷북인지 몰라도               뒷북
# 3              한명이라도 더 보시라고
# 4              정말 아름답고 따뜻하다        아름답고 따뜻하다

# %%
# 토큰화 + 토큰리스트 생성 
def make_tokens(df):
    df['tokens'] = ''
    tokens_list=[]
    for i, row in df.iterrows():
        if i%10000==0:
            print(i,'/',len(df))
        token = token_mecab(df['clean_doc'][i])
        df['tokens'][i] = ' '.join(token)
    return df

# %%
df = make_tokens(df)
# Out:
# 0 / 475

# %%
df.head(3)
# Out:
#                       content                 content_new  \
# 0  @OLT_jeju: 왓챠에 9분만 투자해주세오.  @OLT_jeju: 왓챠에 9분만 투자해주세오.
# 1         단편에니메이션 “별이 빛나는 밤에”         단편에니메이션 “별이 빛나는 밤에”
# 2               나 이거 뒷북인지 몰라도               나 이거 뒷북인지 몰라도
#
#                   clean_doc      tokens
# 0  OLT jeju  왓챠에  분만 투자해주세오  jeju 왓챠 투자
# 1        단편에니메이션  별이 빛나는 밤에      단편 빛나는
# 2             나 이거 뒷북인지 몰라도          뒷북

# %%
tokenized_doc=df["tokens"].apply(lambda x: x.split());tokenized_doc
tokenized_docs=tokenized_doc.apply(lambda x : ' '.join ([item for item in x if item not in stop_word]))

# %%
type(tokenized_docs)
# Out:
# pandas.core.series.Series

# %%
from wordcloud import WordCloud

# %%
df["tokens"]
# Out:
# 0                jeju 왓챠 투자
# 1                    단편 빛나는
# 2                        뒷북
# 3
# 4                 아름답고 따뜻하다
#                ...
# 470             넷플 왓챠 보고 딱히
# 471    넷플 왓챠 영화 드라마 추천 해주세요
# 472     일단 장난스런 키스 없는 비밀 볼거
# 473        왓챠 나도 한자 나오키 볼거야
# 474           drywriting 왓챠
# Name: tokens, Length: 475, dtype: object

# %%
for i in range(len(df)):
    b=str(df['tokens'])

# %%
b
# Out:
# '0                jeju 왓챠 투자\n1                    단편 빛나는\n2                        뒷북\n3                          \n4                 아름답고 따뜻하다\n               ...         \n470             넷플 왓챠 보고 딱히\n471    넷플 왓챠 영화 드라마 추천 해주세요\n472     일단 장난스런 키스 없는 비밀 볼거\n473        왓챠 나도 한자 나오키 볼거야\n474           drywriting 왓챠\nName: tokens, Length: 475, dtype: object'

# %%
wordcloud = WordCloud(font_path='malgun.ttf',max_font_size=100,background_color='white').generate(b)

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(13,13))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)
