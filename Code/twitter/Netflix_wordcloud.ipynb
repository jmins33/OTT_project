# %% [markdown]
# ## 여기서부터

# %%
import pandas as pd
import numpy as np
from konlpy.tag import Okt
import nltk
m=Okt()

# %%
df=pd.read_csv('C:/Users/jminw/Desktop/media/twitternet.csv', encoding='CP949')

# %%
df.head(5)
# Out:
#                                              content
# 0                                        넷플 공포영화 추천좀
# 1                                             좀비 개조음
# 2                                        킹덤 이틀만에 클리어
# 3  솔까말...미하 수준이고, 이 정도로 바로 넷플 공개면 난 차기작 결제할 것 같지않...
# 4                      넷플 왓챠에 비하면 넘 기본이 안 되어 있다고밖엔..

# %%
okt_test = df['content']; okt_test
# Out:
# 0                                            넷플 공포영화 추천좀
# 1                                                 좀비 개조음
# 2                                            킹덤 이틀만에 클리어
# 3      솔까말...미하 수준이고, 이 정도로 바로 넷플 공개면 난 차기작 결제할 것 같지않...
# 4                          넷플 왓챠에 비하면 넘 기본이 안 되어 있다고밖엔..
#                              ...
# 748                                             보고싶은대...
# 749                                          이거하나 때문에...
# 750                  넷플 질러야하나?ㅠㅠ https://t.co/Ht6FSNsL7R
# 751    보건교사 안은영 넷플로 보기전에 책으로 먼저 읽고 싶어서 충동구매했는데...모야 생...
# 752                                  안은영 재밋나여 여새 넷플 볼게없어
# Name: content, Length: 753, dtype: object

# %%
okt_list = okt_test.values.tolist()

print(len(okt_list))
okt_list
# Out:
# 753
# ['넷플 공포영화 추천좀',
#  '좀비 개조음',
#  '킹덤 이틀만에 클리어',
#  '솔까말...미하 수준이고, 이 정도로 바로 넷플 공개면 난 차기작 결제할 것 같지않음. 넷플 정기결제인지라(...)',
#  '넷플 왓챠에 비하면 넘 기본이 안 되어 있다고밖엔..',
#  '애플,디즈니,HBO맥스 국내 진출 준비 https://t.co/psuP63YJsK',
#  '곧 넷플에 있는 워너IP들도 다 내리겠네.....;;;;;',
#  'OTT가 너무 많아지는 거 아냐?',
#  '넷플은 만화읍냐',
#  '@cafe_yotsuba HBO에서 제작한거라 넷플엔 안올라 올 듯 하고 저는 웹하드에서 다운 받아 봤어요',
#  '부산에 왔지만 집 밖에 나가지 않는 이시국 집콕러',
#  '나 왜 부산왔더라? ㅋㅋ 넷플이나 봐야지ㅋㅋ https://t.co/COCVJfiGiU',
#  '보고싶은대...',
#  '이거하나 때문에...',
#  '넷플 질러야하나?ㅠㅠ https://t.co/Ht6FSNsL7R',
#  '보건교사 안은영 넷플로 보기전에 책으로 먼저 읽고 싶어서 충동구매했는데...모야 생각보다 잘 읽혀...!! 너무조차나...?? https://t.co/KrXOnM8q58',
#  '안은엳 재밋나여 여새 넷플 볼게없어',
#  '넷플도 없어서 비숲도 못 본단 말여ㅠ',
#  '넷플에서 파우다:혼돈 보는중인데 .. 순교자 많이 나오던데 ..',
#  '넷플에서 래치드 주행 시작했는데 벌써 맘에 든다 화면 구성 컬러감 하며 배우들 소재 까지 .... 간만에 볼만한 게 생겨서 너무 조음',
#  '넷플 끊고 왓챠로 갈까봐 넷플에 없는 한드 사극 많네 독립영화도 많고 2주 무료로 보고 있는데 탐색하면서 이게 있다고?? 연발 중 ㅋㅋㅋㅋㅋ',
#  '#본사람_다하기',
#  '이름: 남구',
#  '나이: 99년생',
#  '키: 157',
#  '몸무게: 43',
#  '통장 잔고: 십만엔',
#  '지갑 잔고: 백엔',
#  '거주지: 도쿄',
#  '폰 기종: 사과폰',
#  '취미: 넷플 보기',
#  '직업: 유학생 겸 매국클로 스탭',
#  '부란당 넷플파티 있었구나... 재미있었겠다...',
#  '아니 그땐 분명 손절한 이유가 있었을텐데 소장할 정도까진 아니라고 생각했을 거란 말이지 ㅜㅠㅋ 근데 넷플로 도깨비 다시보기 하는데 재밌네 재밌어 불쾌한 골짜기 같은데 재밌긴 해',
#  '아놔 넷플 봤으니 끝난 줄 알았는데 유튜브는 인터뷰에 비하인드에 난리났...',
#  '&lt;보건교사 안은영&gt; 넷플 드라마. 원작은 안 읽어보고 봤는데 1, 2편만 영화로 만들었으면 딱 좋은 느낌이었고, 3편~6편은 다음 시즌을 위한 복선을 보여주는 이야기였을텐데 전개가 불친절해서 그래서 대체 그… https://t.co/8IcgOECm3d',
#  '일본 넷플에 있습니다?',
#  '@stellajoon912 저도 원래 넷플로 보는데 오늘만 tv로 ..',
#  '뜨면 바로 보셔요',
#  '여러분 넷플 시작하시는 분들 주변에 있으시다면 이건 제가 권해드리는 리스트입니다.',
#  '여기서 하나라도 재밌게 보시면, 다 재밌데 보실',
#  '아 Umbrella Academy 깜빡했다. https://t.co/iW5f2YNWTz',
#  '@_kook2_W 동재,,,, 정답을 말해조.....',
#  '힛 넷플로 달려갑니다아',
#  '나나님 굿뱀??',
#  '@harunobear 꺄악 넷플 달려갑니닼ㅋㅋㅋ',
#  '서검사님때매 본방사수함 휴우~~~글두 비숲은 넷플 자막버전이 최고!! 다시 봐야지~~',
#  '비숲 10시에 시작하는 줄 알고 13화 9시에 시작했는데,,하,,넷플에 뜨려면 11시까지 기다려야 하고,,1시간 뜨는거 넘 고통이야,,!!!!',
#  '넷플릭스 &lt;플레이북: 게임의 법칙&gt; 추천. 스포츠 감독들이 말하는 자신들만의 ‘Rule’에 대한 이야기. 모리뉴 편부터 봤는데 꼭 스포츠가 아닌 대부분 조직에도 적용될만한 이야기가 많아서 좋았다. 대단한 팀… https://t.co/nTSOGDyfg6',
#  '보는 작품마다 은은하게 사라폴슨 자주 나오네... 넷플에서 요번에 나온것도 봐야하는디',
#  '넷플에 오페라의 떼쟁이하네',
#  '노래잘한다',
#  '지금 저녁 먹으며 랜선 회식 켜서 이번엔 진짜 밥먹으며 인라 보는데... 진짜 내가 넷플이라면 이런 느낌일까 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 짝궁엔터회식아니라 그냥 넷플감상ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '잼는..왓챠나..넷플 영화 추천해주실분..?',
#  '저도 추천해드리겠어요',
#  '다이버전트-얼리전트(??)-인서전트 시리즈작 넘 잼써용...여성서사...',
#  '글구 진격거..정말 잼써요...',
#  '@H_Summer_66 왕 나도 유튭이랑 넷플은되는데 브이앱은 모르겟당',
#  '주먹왕랄프를 방금 넷플로 봤는데',
#  '그냥 동화가 아니라 레디플레이어원같은 옛날게임 많이하던 키덜트용 영화였네',
#  'RT @zz_sewoon: 미친 넷플에 정새운 검색하면 폰요 나와ㅋㅋㅋㅋㅋ 기절 https://t.co/uaIYcfwXoK',
#  '@rabbit_cat__ 그건...뭐죠? 추석지나고 넷플 정주행할예정 추석담날 출근했다가',
#  '탐라에 안은영 넘쳐나는데 넷플 없어서 못본다.??',
#  '@momocathy 넷플 올라왔어?',
#  '넷플 보건교사 안은영 드라마 재밋어서 책사러갈라구 https://t.co/cKs3VRqJyR',
#  'RT @Bookistak: 보건교사 안은영 넷플에 풀리기를 막 고대하고 있었는데 막상 풀리고 나니 아끼느라 못 보고 있다. 특별히 괴로운 어떤 날 스스로에게 선물하듯이 봐야지.',
#  '도은씨랑 넷플이 만나서 레즈물을 찍어야한다 이거야',
#  '넷플 안은영 3화까지 봤는데 재밌다 별로라는 평이 많아서 걱정했는데 사건을 에피소드별로 끊지 않고 서로 물려서 진행되는 게 처음엔 이상했는데 2화 지나면서 자연스럽게 녹아드는 듯 다음화로 계속 보게 되는 효과도 있고 아 음악이 진짜 좋다ㅋㅋ',
#  '윈도우 업데이트 했는데 다시 엣지 소리 출력 설정 제대로 작동한다!',
#  '더이상 엣지로  넷플  볼 때 모든 출력을 스피커에서 티비로 바꿀 필요가 없어!',
#  '안은영은 넷플 오리지널이니까 느긋하게 봐야지',
#  '아니 진짜 넷플 볼 리스트 너무 많은데 이거부터 봐야할듯 ;;; https://t.co/Y2Bm5HeKbC',
#  '하루종일 넷플 봐야지 추천 받아욥',
#  '내가 조만간 넷플을 끊든 티비를 사든 결단을 내고야 말겠네. 티비 사는 건 너무 극단적인 것도 갖고ㅋㅋ',
#  '@daddyispsycho 넷플 보건교사 안은영에 나오더라구요 &gt;_&lt; 훈훈',
#  '간만에 넷플 돌아간 김에 천성장가 시작',
#  '@JinseoYul 저 ㅋㅋ 어제 가족이 넷플본대서 가족거로 한달결제 하려다가 .,실수로 제계정으로 프리미엄 결제 한달치 재개 해버렷는데 제가 넷플을 안봐서 ㅠㅠ 개인정보문제만 아녓다면 맘만같아선 드리고싶네여 흐흑 넘아까워',
#  '아놔 넷플 보는데 갑자기 아빠 내려와서 강제로 취침...하게 됨...',
#  '@0ra1Yggz7CxNfgI 이거 넷플에 드라마도 잇음 ㅋㅋ 개재밋어요',
#  '아무래도 결맞는대로 탐라가 구성돼 있을 확율커 어떤컨텐츠 유행하면 영향받게 마련.',
#  '그러나 난 그간 정세랑,정유미,이경미(비밀은없다 꽤 재밌게 봤지만 미스홍당무는 영원히 이해할수 없을듯;;)님들 좋아하지않아… https://t.co/G80EMQudg6',
#  '@zz_kk_pp +넷플',
#  '다들 노는 언니들 보세요 넷플에 있어요 개꿀잼임 여자들만 나옴 개멋있는 언니들 가득',
#  '헐.... 리제로 2기에 사테라 나옴?나옴???나옿ㅁ??????????',
#  '넷플 ㅈㅂ 빨리 2기 내주세요',
#  'RT @s_harukze: 넷플 멍청이들아 왜 에놀라 홈즈의 옆에 레이디 세실리를 빼고 거기에 남캐넣어둔거야 바보들 공식 원작소설이 다 떠먹여주는서사를 너네가 발로찼다 어휴 어휴',
#  '할머니 위독하신데 아무생각이 없다',
#  '하루종일 넷플이나 봄',
#  '오늘부터 넷플 정주행 할라 했는데 컴이 고장나서 암것도 못해 https://t.co/VQguLSlcHX',
#  '@newmadeID 헐헐럴ㄹ 그거 탐라에서 많이 보여서 보고 싳엏는데ㅠㅠㅠㅠ넷플 사면 꼭 봐야겠어요...!!!!',
#  '@rkdeksdl 왓차가 더 볼꺼많은듯 넷플보다',
#  '시험 끝나면.... 엄브아카보고 미뤄뒀던 넷플 보고 롭톰하고 데바데하고 할나 마져 하고... 아이파드 사고.. 컴도 새로 맞추고... 돈만 있으면...',
#  '오랜만에 제대로 영화랑 드라마 다 보고 있는 느낌! 넷플에 새로 뜬게 많아서! ㅋㅋㅋ 오늘은 계속 영화 드라마 보다가 일찍 기절해야겠군!',
#  '넷플 멍청이들아 왜 에놀라 홈즈의 옆에 레이디 세실리를 빼고 거기에 남캐넣어둔거야 바보들 공식 원작소설이 다 떠먹여주는서사를 너네가 발로찼다 어휴 어휴',
#  '바보같은 넷플릭스...몽총이 넷플...',
#  '@newmadeID 꺅ㄱ???? 헐 넷플 짱부러워요,, 넷플이 없는 사람은 웁니다 흑흑ㄱ????',
#  '@yuh0601 엌ㅋㅋㅋㅋ 설마 넷플의 토미 신작인가욬ㅋㅋㅋㅋㅋㅋ',
#  '우리는 그 소리 마저 들을수 없기 때문이죠 넷플자막 겁나 좋은것...ㅠㅠㅠㅠ https://t.co/CR2gqmj7mz',
#  '넷플 왓챠 아마존프라임 웨이브 라프텔까지 구독하고 있는데, 신작 편 수야 말로 플랫폼 전쟁의 핵심인 듯하다. 작품당 퀄은 아마존이 더 낫지 않나 싶은데 매주 무식한 수의 신작이 쏟아져 들어오는 넷플릭스가 너… https://t.co/I3GDnYHlJv',
#  '보건교사 안은영 넷플에 풀리기를 막 고대하고 있었는데 막상 풀리고 나니 아끼느라 못 보고 있다. 특별히 괴로운 어떤 날 스스로에게 선물하듯이 봐야지.',
#  '저민? 김저민? 저스틴 민? 궁금해서 찾아보니 넷플 시리즈에 출연 중인 한국계 배우로구나. 훈훈하다 훈훈해. 그에 대한 누군가의 평가 중에 진지한 개구쟁이라는 말이 좋다. 가족에게 친근한 사람들, 마비조도… https://t.co/NXtOBDtgKr',
#  '재미있어.',
#  '책 읽다가 낮잠 시간 놓칠만큼.',
#  '어서 읽고 넷플로 슝 달려갈테다. https://t.co/dxKeActNQ9',
#  'RT @marisgoto: 고등학교 동창커플이었던 두 노인.',
#  '40년동안 일생을 함께했는데, 레즈비언이라는 이유만으로 서로의 생사도 확인 못하고, 재산도 모두 빼앗기고 죽었다. ',
#  '같은 상황인데 넷플의 시크릿러브의  레즈커플은 모두의 축복속에 결혼하고…',
#  '나도 보건교사 안은영 보고싶다ㅠㅠㅠ걍 지금 넷플 끊을까 어카지 중간고사 끝나고 끊으려고 했는데',
#  '아진짜 요즘엔 유튭도 진짜 볼거없네...겜개발사들 일안하냐..',
#  '겜스트리머들이 하는 겜들 다 내스탈아님 ㅠㅠㅠㅠㅠ...',
#  '진ㅉㅏ 결국엔 넷플로 갈아타야하냐구!!!',
#  '넷플 자꾸 메인배너에 호오츠키의 냉철..인가를 띄워놈 사람 씹덕만드네',
#  '동기칭구 중드본다길래 ㅈㅈㄹ추천해주고 그 친구 이번엨ㅋㅋㅋㅋㅋㅋㅋㅋ 상견니에 빠졌나봐 시백우랑 허광한사진찾아보면서 나보여줌ㅋㅋㅋㅋㅋㅋㅋ 왕2ㅂ나온 베니도세계지전인가 그거봤다고하더라 심지어 선풍소녀도앎....… https://t.co/ZszMCTeKIG',
#  'RT @SweetJJ_bjd: - 편의점 안 갈래? 같이 가주면 포나가 아이스크림 쏜다( ?? )/??',
#  '주말의 시작은 언제나 편의점과 함께!',
#  '야식거리 잔뜩 사들고 룰루랄라?? 돌아와서 넷플과 함께 끝내주는 주말을 보낼 거라네요?? https://t.co…',
#  '넷플 새로운 로그인 알림이 와서 계정 공유하는 친구A한테 물어본다는 게 카톡방을 잘못 찾아 친구B에게 말걸음. 작은 실수를 계기로 근황을 좀 나눴다. 실없는 대화는 좋은 거지. 뭐 이런 게 다 그립냐ㅜㅜㅜㅜ https://t.co/sDif4rmJ6r',
#  '넷플 보던거 다 봐서 볼거 없는데 엄브렐라 아카데미 한번 볼까',
#  '탐라에 계속 뜨니까 궁금하네',
#  '주말의 시작은 언제나 편의점과 함께!',
#  '야식거리 잔뜩 사들고 룰루랄라?? 돌아와서 넷플과 함께 끝내주는 주말을 보낼 거라네요?? https://t.co…',
#  '넷플을 끊을수가 없다니까 ㅋㅋㅋ 정유미는 최고고 젤리들은 너무 귀엽다!!!! #넷플릭스 https://t.co/tZxWbq4sLE',
#  '왓챠 이번에 끝나면 넷플로 다시 이사갈까...',
#  '전 넷플 힐하우스의 유령 잼깨 봤어요',
#  '티비를 거의 비지엠으로 틀어 놓는 인간인데 안은영때매 넷플을 결제해야하나 고민중.... 딱 그것만 보구 안 볼거 같은데....',
#  '안은영 보고 싶어서 넷플 다시 가입해야하나고민중',
#  '@sundkiz 아몬가 넷플은 하나보고 나면 다른하나 볼게 없아서(ㅋㅋㅋㅋㅋㅋㅋ) 넷플에서 봐야할 목록 오십가지 적어놓고 존버 한담 결제햐야겟어요 ㅋㅋㅋ 하 근데 폴라듀 신작 넷플에 뜨면 당장 다시 구독할랴요;(뮤트 갓은 영화 말고요...)',
#  '보건교사 안은영 책으로 읽다가 넷플 보러왔는뎅 재밌닼ㅋㅋㅋ 시선으로부터 작가님이라닝',
#  '@sundkiz 그렇다구 들엇읍니다..완준..거친행동에 그렇지 못헌 얼굴..ㅎ..;;;;;;;  후 저가..넷플 해지한지 꽤 되가지고..나중에 다시 결제할날이 오면 꼭 봐야지요 암;;;;암;;;(호록..쩝쩝쩝;;;)',
#  '한국에서 개봉해줘 ㅜ 안해줄꺼면 넷플에라도 빨리 풀어줘요 ㅜ https://t.co/KYk53OmWnJ',
#  '쓸디펜 유튜버 해보까 넷플 안은영 광고받았네 해보까쨩 적게 일하고 많이 벌어',
#  '@Leeif_ @sgoringgg 넷플보다 유툽 요약이 ?? 항마력 딸릴 땐요ㅋ',
#  '@Ddalgiuyuplease 넷플 오리지널이 장르에 따라 러닝타임이 다르군요 그것도 몰랐네요...!',
#  '@_gang_ja 어케 봐요 저 아무것도 없어요... 넷플, 왓챠, 웨이브 등등 아무것도 안됨...',
#  '넷플로 타이타닉 처음 봤는데',
#  'ㄹㅇㅠㅠㅠ 너무 명작이다',
#  '왜 타이타닉 타이타닉 하는지 이제 알았음',
#  '넷플 보건교사 안은영 풀로 보고 자서 그런지 악몽꿨다 꿈속기괴함',
#  '넷플로 드라마 2시간째 보는데 아직도 90퍼남음 ㅋㅋㅋㅋ',
#  '한국은 담백한 치유물이 없어서,,완성도는 좀 그랫지만 소재나 연출이 넷플이나 웹용 장르로는 괜찮아보였다 나츠메와 충사 팬으로서 요런 종류 좀더 나와줬으면 좋겠음 넷플측에서 씨지 엄청 욕하고 있대서...추가기획은 잘 모르겠다 에라이',
#  '티비가 커지니 집에서 넷플 볼 맛이 난다 https://t.co/aURWqnVadp',
#  '넷플엔 재밌는게 많은데 굳이굳이 그걸볼이유?',
#  '없다',
#  'RT @SweetJJ_bjd: - 편의점 안 갈래? 같이 가주면 포나가 아이스크림 쏜다( ?? )/??',
#  '주말의 시작은 언제나 편의점과 함께!',
#  '야식거리 잔뜩 사들고 룰루랄라?? 돌아와서 넷플과 함께 끝내주는 주말을 보낼 거라네요?? https://t.co…',
#  '안은영 엔딩크레딧 끝까지 봐야함 물론 1화는 읽을라고 끝까지 봤는데 2화부터 갑자기 대사가 나와서 넷플에서 엔딩크레딧에 이렇게 집중해서 보긴 또 처음이다 맨날 다음화로 바로 넘겼었지',
#  '사람들 만날 땐 좋은데.... 에너지를 다 써서 집에서 회복할 시간이 꼭꼭 필요한 호노카.... 머리 풀고 파자마 입고 침대에서 뒹굴거리며 순정만화, 소년만화 다 섭렵하고 넷플까지 보는 거 보고싶다.',
#  '주말의 시작은 언제나 편의점과 함께!',
#  '야식거리 잔뜩 사들고 룰루랄라?? 돌아와서 넷플과 함께 끝내주는 주말을 보낼 거라네요?? https://t.co/K9ehYhTOHl',
#  '@linnea009 욕심쟁이는 어쩔 수 없지.. 근디 넷플은 점점 하락세로 추락할거 같아요 ㅠㅠㅠㅠㅠ 디즈니가 넘 큰손이야 ㅠ',
#  '넷플에서 볼거많당 근대30일에 끝남ㅇ0ㅇ',
#  '@cotton_ss_usa 전 넷플 구독을 안하는 중이라 ㅎㅎㅎ 재밌으시면 꼭 후기 남겨주세요!!',
#  '@fuxxkki 넷플 솔직히 볼게 없어',
#  'RT @zi_pple: 엄브렐라아카데미2... ㅈㄴ 시기적절한 타이밍에 풀린듯 ㅋㅋㅋㅋㅋ 이보다 넷플 드라마가 흥할만한 타이밍은 없다...',
#  '@donquixote20000 시네마 천국!! 넷플에 없군요 흑흑 아쉽지만 ost를 유툽에서 듣는걸로 만족하겠습니다 ㅠㅠ',
#  '엄브렐라아카데미2... ㅈㄴ 시기적절한 타이밍에 풀린듯 ㅋㅋㅋㅋㅋ 이보다 넷플 드라마가 흥할만한 타이밍은 없다...',
#  '넷플에 닥터후좀 들어왔음 좋겠다 우는천사같은 옛날 띵작들 이젠 어디서 돈주고 보기도 힘들어',
#  '할로윈 오리지널 넷플에 뜬다고 ???????????????????????????????????????????????????????????????',
#  'RT @OLT_jeju: 넷플“소셜 딜레마”보았고.',
#  '드라마 체르노빌 보고난후의 감정을 느꼈다.',
#  '우린 이제 잣됐어 의 공포.',
#  '비관론에 빠지지말자 희망얘기하며 끝내지만..가능할까',
#  'Sns가 인간데이터화 상품으로 얼마나돈벌이에 혈안인지.지금 민주주의가 어떻…',
#  '호호호..영화를 안봤더니 내가 보려던 영화만 쏙쏙 없애버리는 넷플 인성...이아니라 내가 너무 안봤구나 ..크흑흑????',
#  'RT @Hailey07170919: 넷플 볼만한거 뭐있어요...?',
#  '넷플 볼만한거 뭐있어요...?',
#  '넷플에서 곧 내려간다길래 귀여운 여인을 허겁지겁 봤다. 30년이 돼 가는 유명한 히트작인데 그간 안 본 것도 머쓱하고 해서.. 그치만 마음이 안 가는 건 역시 이유가 있었다리?? 내 취향은 아니네..',
#  '이번분기는 넷플 애니 많이 하네',
#  '노는언니\'CP "김연경→김연아 초대하고파, 멤버중 예능캐는 정유인"[EN:인터뷰] | 다음 연예 https://t.co/DLwcYgGZVb',
#  '넷플에서 매주보는데 이거 왤케 재미지냐. 남자들 안나와서 더 재밌엉',
#  '보건교사 넷플에 올라왔네!!!!  주말에 달려보자~~♡♡',
#  '아슬프만 보려고 웨이브 결제하고...',
#  '시트콤만 보려고 넷플을 사야하고...',
#  '집에 올레TV쓰시는 모모님들은 이번에 올레랑 넷플이랑 계약해서 보건교사 안은영 티비로 크~게 보실 수 있어요! 기가지니도 완전 편하게 인식돼요!!!!',
#  '@YRK0116 저도 넷플만 가입해놓고 티비로 유튭이랑 같이 봄ㅎㅎ 븨앱도 연결 가능할거 같은데 안해봤고...',
#  '@Z9UThjdCfBqwEVj 안 그래도 엄마가 넷플 하나도 결제 안 시켜 주려고 하는데 죠필 다 깰려면 도대체 몇 개를 결제해야하는지ㅠㅠ',
#  '아니 진짜 죠필 깰려고 하면..',
#  '넷플만 끊어서 될 일이 아니구나..ㅋㅋㅋ',
#  '@gotmangjinchang 흠... 악마판사 방영하는 시기에 스드에서 다른 드라마들 뭐가 방영할지 모르겠지만 악마판사가 장르물이고 티벤 주드면 넷플 갈 가능성이 좀 있지 않을까요....?',
#  '넷플로 영화한편 봐야지',
#  'RT @forever_4_B: 넷플릭스 4인팟 분할 한자리 남았어요',
#  '오늘 결제라서 오늘부터 바로 보실 수 있어요',
#  '입금 칼같이 해주실 분, 그리고 오래하실분만 디엠주세요',
#  '#넷플릭스N빵 #넷플분할 #넷플쉐어 #넷플릭스 #넷플 #넷플4인 #넷플4인팟 #넷…',
#  '현재는 넷플만 씀. ',
#  '넷플 현 상황 : 은근 있는데, 은근 없어 https://t.co/Afkhfll6PU',
#  '50회차면... 총 몇 분 분량인지 아시는 새님 계시나요? 제가 넷플 오리지널 드라마를 본 적이 없어서...',
#  '아 넷플에 뜨는구나 넘 좋다',
#  '일단 소설 먼저 다시 읽고 넷플로 봐야할까 넷플보고 다시 소설을 읽을까. 너무 떨려',
#  '@Po_516 엇 넷플에 있었는데 사라졌나 보네요?',
#  '티빙이라는 다시 보기 앱에 있어요!',
#  'RT @Dal_Moon_Tsuki: 넷플에서 디즈니 관련 작품이 내려가는 이유를 알려드리겠습니다... 디즈니 플러스가 한국에 곧 들어오기 때문이죠. 이걸 제가 왜 아냐고요? 일본도 같은꼴 났거든요. https://t.co/weeLuAOnw6',
#  '빨리 다 끝나고 따뜻한 홍차에 우유타서 소파에 반쯤 컬터앉아 유툽이나 넷플에 볼거없나 고민하는 휴식을 갖고싶음',
#  '아싸! 티비로 넷플 볼수있다아 ',
#  '근데 뭐보지..?',
#  '선생님들 라프텔 볼만한가요? 넷플은 이제 단물이 다빠진거같아서...',
#  '어차피 넷플은 마음대로 볼수있으니까 펭귄 많이 나오는 장면만 골라 보는것도 좋은듯',
#  '@moroha_ddoing 넷플에 정말 온갖 듣보잡 일본애니가 전부 있고, 뭣보다 이누 극장판4개가 자막판으로 다 있으니까 할거 같긴한데... 역시 시기가 문제 아닐까요.. 개인적으로는 애니플러스가 이누야샤… https://t.co/fSTFpSQq0e',
#  '오오 넷플 오펀블랙 잼씀~~~~ 아직 시즌1이긴 하지만은~~~',
#  '@UZR1ox3Cz2YvZ2k 1번 진석니형이랑 아이스크림 키스를 하면서 껴안고 넷플보다 잠든다.',
#  '넷플이 왜 오리지날에 올인하겠어... 결국 스트리밍 시장은 자사 오리지날 컨텐츠가 얼마나 풍부한지에 따라 판가름 날 것.',
#  '@i_m_yours_____ 넷플엔 없는듯 ㅜ',
#  '헐 시즌 여러개 나오면 좋겟다 아직 하나두 못봤지만 재밋을거 같애! 보건교사 안은영 나오면 넷플 끊을라고~~~',
#  '9월 30일 넷플에 있는 디즈니 웬만한거 다 빠지니까 몰아보기...',
#  '@likeyou_jh 일본 넷플인가보네요~~^^ ㅋㅋㅋ',
#  '주말만 지나봐 내가 넷플 살려서 도장깨기 간다',
#  '드디어일본 넷플1위 했당  사불을 이기다니...ㅊㅋㅊㅋ',
#  '#박보검 #드라마청춘기록 #청춘기록박보검 #청춘기록사혜준 ',
#  '#청춘기록_박보검 #청춘기록_사혜준 https://t.co/rZqM8hiOb3',
#  'RT @tokyo_seoul_mom: 넷플에서 ‘거꾸로 가는 남자’를 봤다. 그곳은 여성우위사회인데, 청소작업원도 앱개발자도 잘 나가는 소설가도 공사장인부도 모두 여성이고, 남자는 캣콜링과 직장 성희롱을 쉴새 없이 당하며 체모제거 또한 남자 일이다.…',
#  '아 저거보니까 좀 넷플,다시 생각하게 되는데...',
#  '아이랑 넷플로 브레드이발소 보는데 블러 Coffee and TV 주인공이랑 넘 닮았다. 여튼 이 만화 재밌다. 오프닝 노래도 신나고~ 아이가 보기엔 약간 수준이 높은 거 같은데 내가 재밌어서ㅋㅋㅋㅋㅋㅋㅋㅋㅋ… https://t.co/XKLhaIhENA',
#  '넷플릭스 넷플 추천 카3 9월 30일 넷플 종료 ㅠㅠ ',
#  '추천합니다',
#  '내일부턴 헨리 얼굴 감상하러 넷플 n차를...',
#  '넷플에 있는 디즈니, 폭스 영화 대거 내려간다는거 같은데',
#  '엄마빠집 와서 티비로 넷플 보니까 신세계',
#  'RT) 디즈니 전용 OTT 아직 한국 진출 소식도 없는데 넷플에서 마블 다 빼면 이제 울적할 때 뭘 봐야하나ㅠ',
#  '@Myb0y_yh 넷플에도 잇긴 한데 1기 없을 걸',
#  '리제로 2기나 몰아서 볼까 -&gt; 1기 신편집판 넷플에 있네 복습하고 볼까 -&gt; 화질이 별로네 역시 블루레이 -&gt; 아 그냥 초기판 코멘터리 버전으로 볼까 -&gt; 현재',
#  '난 집에서도 티비 보는 시간이 아까워서 차라리 겜이나 홈트를 하거나 ',
#  '유튜브나 넷플을 볼만큼 티비를 안보는데 근데도 여기저기에서 트로트 프로가 난립하는건 알겠다',
#  '멜론차트에도 줄세우기 된 생소한 가수가 있어서… https://t.co/qbIiPBiFd5',
#  '이제 곧........24시간 뒤면 넷플 계정이 정지된다. 뭘 봐야 보람찰까나',
#  '@_versatile2 ㅋ ㅋㅋ ㅋㅋㅋㅋ ㅋㅋㅋ ㅋㅋ ㅋ 넷플 재밋네요 &gt;&lt;..',
#  '넷플릭스 4인팟 분할 한자리 남았어요',
#  '오늘 결제라서 오늘부터 바로 보실 수 있어요',
#  '입금 칼같이 해주실 분, 그리고 오래하실분만 디엠주세요',
#  '#넷플릭스N빵 #넷플분할 #넷플쉐어 #넷플릭스 #넷플 #넷플4인… https://t.co/8YMxSXW9Nc',
#  '와 엄마 넷플 창 들어가봣는데 애니메이션 단 1개도 안뜸 https://t.co/ejOchnVICQ',
#  '요새 친구가 넷플팟에 껴줘서 넷플을 룰기고 잇습니다',
#  '@JU_UN1 갱자나유 저도 적마 어쩌구저쩌구 하면서 반쯤 혼잣말 한거라서 ㅋㅋㅋㅋㅋㅋ 엄마가 영화보고 싶다고 하셔서 넷플 틀어드리고 침대에서 하이큐 봤어요 ㅋㅋㅋㅋㅋ 저야말로 말도 못하고 나가서 죄송하죠 ㅠ',
#  '@shit_bee_ @smero13 넷플에 에놀라 홈즈~~',
#  '@L24922643 넷플 보면서 게임하면서 맥주 먹으며 피자 먹는 삶 최고입니다',
#  '피자와 맥주와 넷플은 최고. 꽃페페로니와 감자 https://t.co/epFIch6NVg',
#  '넷플에서 봤는데 과몰입하는중.... https://t.co/ddCnlSMg5p',
#  'Barbarians라고 독일서 만든 토이토부르크 전투를 다룬 넷플 씨리즈라는데, 개띵작같음. (VPN은 필수일듯) https://t.co/N8YtyU4vU4',
#  '@BrightWin_0212 @BWisreallove 제발 유튜브로 봐쥬세요 ㅠㅠ 넷플로ㅠ정주행하려다가 첫 화 오역보고 그만둿어요...',
#  '@heaven_of_1981 깔깔깔 여중여고에는 홈친녀들이 많지요... 누가 넷플이나 왓챠로 틀면 다같이 보고...',
#  '@vyse__ 결제할려다가 넷플이랑 다르게 자막 붙박이가 많다고해서 일단 보류했음(....)',
#  '아 넷플 짱 기대된따 https://t.co/PhDH6SJAQN',
#  '대박 넷플에 레베카나오네',
#  '@_KIM_STOP_ 나는 넷플 프리미엄도 혼자 쓰는 솔로라네',
#  '넷플, 왓챠에 있는 작품 중에 스트레스 받아서 힐링하고 싶을 때 볼만한 영화 추천해주세요:-)',
#  '넷플 상단에 밀리 대문짝만하게 있는거 너무 좋음 말랑밀려 만천하에 알려~ https://t.co/NdM2Oe8u4F',
#  '왓챠랑 넷플에 오료 나오는거 뭐뭐 있을까요..왓챠 왜 배우 검색이 안돼????',
#  '집에서 넷플로 맨날 마약 다큐 봤었는데 부모님이 오해하실까봐 요즘은 그만둔...',
#  '@CindyRuby_ 위베베 넷플에도 시즌1 뿐이고 한국서 보기 너무 어려워요 ㅠㅜ',
#  '오늘 드뎌 에놀라홈즈 넷플에 올라왔다?? 근데 이거 시리즈물인 줄 알았더니 영화였네... 2시간짜리... 아껴봐야겠어ㅠ ',
#  'https://t.co/hiobSpfsCV',
#  'RT @SofieSunny12: 주말에 노는언니 넷플에서 재밌게깔깔거리면서 봤는데, 펜싱 남현희 선수에게 자꾸 "OO엄마" 라고 하는 거 신경쓰였다. 그녀가 아이의 엄마로서 세심하고 잘 신경쓰는 장점을 가지고 있다한들, 훌륭한 스포츠선수로써 마음껏…',
#  '아 미스터 하트도 넷플에 들어오넼ㅋㅋㅋㅋㅋㅋ',
#  '@jXxPT2Obu0jUay0 넷플짱이졐ㅋ 365 잼남.꼭보셈',
#  '하이큐 오랜만에 보니 존잼... 1화부터 보고 싶은데 넷플에 없네..? ㅠ',
#  '넷플 30일 체험하는데',
#  '작품 추천점!',
#  '현재 : 넷플 유튜브  왇챠(는 해지한지 2달쯤 됐음)',
#  '앞으로 들어오면 결제 할 것 : 디즈니플러스 애플티비 ',
#  '곧 할 것 : 아마존 프라임',
#  '@gpdkdkr ㅜㅠㅜㅜㅠ넷플에 있을지 모르겠어요.. 집에 소설도 없어서',
#  '나이제 넷플 꾸준히 볼꺼야 진짜그럴꺼야',
#  '엠토피아... 이거 주1회 공개인건가...넷플에 익숙해서 ㅋㅋㅋㅋ 에피 전부 공개 해줬으면',
#  '@D__O_love 마자여...넷플이 짱인',
#  'RT @Dal_Moon_Tsuki: 이런 희망을 가질 수 있다는게 부럽기만 한 엑스맨판 사람... 전에 영엑스맨들로 하이틴드라마 넷플에 올라왔다한분이 계셧는데 엑스맨판 사람들 다 그럴리가 없다고 확인도 안했던거 생각남. https://t.co/gUL…',
#  'RT @proana16859: 배고플 때 볼 만한 넷플 프로그램 ....',
#  '산타클라리타 다이어트(엽기좀비물)',
#  '워킹데드(좀비물)',
#  '종말의 세라프(인간의 추악함 풍자,액션)',
#  '문호 스트레이독스(판타지액션, 남주동료가 존잘)',
#  '도쿄구울(좀비물)',
#  '바이올렛 에버가든…',
#  'RT @Dal_Moon_Tsuki: 이런 희망을 가질 수 있다는게 부럽기만 한 엑스맨판 사람... 전에 영엑스맨들로 하이틴드라마 넷플에 올라왔다한분이 계셧는데 엑스맨판 사람들 다 그럴리가 없다고 확인도 안했던거 생각남.',
#  '그나마 넷플은 글에서 이걸 구라라고 밝히지 않아서 어떻게 그럴수도 있..나..?ㅋㅋ까진 되는데 저분은 글에서 리터칭인거 명시하고도 욕 먹은거라.. 글 좀 읽어',
#  '오늘 넷플에 에밀라홈즈 나온대??몇십년만에 볼 영화 생겼다&gt;&lt;',
#  '진격 초창기엔 에레리였던 모양인데 넷플 올라오고 백야이후 입덕한 이들은 에루리에 진심일수밖에 업음...물론 십꾸 에렌나오는 4기 이후는 짐작 못하겟음...ㅋ',
#  '스트리트 푸드파이터 넷플이나 뭐나 들어왔으면',
#  '이런 희망을 가질 수 있다는게 부럽기만 한 엑스맨판 사람... 전에 영엑스맨들로 하이틴드라마 넷플에 올라왔다한분이 계셧는데 엑스맨판 사람들 다 그럴리가 없다고 확인도 안했던거 생각남. https://t.co/gUL8TkZJVp',
#  '방금 넷플에서 쿠스코쿠스코를 봤는데 넘나 감동적... 쿠스코가 계속 배신하는데도 끝까지 믿어주는 파차가 너무 멋있었다..! 오랜만에 동심으로 돌아간 느낌ㅋㅋㅋㅋ 파차같은 사람이 되고 싶어???? https://t.co/WGXiRsywzt',
#  '@Squirrel__0218_ 넷플 추천해주세료...',
#  '@keemje2 오늘은 이따 넷플로 봐야겠어요??',
#  '@Dol_Eee_ 넷플이 없서요... 흑흑????????',
#  '@monie_108 좋아욬ㅌㅋㅋㅋㅋ그거 넷플에 있거든요? 저 넷플 보는데 그건 안봤잖아요............',
#  '@moone_da 힝구?????? 지금이라도 한달 무료 서비스 고고!!!! 아마존 프라임이나 넷플에 없는 영화 몇개 있어서 주말에 더 집에만 있을 것 같아요 ㅋㅋㅋㅋㅋ',
#  '넷플 미스아메리카나봅니다!!',
#  '@howbeautifullie 안 제가 제 돈으로 혼자 4인 넷플로 티비로 틀고 폰으로 틀고 했는데!! 뭐가 문제입니까!!',
#  '왓챠랑 넷플 끊는거 그렇게 고민하면서 길가다 타르트 2만원어치 사는건 고민도 안 했네요... ????',
#  '넷플이나 왓챠팟 할까 했는데... 그냥 혼자 쓸까 싶기도 해요... 근데 혼자 써도 화질차이 때문에 4인용 쓸 생각이에요',
#  '아 오늘 넷플 영화 보다가 혹시나 해서 ',
#  'BTS 쳤는데 2015 드림 콘서트가.. ㅋㅋㅋ',
#  '@howbeautifullie 왓챠랑 넷플 고민 중이었는뎁... 왓챠는 얼마에요??',
#  '한국어가 나오는 넷플과 왓차 프로그램, 팟캐스트, 공기가 통하는 곳-테라스나 옥상-에 놓인 사랑스러븐 내 화분들을 돌보는 잠깐잠깐의 시간이 나를 도와주고 있었구나아 새삼스럽네.',
#  '쾌적한 식물 공간을 만들… https://t.co/dPZGSDiNcr',
#  '넷플 말고도 왓챠도 파티 가능해졌네.,',
#  '@llllluckkkkky 우너님도 넷플의 늪에 오신걸 환영합니다?? 비숲도 꼭 보시고 미스터 선샤인도 봐주세요!!!!!!',
#  '다친 어린이가 심심해해서 넷플 구경하다 주디 갈란드 나오는 오즈의 마법사를 보고 있다. 나도 제대로 보는 건 첨인데 재밌네.',
#  '배고플 때 볼 만한 넷플 프로그램 ....',
#  '산타클라리타 다이어트(엽기좀비물)',
#  '워킹데드(좀비물)',
#  '종말의 세라프(인간의 추악함 풍자,액션)',
#  '문호 스트레이독스(판타지액션, 남주동료가 존잘)',
#  '도쿄구울(좀비물)',
#  '오직 넷플을 위한 용도면 성공적=나',
#  '다양한걸 시도하기엔...그냥 스마트티비사십쇼(결론)',
#  '아..진짜 공유 차기작만을 기다려왔는데 .. 넷플..하아ㅏㅠㅠ https://t.co/IVzjVmvOVh',
#  '아아니 넷플 돈없어서 멤버십 더 안할건데',
#  '엄브렐라 아카데미 재밌자나..',
#  '꼭 이러더라 한참 볼거없어서 안보다가 꼭 이래..',
#  '김비서가 왜 이럴까 넷플에 떴길래 본다',
#  '+넷플... 너무 행복해ㅠㅠ 꿀같은 휴무 https://t.co/e5059yAQLr',
#  '일단',
#  '넷플 왓차 웨이브',
#  '스팀 *픽 유플레이 오리진 ',
#  '등',
#  '근데 게임불따나 영화드라마 불따 저걸로 정당화하는애들이 있나',
#  '@ezo_monga @karena139 연출이 제 취향이라니 좋아요 도전해보겠습니닼ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ넷플결제좀 해야지',
#  '@karena139 @ezo_monga 넷플 결제 끊은지 오래인데...아 근데 2부까지 못버티면 3부부터 보라고는 하더라구요',
#  '보건교사 안은영 당연히 지금 공개 되어 있는 상태라고 생각했는데 25일에 공개라고?',
#  '저거 광고 처음 본 게 꽤 오래전이라 넷플에서 공개예정에 있는 거 보고 시즌2가 벌써 나올리는 없고 시즌 1 반절 반절 분할해서 공개하나보다.. 했는데',
#  '넷플 볼거 추천받음',
#  '극장판보다 넷플에서보는 외전이더좋다',
#  '@BB0_tto 헉 넷플에서 고민 중인 거 맞아요!! 혹시 재밌게 보신 영화 중 추천해 주실 만한 거 있으신가요!',
#  '경녀 시발 진짜 내가 몇년전에 봤는데 미쳐버릴 것 같았음 일단 작품 분위기는 진지한 스포츠물인데 설정 자체가 너무 괴랄해서 사람들이 다들 개그물로 착각하는 애니 중 하나이긴 한데 너무 끔찍했음. 경녀 전 1… https://t.co/oh2ndCjfro',
#  'RT @meunghaejun6: 아 진짜 머겜 이젠 슬슬 넷플에',
#  '들어오는 척이라도 해라',
#  '좀 사 돈 좀 제대로 써 넷플',
#  '왓챠야 걍 너가 먼저 해라',
#  '독점해 머겜!!!!',
#  '@mklove6133 원래 넷플릭스 보는 용도였는데',
#  '올레티비에서 넷플 보게된 후로',
#  '완전 데코용 ㅋㅋㅋ',
#  '아 진짜 머겜 이젠 슬슬 넷플에',
#  '들어오는 척이라도 해라',
#  '좀 사 돈 좀 제대로 써 넷플',
#  '왓챠야 걍 너가 먼저 해라',
#  '독점해 머겜!!!!',
#  '@FMa_sex 유투브가 작은 화면 지원한다고 했는데 넷플도 되나보네요?',
#  'PMC더벙커 보는데... 이선균 나오자마자 대사씹힘.. ',
#  '뭔말이야 안들려 ㅅㅂ...',
#  '넷플처럼 자막이라도 주시오ㅠㅠ 으엉',
#  '@leviejzn 살아...있다니 ㅋㅋㅋㅋㅋ 무섭ㅋㅋㅋ 아 넷플은 모자이킄ㅋㅋㅋㅋ 성의없이 하졐ㅋㅋㅋㅋ 맞아ㅋ 그거랑 별개로 라프텔은 좀 궁금하긴 하네얔ㅋㅋ 거긴 애니 주로 있는 곳이져?',
#  '저 이번주 보건교사 안은영 넷플 올라오면 피자시켜 먹으면서 볼꺼임',
#  '@yu_yu916 @dlwsnsjtnwl @junhospoppy 앍 넷플에 잇군여 한번 더 보러가야게따',
#  '@jindoldixon 넷플 공개예정일 보니까 걍 정상방영 같던데요 ㅋㅋㅋ',
#  '넷플 보다가 출석체크 까먹을 뻔.. 헤엑..',
#  '주말에 노는언니 넷플에서 재밌게깔깔거리면서 봤는데, 펜싱 남현희 선수에게 자꾸 "OO엄마" 라고 하는 거 신경쓰였다. 그녀가 아이의 엄마로서 세심하고 잘 신경쓰는 장점을 가지고 있다한들, 훌륭한 스포츠선수로… https://t.co/Jxx7s3xBz7',
#  '원래 자려했는데 아무 생각없이 콜라를 마셔서 잠이 깸,,,,,그런김에 넷플 추천 좀 해주라 다들??#섹트 #디엠 https://t.co/HtirdwTGw3',
#  '미쳤다......한낮의 유성 넷플로 보고 진짜 푹 빠져서 만화까지 정주행완료......',
#  '마무라 이 순정남,,,,,,미쳤냐구......엉엉',
#  '@h___ruu11 아니 이거... 일본 넷플에는 없나보다..',
#  '이게 2004년에 나온 건데 아직까지도 풀리지 않은 떡밥들이 있고 해석도 엄청 여러가지로 갈려!!',
#  '0.0mhz 도 재밌고 또 태국인가 거기 공포… https://t.co/gkKAilR2Ej',
#  '요근래 머겜 관심이 줄어듦',
#  '이럴 때 딱 다시 봐야하는데',
#  '티빙 결제하긴 싫단 말야',
#  '이미 넷플 왓챠 웨이브 자주 보지도',
#  '않는데 작품 몇개땜에 끊었단 말야',
#  '아엌ㅋㅋ넷플 끊기 전에 마지막으로 본게 &lt;라이트하우스&gt;였는데 이거 너무 공감ㅋㅋㅋㅋㅋ #리트윗',
#  'RT @inisoft: 원도에서는 엣지 맥에서는 사파리에서 화질도 좋고 용량도 적게머고 전력도 적게 씁니다. 넷플 말고 왓챠도 비슷하니 동영상은 OS만든데 브라우져 쓰셔야합니다. 유투브는 크롬이 좋기는 합니다.',
#  '헐 미친 냇플에 쿠스코쿠스코 잇네!!! 내 어린시절의 ... 적어도 50번은 본...! ㅋㅋㅋㅋㅋ',
#  '브로드처치 다 보고 비슷한 거라고 넷플이 추천해주는거 틀었는데, 어머 주인공이 같은 아저씨야 ㅎㅎㅎㅎ 헷갈리지 말아야지 ㅎㅎ',
#  '@taechi_x2_yaya 마자염 볼게 없어염...서구가 머 추천해줬는데..까먹었네염ㅋㅋㅋ 넷플..해지고민중이예여ㅋㅋ',
#  '원도에서는 엣지 맥에서는 사파리에서 화질도 좋고 용량도 적게머고 전력도 적게 씁니다. 넷플 말고 왓챠도 비슷하니 동영상은 OS만든데 브라우져 쓰셔야합니다. 유투브는 크롬이 좋기는 합니다. https://t.co/S9T18Cq8dI',
#  '넷플에서 정주행 할 드라마 새로 생겨따... 존잼 https://t.co/gjVdYyXGri',
#  '@Sweet_Kairos 넷플 결제를 해야하는가...',
#  '우부장때메 본방 안보고 자막 켜놓고 넷플로 보니까 훨 이해가 빨라',
#  '비숲2 탐라 반응이 심상치않다. 동재 이번에도 못나와??? 영영 못나와?? 동재살려내!!! ',
#  '(넷플로 보는 사람)',
#  '@LOVEYA_1013_ 헐 핝끼줍쇼 몇화에요 나 넷플 있어서 볼수있음',
#  '와 나 너무 흥분했어!좀 가라앉히고 넷플로 비숲봐야지',
#  '비숲 넷플 업ㅇ롣 10시밴이라는 얘기 듣고..',
#  '다음주 스타디 플랜을 짜고 머리감고 봐야딩',
#  '@Yasal_Daily 하 참고 참았던 넷플 가입을 해야하는 순간이왔나부다..',
#  '@soidrinkk 나 넷플 결제하려공',
#  '넷플로 어웨이 보는데 이거 중국돌려까기 디게하네 ㅋㅋ',
#  '@UZR1ox3Cz2YvZ2k 넷플에 스캄프랑스 시즌3 보세요! 존잘 2명이 쭈압쭈압',
#  '@anzinne @Heathen49 오늘은 토트넘경기 봐야 합니다.저도 비숲 넷플로 볼려구요!??',
#  '넷플에 하이스코어는 게임 좋아하는 사람들이면 정말 좋아하겠네 ㅎㅎㅎ 오락실에서 오락실게임기나 집에서 팩으로 게임 해본 사람들은 특히',
#  '아 너무 좋아',
#  'ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ',
#  '쵀빛 담배펴ㅠㅠㅜ 안되 폐안좋아져 피지마',
#  '아니야 담배펴 아니 피지마 아니 펴',
#  '아니 넷플 퀴즈? 졸귀여 저녜진ㅠㅠㅠㅜ',
#  '너무 웃어서 광대 아퍼ㅋㅋㅋㅋㅋ큐ㅠㅠㅜ',
#  '비숲 본방 끝나면 바로 넷플에 뜨나요?',
#  '진짜 .. 넷플 개국공신 아니냐... 크루들 첨에 인터넷 드라마?? 하는 상태였다는데 ㅋㅋㅋㅋ',
#  'RT @estellepark: 넷플 트랩트. 나 이거 왜 올 여름에 안 봤지ㅠㅠㅠㅠ 너무 재미있는데 눈에 갇힌 아이슬란드 도시 보니 시원시원. 눈보라. 고립된 마을. 살인. 인신매매. 부패한 관리. 사건 후 일지식으로 구성된 것도 너무 좋음??  ht…',
#  '@sseansun yeah 넷플에 1기 2기 모두 있어용~~',
#  '어제 넷플에서 힘을내요 미스터리 라는 영화를 봤는데... 너무 코믹하고 재밌게 보다가 막판에... ',
#  '대구지하철화재사건나오면서 짠하고 뭉클했다.  재밌음..보세요.!! https://t.co/xumKnhnqa5',
#  '@chaochaoschao 넷플에 잇서요',
#  '@simok_zo 저도요ㅠㅠㅠ 같이 넷플 달려요??',
#  '난 내가 넷플 끊은 며칠만에 새로 올라온 줄 알고 순간 설렜어…(；▽；)',
#  '넷플릭스 재팬에 하이로 들어왔다는 얘기 듣고 넷플 코리아 얘기 한건데 #리트윗 검색하다보니 한국에서도 하이로 워스트 볼 수 있다는 한국분 멘션이 보여 순간 텐션 올라간 것도 잠시..결국 넷플 재팬 얘기였다. 스핀오프 보게 해주세요…(；▽；)',
#  '넷플에잇을가요..? 잇엇르면좋겟다 https://t.co/vpNZHp9Ore',
#  '넷플에서 브로드처치 보는데 시즌1 정말 흥미진진하고 잼썼는데, 시즌2.. 아 물론 재밌지만 약간 발암? (이런말 쓰지 말랬는데 뭔가 대체어를 못 찾겠음) 승질나서 건너뛰기 하면서 봄. 재미없어서가 아니라 승질나서!!',
#  '언젠가 넷플파티 또 하고싶은데 생각하고 있는 것들..',
#  '생각1 처음 만나는 자유 (사유: 리투가 언급 ^-^)',
#  '생각2 금욜 시카리오1 토욜 시카리오2 이런식으로 연달아 보기 (사유: 시카리오2 디에고 캐시… https://t.co/8HVasRVUSX',
#  '동생이 넷플 혼자쓰길래 집이랑 나 추가시킴 https://t.co/Zpr6nJUuhp',
#  '중국에서 오래 살면 공산당이 좋아지나? ',
#  '트위터리안이라면 그럴 리 없음 트위터 쓰려고 vpn돈내고 우회하면서 내가 욕을 얼마나햇는데 카톡도 끊겨 유튭도 안되고 넷플도 안된다고 가끔 문퍄도 안열려tlqkf',
#  '앜ㅋㅋㅋㅋㅋ 넷플 인터뷰 너무 잘뽑아',
#  '넷플에 365 유명하다길래 켰다가 기분 나빠서 꺼버림..........이렇게 폭력적인거였다니',
#  '우와 이게 언제 넷플에 올라왓었냐. 예전에 하이텔에서 비디오 테잎 구해다 봤던게 기억난다. 예전엔 구할 방법이 없느니 저렇게 하이텔에서 비디오카피 업자한테 구해서 많이 봤는데. 지금은 뭐 원 클릭시대구나..… https://t.co/LpwwpmJWyr',
#  '넷플에 드레스 메이커 있었네?!!!!! 왜 이제 알려주고 난리야ㅠㅠ https://t.co/A64If8IBDp',
#  '이보리즘이랰ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 근데 난 이보를 검색해서 보는게 아니라 샤오잔 연관영상으로 뜨고 자동재생 되는걸 끄지 않았을 뿐.. 배니도는 안볼거야.. 근데 와 트위터고 왓챠고 넷플이고 유투브고 감시당하는 기분 오지게 만들어준다^^!!!',
#  '주술홰전냇플애 들여와주세요 제ㅏ발요 @ netflixkr',
#  '냇플이라거라고라고',
#  'RT @jeonsweet: 넷플 구독해지전까지 승ㄹ YG전ㅈ 내리라고 신고해도 계속 오픈이던데 선택적 피드백임?',
#  '아 뭐야 3기 2부 나왔었어? 넷플에 없길레 아직 제작ㅇ나한줄',
#  '@CHEEZE61719 헐 그거 저 넷플에서 봤었는데...!!?!?',
#  '왠진 모르겠지만 개봉한지 얼마나 됐다고 벌써부터 넷플에 살아있다가 올라와있길래 잠깐 보고있는데... 시작부터 뭔가 리얼의 느낌이 난다',
#  '넷플 비밀의숲2는 대체 몇시에 올라오는거니....',
#  '기다리고 있는데 안올라와 ㅜㅜㅜㅜ',
#  '오늘은 넷플로 킬링타임용 영화 A특공대 보는중ㅎㅎ 액션이 화려하군아ㅎㅎ',
#  '@searcherJ 그랬겠다~~ 넷플 올라오길 기다리는 중~~ 서동재 언제 찾는겨 ㅠㅠㅠㅠ',
#  '아침에는 긴즈버그 부고 소식을 접하고 잠시 생각에 잠기길, (일찍이 어른들이 말씀하시던) ‘인생은 짧다’라는 말이 급와닿았다. 그러면서 조금 전엔 넷플에서 라라진 이야기를 보고 있자니 20대 초반 생각이 나… https://t.co/ahpwBH7tBh',
#  '일드중에 그거 마더 보고 싶은데 왓챠에도 넷플에도 없어',
#  '@utaite_cha 아직 나도 멀 많이 안봐서 머가 내 취향인지 몰랔ㅋㅋㅋ 지금 넷플에서 본 드라마는 킹덤이랑 시그널...?? 밖에없섴ㅋㅋㅋ 추천해준거 함 바야겟당...!',
#  '@rowoon_807_love 응응 어플설치가 가능해서 유튭 넷플 다되더라고!!!',
#  '플스 원래 넷플 기기 아니었나요 (젼',
#  '넷플에 올라온 쥬월 백악기 어드벤처 재밋어ㅜㅜㅜ',
#  '@dont_find_somae 독살맞고 빈정대는 사라 아주 좋습니다... (빨리 집 가서 넷플 켜고 싶다...)',
#  '@HCTERB (맞다 발렌님 레쳇 보셨나여 빨리 봐야되는데 아직 넷플에 못 들어가봤어요 으아아)',
#  '요즘 넷플로 유니콘 다시 보고 있는데 제타도 보고 싶어지네ㅠ',
#  '@debbluvv 유툽이랑 넷플도 돼요????? 플스는 있지만 활용 못하는 1인이 되었네요 ㅜㅜㅠ',
#  '오늘 플스가 와서 실행히봤는데 우오오오~ 신세계다!!!!!!! 게임보다 젤맘에드는기능은 유튭이랑 넷플이 되는거!!!!!! 티비로 울애들 직캠틀어보니 극락이네?? https://t.co/6eNrd4WahU',
#  '@avantchina: 베이징판 첨밀밀이라고 해서 넷플서 본 영화&lt;먼 훗날 우리&gt;. 가벼운 맘으로 보려다 휴지 한 통을 다 써버리고 말았다.ㅠㅠ 인생에서 가장 힘들고 자존감이 바닥 칠 때 일생일대의 연인을 만난다는 건 축복인지 불행인지..아니면…',
#  '@leejade17 @5Ootak9 넷플에 보이프렌드치시고 넷플이 없으시면 유튭에 2gether the series라고 치심 한국자막으로도 볼수있으세용ㅎㅎ',
#  '@frui2store: 코로나 사태를 맞이하야... 줄줄이 캔슬되는 이유 1 :',
#  '제작이 미뤄지면, 배우, 제작진과의 계약기간을 연장해야 하는데, 그럴려면 돈을 줘야함. 계약해두었던 시설,장비 비용 역시 새로 지급해야하고...',
#  '알긴 아는데 AC…',
#  '존나 슬프지만 요즘 넷플 행보 보면 왠지 그럴 것 같았어 ㅠㅠ https://t.co/Z9pRH3HoPY',
#  '떡밥 넘쳐나러 울어 ㅠㅠㅠ 예능 나가고 인터뷰도 하고 넷플도 나오고 ㅠㅠ 이게 행덕 아니냐',
#  '틴에이지 바운티 헌터스 시즌2 캔슬이라니.... 그냥 전부 다 캔슬이네... 코로롱으로 넷플 성공했다지만 코로롱 때문에 컨텐츠 제작도 안되고 다음 시즌은 전부 캔슬 시키다가 컨텐츠 고갈로 아이러니하게 망하는 거 아니냐고',
#  '넷플은 이제 일본에는 니네는 딴짓 말고 애니메이션이나 만들어라 하는 노선으로 완전히 정한 듯. https://t.co/akof98O4sT',
#  '넷플 보디가드 보다가 단단히 감김 식이라고 생각안해봤는데 식임 ㅇㅇ 조졌다 RT @avantchina: 넷플 하나 보고오면 되겠나',
#  '@dreamlatte616: 넷플 다시보는데',
#  '소스 옴팡지게 챙겨 넣는 혜준 너무 귀여워',
#  '(마지막에 콜라도 챙겨감 ㅋㅋ) https://t.co/7jMdZVkwRS',
#  '@TOMNHEMS 어 넷플에 저는 왜 안뜨죠?? 다른 앱 들어가야되나요?',
#  '넷플 볼꺼  추천해줘용?',
#  '넷플이나 왓챠에 볼거 없나?',
#  '@Su_82_90 개봉 안 하면 깨끗하게 포기하고 넷플로 보는 건데 평일에 영화관까지 출근하려니 체력적으로 약간 부담되는 건 있지만 잘 만든 영화 같아서 기왕이면 스크린으로 빨리 보고 싶기도 하고 양가감정 드네요ㅋㅋㅋ',
#  '@Su_82_90 그렇게 말씀해 주셔서 감사해욬ㅋㅋㅋ큐ㅠㅠ상영관이 있긴 있어도 너무 한정적이죠ㅠㅠ그리고 아무리 넷플 공개라도 그렇지 에디 없는 포스터 달랑 1종...너무하긴 했음ㅠ',
#  '@xxx__8815 넷플!!',
#  '@wnF0g1Dm1TkIev4 넷플!',
#  '@:넷플 추천작: 도전 꽃들의 전쟁(쓸모없고 안예쁜걸 만드는데 재밋음..)',
#  '@chelsslee1: 넷플릭스 &lt;플레이북: 게임의 법칙&gt; 추천. 스포츠 감독들이 말하는 자신들만의 ‘Rule’에 대한 이야기. 모리뉴 편부터 봤는데 꼭 스포츠가 아닌 대부분 조직에도 적용될만한 이야기가 많아서 좋았다. 대단한 팀을 이끄는 대단…',
#  '@wi_n7 ㅎㅎ 보건교사 안은영 넷플에서만 봤는데 책도있군요',
#  '니노쿠니,,',
#  "넷플을 끊었지만 아직 도전못한 그',,,,,",
#  '@Bokkchi_ 대신 저랑 넷플 봐주고 재워줘야 됨요 ㅋㅎㅋㅎㅋㅎ',
#  '데어데블 사랑해서 넷플 생기자마자 우리 디디 보려고 넷플 가입하고 제시카 사랑해서 제존 다 보고 앗 디펜더스를 주신다구요? 루크케이지 다 달리고 아니 근데 아이언 피스트 주인공 인종이 뭐 어째? 아이언 피스… https://t.co/Mslb9Aid7z',
#  '트위터 당분간 안봐야겠다',
#  '비숲 넷플에 떠야 볼수있어서 아직 못봤는데 여기저기서 감상 스포 올라와서 슬슬 짜증남',
#  '하루의 마무리 같은 느낌으로 명탐정 코난과 짱구는 못말려를 시청하는 게 탱님의 취미라고 할까 일상의 힐링이라고 할까 아무튼 코난과 짱구를 다 보고나서 새로운 애니를 찾기 시작해서 넷플에 강철의 연금술사가 있… https://t.co/GyDumNwci8',
#  '@bts_megu613 아~ 넷플은 전부 같은 줄 알았어요. 비숲2 초반에는 조금 이해 안되는 것 같아도 중간부터 떡밥 다 수확하고 사건집중도 높아지니까 꼭 완주하세요!!',
#  '@bts_megu613 일본 넷플은 한국 방영 후 1시간 뒤 업데이트 아닌가요???',
#  '한국 넷플에는 들여오지 말아주세요. 여동생과 가족들이 람다 얼굴을 압니다ㅠㅠ',
#  '@HqRisa 넷플 지짜인생에 도움이 안되네',
#  '넷플 레베카 재밌겠다...뮤지컬도 대박이잖아..',
#  '디아니메 넷플 아마존보면 일단 한두개 빼곤 다 볼 수 있는데 최속하고 시간차 일주일 이상 나는것들 있으면 좀 그러니까 녹화 박긴함..',
#  '아자자 여기 넷플에도 담달 2일에 범블비 올라온다!!!!!????????',
#  '@below_milkyway 넷플은 캡쳐가 안됩니다... 그냥 사진을 찍어야해요 ㅎ',
#  '미키 사토시의 영화 드라마 좋아하는데 넷플에도 왓챠에도 별로 없어서 아쉽다. 있는건 거북이는 의외로 빨리 헤엄친다랑 시효경찰 정도....인스턴트 늪이랑 이타미의 수사관 다시 보고싶다',
#  '@shaminnnnnnn: "그다음... 넘버 식스! 죽었어 죽었어~"',
#  '넷플 공계가 트위터에 올려준 영상에는 대사가 여기까지만 나와서 심플하게 넘어가네 싶었는데 유튭 가서 봤더니 살벌한 다음 대사 도저히 우리말로 뉘앙스를 어떻게 살려야 할지…',
#  '아니야...넷플에 페어리테일 한판밖에없어서...아이마스신걸 볼려고...',
#  '학교괴담 넷플에 떴으면좋겠다',
#  '연휴내내 청소 빨래 당근 넷플 왓챠 몇 개 보고 나니 지나가버렸네. 영화보는게 (행복한)일이긴 하지.',
#  '@choijungwha: "한국이 만들고 세계가 열광합니다"',
#  '작년 넷플리스 대표의 이 말을 듣는 순간 "맞아!"',
#  '연휴때 넷플을 너무 많이봐서 인강을 보기 싫어졌다???? https://t.co/0gd1u4lSbL',
#  '@DARIM_1 전 뭐 넷플에 아직 안본 한드가 쌓인게 잔뜩이라 ㅎㅎㅎ',
#  '@live_in_april 넷플 구독할 이유가 없는건가요???',
#  '오 넷플 키니까 그레이아나토미 뜨는데 시즌이 15개나 되네 ㅋㅋ 어마어마한 드라마구나',
#  '요즘 드라마 넷플 한국어 자막 없으면 이해가 안된다고 ㅠㅠㅠ',
#  '한조 회장님 동재한테 마지막에 뭐라고 했냐고요ㅠㅠㅠ',
#  '넷플에서 강연금보는데 1~2기는 섬넬만 봐도 뭔내용인지 다 알겠고 3기부턴 가물가물하다가 4화는 기억 별로 안남.. 덕력 다죽었음',
#  '@290twins @eujlogiva @zootopia7777 어제 못본 비숲 오늘꺼까지 넷플 볼 생각으로 저 지금 옷방에 쳐박혀있어요 ㅋㅋㅋㅋㅋㅋ 버리려고 뺐다가 다시 넣고를 반복하며 ㅋㅋ',
#  '이제 마음의 여유가 좀 있어서 진정령을 보고 싶었는데.. 넷플에 없구나..나랑 인연이 아니야..??',
#  '넷플도 왜 배속이 안되냐 그레이 아나토미를 정주행 마무리 하는 날은 과연 오는가.......',
#  '@x_shinju 넷플에서 본게 위쳐밖에 없어서..',
#  '@Today_JUNi 넷플을 깔아야하나ㅜㅜ',
#  '넷플 파티 하기로 해놓구 이틀이나 까임 .. ㅠㅠㅠ',
#  '@_ra_wn 혹시 넷플 팟 구하셧나요? 한달만 보건교사 보고싶어서요ㅠㅠ',
#  '@Obr2019 넷플 보던거좀 보고옴',
#  '넷플 공계가 트위터에 올려준 영상에는 대사가 여기까지만 나와서 심플하게 넘어가네 싶었는데 유튭 가서 봤더니 살벌한 다음 대사 도저히 우리말로 뉘앙스를 어떻게 살려야 할지…',
#  '@HeeT_01 그래도 넷플로 볼 수 있으니까요! 괜찮습니다??',
#  '@HeeT_01 저는 오늘 넷플로 볼 것 같아요ㅠㅠㅠㅠ 막방은 본방으로 보고 싶었는데!!!!??',
#  '@blueblu79363717 @happyAmy10 나도 넷플에서 열심히 봤는데 짤로 모아 놓은거 보니 저 대사 뿐이구만요.ㅋㅋㅋㅋ',
#  '@_discreto19: 넷플 이탈리아 시리즈 베이비 로마 행사간 날. 차에서 내리는 오마르 엉덩이 찍어서 올린 아론 피페르ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 오늘부터 넷플!! :)',
#  '넷플 같이 볼 사람 없겠지..? 베이직할지 플미할지 고민되는디',
#  '엄브릿지 궁굼한데 넷플 한달만 끊을까..',
#  '@kind0320 라프텔 넷플 애니플러스 뭐해 태업하지마~~',
#  '다들 넷플 에놀라 홈즈 보세요...',
#  '내 첫사랑 핼레나 본 햄 카터님이 나오시고-분량은 적지만 존재감은 깊은...- 에놀라가 셜록을 한 방 먹입니다. 은근 액션로코재질. 연출은 단순합니다.  격투기 배우고 싶어지는 넷플영화!!',
#  '넷플 내 찜리스트에 안은영보다 신선한게 없어...',
#  '오늘 Ew들으면서 교보갔다가 와서 넷플 봐야지 #RM추천',
#  '넷플아.. 유녀전기 들여 올거면 극장판도 들여와...',
#  '설거지 했고 넷플 틀어놓고 테이블 세팅했고 덕복희만 오면 돼',
#  '헐 유녀전기가 넷플에???',
#  "@ediemdidi 겹추천이지만, 넷플에서 볼 수 있는 최고의 영화, '빅 피쉬'를 추천드립니다",
#  '인생이란 커피를 조금더 달게 마시는 법, 그리고 팀 버튼이 답하는 "왜 판타지인가?"',
#  '단연 최고의 판타지 영화… 수능끝나고 넷플 달릴 리스트에 추가해야디... 아우 원서접수하고 자소서 마감하고 명절지나니까 중간이네ㅋㅋㅋㅋㅋㅋㅋㅋ 진짜 현타 씨게 온다... 근데 4주 뒤에 면접... 음 인생... 진짜 다 끝나면 좀 하… https://t.co/KkDKbhC0MY',
#  '@auidapo 후후 시즌1 보신다고 하니까 제가 다 떨리고 설레네요! 저도 넷플로 봤는데 진짜 금방 호로록 봐버럈어용!! 오우 소셜딜레마?? 넷플 바로 본다',
#  '넷플보다 영화 딥디 소유 갯수가 많은 사람 예송..',
#  '@femi_dugi: @oooooung 저도 이걸 이제서야 안게 너무 황망해요ㅋㅋㅋㅋ',
#  '넷플에서 밀드래드 보는데 싸한장면이 한두개가 아니라서 찾아보니까.....다양하게 표절해서 고소건들이 좀 있더라구요...ㅎㅎ 다 기각됐다는데 돈으로 어케 막았나…',
#  '넷플 시리즈 하나씩 끝낼 때마다 오는 공허함이란 ..',
#  '12. 인생드라마 나의 아저씨  넷플로 보는 4시간 내내 울음',
#  '근데 한국 컨텐츠가 매력이 있는거야, 자기네 나라에 이런게 없는거야..?(ㅈㄴ...연애만 하고 감정과잉 캐(특히 남캐) 넘쳐나서 넷플로 갈아탄 한국인)',
#  '볼라했는데 지금 넷플 해지해놔서 시즌3뜨면 다시 할라고 해서 굉장히 애매한상태임 비숲은 넷플에서 봐야겠다',
#  '비숲 나만 안보나봐ㅜㅜ 10분후에 자동차극장 답사(?) 가야해서 꾹 참는 중 ㅜㅜㅜ 갔다와서 넷플로 봐야지!!!',
#  '안은영이 내가 본 넷플 시리즈 중에 제일 에피소드 갯수 적은 시리즈였음 ㅋㅋ 아무리 적어도 10화까진 있었는데..',
#  '근데 심지어 그 10화인 애니메이션도 결국 정리는 했지만 약간 급하다는 느낌을 받았었단말이지… https://t.co/OU9ugSMOIU',
#  '머야 먼소리야 이따 넷플 지막 켜고 다시 봐야돼? ㅠㅠ ? 아 그렇구나.. https://t.co/skjQMPC1Vf',
#  '@gogogreenms 그래도 끝까지 봤네 ㅋㅋㅋㅋ',
#  '한국 넷플 드라마는 결국 킹덤 유일천하 되는건가',
#  '#우리장르_입덕계기 ',
#  '히로아카) 우연히 유튭에서 마보로키를 보고 치여버림',
#  '진격거) 넷플에서 재미있는거 없나 뒤지다가 리바이의 미모에 입덕',
#  '귀칼) 친구의 영업때문에 넘어갔지만 그 친구는 탈덕...',
#  '@_MiserereNobis 네 맞습다 저는 넷플이 없어여 그래서 넷플민족이 너무 부러워여',
#  '그리고 틈새 더크젠틀리 홍보 넘 좋지만 넷플이 캔슬해버림...내 최애 드라마 더크젠틀리 시즌 2에서 완결남...떡밥 5조5억5만5천5개 남겨놓고',
#  '잉 야샤히메 오늘이었네 자느라 못봄 젠장… 넷플로 봐야겠군',
#  '그렇게 저는 넷플 비번 걸어놔도 채널을 하나 더 만들어 쓰는 딸로 자랐습니다 같이 쓰는 사람 평생 구하지 마라 https://t.co/0R1bPQTAHf',
#  '넷플에 캐롤 업뎃 안허냐 케이트 보고픙미...',
#  '넷플에서 에밀리, 파리에 가다 틀었는데 닥몽언니도 나오쟈나? 벌써 재밌네 이거 ',
#  '넷플로 슬의생 보는중인데 내 탭 연결해서 보는중이고 내 탭으로 범프 볼건데.... 어....',
#  '이번 주말에는 넷플 작작 보고 책 좀 읽어야지... 쓰면서도 왼쪽에 넷플 창 띄어놓은 집순이...??',
#  '버스 타고 나오는데 승객 3분의 1이 아주 곤하게 잠들었음. 그것도 같은 종대로 죽 이어서. 다들 어젯밤에 넷플 달리셨나.',
#  '여자들에게 추천하는 넷플 드라마 에밀리, 파리에 가다 https://t.co/aDAC03E91M',
#  '보건교사 안은영 2화까지 봤는데',
#  '나는 조금 실망했다',
#  '장르소설도 좋아하고 소재가 워낙 신선해서 소재에 대한 기대감만 가지고 봤는데 너무 젤리들에 집중한 느낌...',
#  '개인적으로 사람들만 나오는 장면에서 대사나 연… https://t.co/Sdcfkt09gq',
#  '@risingstar_0001 전 저렇게 슬픈거 좋아함. 나의 아저씨 넷플로 보는 4시간 내내 울면서 봄',
#  "폭음·폭식이라는 의미의 영어 단어 '빈지(Binge)'와 본다는 뜻의 '워치(Watch)'가 결합된 용어로, 단기간에 TV 프로그램 등 콘텐츠를 몰아서 보는 행위를 일컫는 신조어. 이번 추석기간 집콕에 왓챠… https://t.co/WWmhnry9U6",
#  '넷플에 트럼프 다큐 보는데 와...이 지독한 사업가 마인드 무슨R=VD같은 성공신화 책으로 읽는 느낌이다',
#  '어 네어비 웹툰 이거 넷플에서 애니화 된건가????????',
#  '넷플에 중판 꽃보다 남자 드라마는 매번 1화 보는 도중에 포기함ㅋㅋㅋㅋㅋㅋㅋㅋ 못보겠어 ㅋㅋㅋ',
#  '@Clear_92 넷플 결제하고 싶어용...ㅠㅠㅠㅠㅠ',
#  'RT @cha_Mill_: 넷플 2대 각성 https://t.co/EEQPAZ9SKF',
#  '@luv__s2____ 넷플 보기시작한지 얼마 안되서 그런데 추천해주실거 있나요..?',
#  '예전 드라마를 보려면 뭐가 좋아요? 넷플?',
#  '요즘 넷플로 고전애니보는데 너무 재밌다 진격의거인,원펀맨은 보고싶어서 봤고',
#  '블리치 어제다보고 이제 이누야사 극장판보는중ㅋㅋㅋ 시간순삭',
#  '@cha_Mill_: 넷플 2대 각성 https://t.co/EEQPAZ9SKF',
#  '좀따 수업 가려면 얼른 자야 하는디.. 넷플 볼까 고민 둥..??',
#  '@jamas95 아 그거 넷플? ㅋㅋㅋ',
#  '@L06130716 잼있어요? 요즘 볼게 없어서 넷플 안보고 있는데...',
#  '엄마한테 넷플에 애니도 있다고 했을 때 애니 끊었다고 하시더니 넷플 아이디 드리니까 애니 보고 잇슴',
#  '7. 최근 관심사',
#  '드라마...?',
#  '최근에 넷플 결제했음!!',
#  ' 청춘기록 박소담 나온다고 해서 봤는데',
#  '너무 재밋엉',
#  '@touchme_biteu 그나마 왓챠가 일드 많고 넷플은... 저는 볼 게 없더라고요ㅠㅠ 판권을 많이 사오길 바라는 사람이 되었습니다요',
#  'RT @cha_Mill_: 넷플 2대 각성 https://t.co/EEQPAZ9SKF',
#  '베이비 이 넓은 침대 위에,굳이 내 옆으로 굴러 와서 같은 베개 베고 눕네 ㅡㅡ 저리로 좀 가, 엄마도 밤에는 누워서 넷플로 보건교사 안은영 보고싶단 말야....앙앙 넘 재밌어',
#  '제대로 보지도 안/못하면서 넷플 유지중에 왓챠까지 지름. 파티원 있으니 저렴하기도 해서.. 리스트만 봐도 배부른 느낌이 있다;;',
#  '넷플 태국드라마 보이프렌드 추천하길래 틀어봄 남주가 시작부터 남녀노소에게 고백받네 역시 편견없는 나라다',
#  '@kikimevius 넷플',
#  '@wldbs8990 넷플 열나게 보능중 ㅋ',
#  '@405Riri 넷플은 드라마만봐서ㅠㅠㅠㅠ 영화를 추천드릴만한게 없네요ㅠㅠㅠㅠ',
#  '나도 비숲2 시작. 동생이 넷플 열어줌ㅋㅋ',
#  '어제 넷플 보건교사 안은영 보다가 2군데서 울어버렸다 너무 슬프잖아',
#  '근데 책이랑 다른 부분은 일부러 시즌2하려고 그런건가..? 마무리 안된 부분들이 뭔가 찝찝한디...',
#  '넷플 2대 각성 https://t.co/EEQPAZ9SKF',
#  '나는 서동요 장난이 재미가 없다. 속는것도 별로긴한데 나랑 상관없을때부터도 재미가 없었어서 싫어함. 넷플 낚시도 마찬가지. 진지 빨지 말라 할 수 있는데 이게 장난 치는 사람의 어조에 따라 웃자는거면 웃을수있는데 아닐땐 진짜 블락함',
#  '넷플 왓챠 티빙 웨이브 곧 디즈니플러스까지 ;;; 엔빵 진지하게 고민해봐야겠다',
#  '나도 검블유 보고 싶어?? 넷플에 올라오길 기다리고 있는데 과연 올라올까..',
#  '어머니랑 밤새면서 넷플으로 스파이더맨 보는중',
#  '어...엄브아카의 파이브라고? 응응..',
#  '어디서 보는데? 넷플?',
#  'Aㅏ...',
#  '아이패드는 동영상 재생기로 전락',
#  '아마존 프라임 일드는 자막(일어) 안넣어주네....... 넷플은 자막있으니 좋던데',
#  '@T4EK0920_ss 나 넷플로 그거 봄 ㅜㅠㅜㅜ 쥬나 웃겨 ㅜㅠㅠㅠㅠ',
#  '@TAKI_MNM 게임 안 하실땐... 넷플 &amp; 유투브 머신',
#  '@JANTE_LAW_ 래치드 어떠세용 넷플이고 여주에요 예뻐요 스릴러에요',
#  '나 원래도 ㅌㄹㅌ 싫어하는데 거실에서 엄마가 틀어서 방문도 못열고 넷플 하루종일 보고 있음. 여긴 지옥인가...',
#  '보건교사 안은영 책 다 읽었고 너무 재밌다! 넷플릭스로도 빨리 보고 싶은데 넷플 해지해버려서 다시 재가입해야 함.',
#  '#치아문난난적소시광 ',
#  '#우리의따뜻했던시절에게',
#  '번외편이 있을줄이야!!!',
#  '넷플에는 없고 wavve에는 있다!!',
#  '1.구웨이이와 쓰투모의 혼인신고서',
#  '2.집안일 다해야한다니깐 “그럼 넌?”',
#  '   “네 마누라” ㅋㅋ… ',
#  '아.. 생각보다 뮤지션 다큐가 많네 넷플에',
#  '넷플엔 또 이런게 있어? ',
#  '하루종일 넷플만 봣다 만료일이 다 됏거든... 흑흑',
#  '추석연휴때 망무 왕샤 몰아그리려고했는데',
#  '막상하는거 -&gt; 먹고 자고 누워서 넷플 웨이브 라프텔보기????',
#  '말랑말랑... 귀염귀염... 핑크핑크... 따뜻한데 괴랄하다...',
#  '넷플에서 잘하면 대박나겠다... 근데 마무리가 허술한듯...',
#  "오늘의 잡담은 사적인 이야기인데요?? '보건교사 안은영'을 너무 보고파서 금단으로 남겨 두었던 넷플릭스 무료체험을 시작했습니다 ㅎㅎ 연휴가 아직 3일이나 남았는데.. 다음으로 어떤 걸 볼 지 고민이에요. 혹시… ",
#  '연휴동안 해야하는 일과 하고 싶은 일이 많은데 가만히 누워있는 거 너무 좋아서 망했다. 질리지도 않고 좋네.. 넷플 보는 것보다도 더 좋음 흑',
#  '@s_k_e2002 넷플 이용 쌉가능여',
#  '@K_SIE_ 보신다고 넷플에 돈 더 나가는게 아니니 보셔야죠 (?)',
#  '저번 인스타스토리에 귀멸의칼날 얘기 나왔을 때 볼까말까 했는데 이렇게 또 언급하면 봐야지 뭐... 오빠 좋아하는건 나도 좋아할테야?? 넷플 티빙만 쓰는데 다행히 티빙에 있으니 원나블 덕후 경력으로 달려본다??',
#  '캡콤 일 진짜 열심히 하네 레지던트 이블 8편 낸것도 모자라 비슷한 시기에 넷플 독점 영화 예고편도 발표함 ;;;',
#  '넷플에 호텔델루나 들어오면 피뮤 왠지 ㅈ ㅣ은이 이야기 하는거 엄청 볼 수 잇을 것 갘은뎈ㅋㅋㅋ',
#  '헐 현생 꺼져 넷플 그아 정주행 간다',
#  '@jiki_0290 난 넷플 생겨버리면 조금의 현생도 그냥~ 날아가버릴 듯...',
#  '@Han_Nah_57 넷플이   없어요ㅠㅠ 슬푸네요...',
#  '@jeoqifyl 내일 출근이야ㅠㅠ 그냥 가서 넷플 보면서 노닥거리다 오려구ㅠ',
#  '넷플보다 볼건 많은데 ㅈㄴ 불편해졌어',
#  '넷플만 계속봐',
#  '@g5d990113 나 요즘 넷플보다 더 많이 보는 듯',
#  '오늘의 왓챠는 조지로메로 감독의 살아있는 시체들의 밤 입니다~ 연휴 끝나면 취소할듯.. 넷플만큼 매력은 없네',
#  '나 방에 누워서 넷플 보다가 유튭 보다가 하고 있는중에 거실에서는 나훈아 노래하는거 보고 있길래 아니 뭘 저런걸 보나 했는데 시청률 70프로...제가 헛 살았습니다 ㅠㅠ',
#  '저 넷플4인팟 성인인증 되어있고 여성분끼리 하는 곳에 끼워주세요 .. 지금 당장 바로 입금가능합니다 ,, ㅠ ㅁ ㅠ ',
#  '#넷플공유 #넷플분할 #넷플쉐어 #넷플공구 #넷플 #넷플4인 #넷플4인팟 #넷플릭스공유 #넷플릭스분할 #넷플릭스쉐어 #넷플릭스',
#  '탐라가 나훈아 콘으로 대동단결되었는데 난 넷플 보이프렌즈 재탕하고 있다니...트위터 중에서도 마이너냐;; n 년전에 늑대의 유혹 무인대신 돌려차기 무인갔던 내가 떠오르는군;',
#  '그나저나 나훈아 콘서트 낼 아침에 나올 시청률이 매우 궁금하군',
#  '지금부터 비밀의숲2 밀린거 넷플로 보다가 새벽에 류현진 야구로 갈아타고 아침에 나훈아 콘서트 시청률 확인해보면 되겠군 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ 긴 밤이 되겠군 ㅋㅋㅋㅋㅋㅋㅋ',
#  '넷플에 없는 영화 봐야지 ..',
#  '나만 안봤나 콘서트 ?!? ㅋㅋㅋㅋㅋ 난 보기 싫어 돌렸는데 진짜 다 재미없는거만해서 넷플 봤는뎅',
#  '넷플에서 보건교사 안은영 보고싶지만 지금 wavve쓰고있어서 못보기에 책을 샀다ㅋㅋㅋㅋㅋ 책 먼저 읽어야지ㅋㅋ',
#  '젠큐 보고싶어.. 넷플에 왜 안뜨냐... 우리나라에서 나오려면 20년은 걸릴려나..',
#  '하 보건교사 안은영 다 읽었다 이제 넷플볼차례.....',
#  '공중파 드라마, 넷플, 왓챠 아무 것도 안보는 난 그들의 대화에 참여할 수 없었다...그럼 뭐하고 지내냐며 묻길래 유툽본다고했더니 오히려 신기해함... 서로를 신기하게 여겼던 기이한 순간들',
#  '넷플 뭐 다 없어진다길래 왓챠 함 도전해봄 영화 ㅊㅊ 좀 해조바',
#  '10시즌쯤 가는 인기드라마 주연이 되면 더 좋겠어..ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 욕심폭발...ㅋㅋㅋㅋㅋㅋㅋㅋㅋ 넷플ㄹ ㅣㄱ스나 왓 ㅊ ㅑ에 한글자막으로 들어오는 걸로..',
#  '지금 일어낫는데 일어나자마자 냇플 예고 보고 우는 중 https://t.co/pNOugWWpTq',
#  'RT @kai_sun95: 넷플 한달 단기 4인팟 하실분',
#  '결제는 이미해서 오늘부터 한달입니다',
#  '넷플 한달 단기 4인팟 하실분',
#  '결제는 이미해서 오늘부터 한달입니다',
#  '@Eb_q55 넷플에서 볼수잇음',
#  '자꾸 넷플 메인에 타짜 뜨네 ㅋㅋㅋㅋ',
#  '증말 추석이야??',
#  '아마존 드라마들은 더 테러 1시즌과 SYFY에서 사들인 인스펜스를 제외하면 별로였는데 유토피아를 보면 시청자층을 넓게 잡은 넷플보다는 고퀄 드라마를 뽑아낼수 있을지도.',
#  '@amumalexs 헐 이거 넷플에 있었어? ㅋㅋㅋㅋㅋㅋㅋ 아 집에 가서 봐야지',
#  '라이프는 왜 넷플에 있는것입니까아ㅏㅏㅏ!! 승효도 보고 싶은뎅...',
#  '오늘 넷플 목록',
#  '프로포즈',
#  '헬프',
#  '죽은시인의사회',
#  '죽여줘!제니퍼',
#  '은하수를 여행하는 ~~',
#  '내가 널 사랑할 수 없는 ~~',
#  '@daopark 쌤 저도 기부천사이긴 마찬가지 입니다^^....껄껄 넷플은 오리지널만 보셔도 쏘굿..! 아니면 꼭 4명 팟을 구하셔요!!!',
#  '아침부터 피아노 소리로 일어나서',
#  '티비로 넷플 정주행하다가',
#  '이젠 지쳐서 누워있음',
#  '아니 오늘 이후 넷플에 남는게 뭐냐',
#  '@guro_obba 요즘 넷플에 애니 많이 들어오더라구요! 넘행복스??',
#  '좀 따 스벅에서 넷플이나 봐야지',
#  '@yst2303 넷플 오리지널이에용~',
#  '@Turtle___neck 넷플 카톡추가하면 이모티콘 주나요? +_+',
#  '보건교사 후기...',
#  '한국에 이런 드라마가 또 있었나 싶었고',
#  '넷플 특유의 코미디공포 보는맛이 있어서 재밌었음 그리고 일단 괴물들이 다 귀여워...',
#  '안은영이랑 홍인표 솔직히 마지막에 하트 두둥 아니었으면 둘 사이에 뭐 있는지도 몰랐을듯 결론 재밌었다~',
#  '@x_shinju 넷플릭스 결제해놓고 보려던 드라마 넷플에 없길래 진격의거인만 보고 썩히는중;;',
#  '@mmaromme 넷플 빨간머리 앤 완전 재밌게 봐서 찍어봤어용(???????)♥ 감사해욧? ? 요론 늑김이죠.. https://t.co/cKyVHoH4f9',
#  '왓챠 3일 무료면 머하나고 울집은 이미 돈 내고 있음..심지어 넷플도 있음....웨이브에 티빙도 있지만 그런거 볼 시간이 없어...ㅜㅜㅜㅜ',
#  '@Kobayashi_Jimoo 넷플은 이걸 안해주는듯 해서..가끔 놓쳐요..',
#  '옛날 영화 진짜 좋아하는데',
#  '왜 바람과 함께 사라지다는 어디에도 없는건가 ㅜㅅ ㅜ ',
#  '넷플에도 없고 ',
#  'wavve에도 없어 ㅜㅅ ㅜ ',
#  '딥디를 사야하는가',
#  '한화남았어ㅠㅠㅠㅠㅠ 넷플도 오늘종료야ㅠㅠㅠㅠ',
#  '@warurul_2da 헛 저두 넷플 달려야하는데.. 뭐 보고계셔요??!',
#  '오늘은 넷플에서 작은아씨들을 봤는데 연기력,,색감,,분위기,,조명,,,모든게 완벽했고 사랑에 빠짐ㅠㅠㅠ아니근데 시얼샤 로넌이랑 티모시 샬라메 케미 뭐냐구ㅠㅜㅠ왤케 찰떡이야ㅠㅠㅜㅠ',
#  '왓챠 2개월 끊었더니 넷플...넷플도 지른다',
#  '사람들이 넷플에서 보건교사 얘기말고 다른 얘기하는 것도 얼른 보고싶다',
#  '넷플이 갑자기 엄브렐라 어쩌고 추천하더니 모털 엔진을 보여주는데 아니 클라우스 너 왜 거깄니',
#  '@pometyt ㅋㅋㅋㅋ잉 뽀미님 뭔일 있으세요???? 저 넷플 예전에 가입했다가 해약했어요!',
#  '@orBackInTime 그렇다고 티비에서 방영해주는거도 아니라서 더 슬프네요ㅠㅠ 방영분만 있으면 녹화해서 영상 따낼 수 있는데ㅠㅠㅠㅠ 그래도 넷플릭스 시리즈로 나온건 제대로 더빙까지 볼 수 있어서 좋네요??… https://t.co/EE4mJiRlJp',
#  '@CARAT_DULI 넷플 버드박스 재미씀',
#  '@orBackInTime 예ㅠㅠ 로미상이 휘닥 더빙하셨고, 로즈 성우는 사카마야입니다... 일본에서도 스트리밍으로 더빙 볼 수 있는 방법이 훌루랑 아마존정도라서ㅠㅠ 많이 아쉬울 뿐입니다... 넷플에 들여오면 좋을텐데요ㅠㅠㅠ흑...',
#  '@znls1997 갈아타 난 상관없음 ㅋㅋ 엄빠 차피 넷플 잘 안보시잖아',
#  '내가 쉬는 날 더 바쁘다고 하면 도대체 집구석에서 뭐하냐고들 하는데 나는 고영 2마리와 함께 살고 넷플, 왓챠, 웨이브를 구독중에 있으며 안 읽은 책이 더 많고 아이패드와 노트북과 4개의 외장하드를 가진 오타쿠라고요',
#  '서울 초년생인데 뭐해야 재미가 있을까? 오피스텔에서 넷플 보는건 아닌데',
#  '여행 가고싶다!!',
#  '#섹트 #여행 #서울 https://t.co/XVRKMiH2kz',
#  '넷플 보이프렌즈 보는 중인데 주인공 둘 와꾸가 모든걸 멱살잡고 끌고감ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 따인 삽질 그만해애애애액!!!!',
#  '@jinjoo_ab 내년에 웨스커 딸래미들 나오는 실사 드라마도 넷플에서 공개되고!!! 걱정과 우려의 시선을 보내며 나의 결제를 받아라',
#  '넷플은 들어가기전에 카드번호 입력하라고 해서 막혔는데.. ',
#  '왓챠는 카드번호 입력을 안 해두 되는거야ㅡ.?',
#  '팃팅 폭망인데~',
#  '그래도 좋다.  ㅋ ',
#  '놀아야줘~',
#  '놀아야줘~.ㅋㅋㅋㅋ',
#  '일단 오늘은 넷플이다~! 캬캬캬~',
#  '@neal39591 내부자들 따라 갈꺼야! 넷플에 내부자들 없엉?',
#  '@neal39591 그러면.. 언니한테 넷플 말고 왓챠로 끈어달라고 해야겠는데.',
#  '@BS__PALGONG ? 무야 재방송 ? 아님.. 넷플?',
#  '넷플 왓챠 라프텔 애니플러스 웨이브 아마존프라임을 하나로 통합 시켜달라는 건… 전 토렌트를 쓰고 싶어요~로 들리는 내가 삐딱한 거겠지.',
#  '넷플 친구랑 반띵해서 보니까 좋네',
#  '즘심 묵고 2시간 놀았으니 .. 3시간 동안 넷플을 보자',
#  '교수님이 휴강 대체 과제로 영화 하나를 보라고 하셨다 넷플 1달 끊어 둔 거 아직 안 끝났는데 봐야지 크크',
#  '@8IjlJUwmcdUyAju 넷플과 함께라면 두려울것이 없죠',
#  '@maerdymteg 냇플도 지겨움요...ㅠㅠ',
#  '와 미스터하트 한국 거였네 넷플 썸넬 보고 대만이나 태국일 줄..',
#  '요즘 넷플에 뜬 모 소설 작가분부 전자책 도정제필요성 주장한다던데 그 소설 10프로 할인하던데 전자책으로? 왜 하지? 정가로 팔지?',
#  '@Berbabiap 넷플 .. 저도 보고싶은데.. ㅠㅠ',
#  '아 악의꽃 넷플 없네',
#  '시도니아 벌써 넷플에서 내려갔군 알람봇 절실하다...ㅠ',
#  '넷플에서 블팬 내려가는거 속상해서',
#  '다시 보고 왔는데. ',
#  '보고와도 속상해요',
#  '트찰라가 진짜 세상에 없는게',
#  '좀 이상해. ',
#  '아닌거 같은디.',
#  '회식 때 과음 때문인가...',
#  '연휴 첫날의 설렘인가...',
#  '도통 잘 수가 없네...',
#  '라면 &amp; 넷플 트라이...진짜 지겨워보이는 작품 골라봐야겠다...',
#  '미스 아메리카나 띵작이네.. 테일러 스위프트 제작, 관점이긴 한데 적어도 무슨 말이 하고 싶은지 무슨 일을 겪었는지 잘 알겠다. 이제 테일러의 노래가 다시 들릴 듯.. 나 어쩌다 계속 연예계 다큐를 보고 있… https://t.co/zPQ2bXXlin',
#  '@nyongchicken 엇 ㅋ ㅋ ㅋ ㅋ ㅋ  ㅋㅋ 저도 넷플은 오랜만이라 새로 업로드 된건 잘...몰라요....ㅋ ㅋ ㅋ ㅋ  ㅋㅋ',
#  '@nyongchicken 맞아요...맛잘알 꼴잘알 듕귁넘덜..',
#  '넷플에도 왓챠에도 보고싶은게 딱히 없어서 ㅋ ㅋ ㅋ ㅋ 후',
#  '넷플이나 왓챠에서 볼만한 영화나 드라마 추천해주세요~',
#  '일단 장난스런 키스랑 말할수없는 비밀은 다시볼거임',
#  '와우~~ 올레티비서도 넷플 볼수 있넹...',
#  '그래서 ‘내일 지구가 망했으면’은 언제 하냐...',
#  '@_ananin 넷플 가입해쏘??',
#  '넷플 열심히 즐기는 중. 에롤라 홈즈 보고 크리미널:프랑스 보는 중',
#  '아아 넷플제작 애니는 왜 다 3D기반으로 만드는거야 난 투디의 좀 생략된 스피디한 동화가 좋은데 스리디는 액숀은 자연스럽지만 뭔가 덜렁덜렁 불필요한 움직임이 많다고 쓰리디소스가 제작비가 더 적은걸까??',
#  '그건 그렇고 냇플 건담시리즈를 올릴 생각은 없나 저작료가 비싸려나 건담시드부터 다시 보고 싶은데ㅎㅎㅎ',
#  '방금 보건교사 아는형이 왜 인기인지 모르겠다는 투잇을 봤는데..음 친구네도 복수심(?)인지 시내필부심인지 몰라도 안은영 별로라며?넷플에서 씨지퀄 속았다고 욕하는 중이라던데 어떠냐고 묻길래 그짝에서 도는 얘기… https://t.co/FMkxsq8mWm',
#  '유튭 포토샵 넷플',
#  '@croco_davin 다빈님! ㅋㅋㅋ 오랜만에 이계정이에요? 요즘 뭔 게임해요?? 다빈님이 예전에 팠던? 파던? 파는? 그 게임 애니...그거 넷플에 있어서 다시 봐봤는데 여전히 이해가 안가더라구요 게임을… https://t.co/iI1y4rzE99',
#  '아 물론 클리프행어엔딩이라고 엄청 또 투덜거렸다. 하지만 모든 미드는 다 클리프행어 엔딩인걸.. 심지어 저건 넷플인데.. 라고 놀렸더니 입이 댓발 튀어나옴.',
#  '냇플에 하카다 돈코츠 라멘즈라는 애니 있는데 은근 재밋음...나 약간 라노베 체질인가봐ㅎㅎㅎㅎ',
#  '@LEEMINHOMINOZ12 넷플 부럽네에엥.. 시험..은 어예 됬어?',
#  '넷플도 한국 서비스 초기에 계약문제였는지 하우스 오브 카드 서비스  좀 뒤늦게 시작했던걸 떠올려보면...',
#  '@Doby_isnotfree 한국은 라이센스 계약이 만료되가지고 넷플에서 10월 1일까지 볼수 있더라..ㅋㅋ 뭐.. 충분히 봤으니 만족함...',
#  '넷플 공포영화 추천좀',
#  '좀바 개조음',
#  '킹덤 이틀만에 클리어',
#  '솔까말...미하 수준이고, 이 정도로 바로 넷플 공개면 난 차기작 결제할 것 같지않음. 넷플 정기결제인지라(...)',
#  '넷플 왓챠에 비하면 넘 기본이 안 되어 있다고밖엔..',
#  '애플,디즈니,HBO맥스 국내 진출 준비 https://t.co/psuP63YJsK',
#  '곧 넷플에 있는 워너IP들도 다 내리겠네.....;;;;;',
#  'OTT가 너무 많아지는 거 아냐?',
#  '넷플은 만화읍냐',
#  '부산에 왔지만 집 밖에 나가지 않는 이시국 집콕러',
#  '나 왜 부산왔더라? ㅋㅋ 넷플이나 봐야지ㅋㅋ https://t.co/COCVJfiGiU',
#  '보고싶은대...',
#  '이거하나 때문에...',
#  '넷플 질러야하나?ㅠㅠ https://t.co/Ht6FSNsL7R',
#  '보건교사 안은영 넷플로 보기전에 책으로 먼저 읽고 싶어서 충동구매했는데...모야 생각보다 잘 읽혀...!! 너무조차나...?? https://t.co/KrXOnM8q58',
#  '안은영 재밋나여 여새 넷플 볼게없어']

# %%
import nltk
from konlpy.tag import Okt; t = Okt()

# %%
# 리스트 중 str 타입이 아닌 요소들이 존재함을 확인
for i in okt_list:
    if type(i) == float:
        i = str(i)
        print(i)

# %%
# str 타입이 아닌 요소들이 있으면 전부 str 타입으로 바꿔라!
for i in range(len(okt_list)):
    if type(okt_list[i]) != str:
        okt_list[i] = str(okt_list[i])

# %%
okt_text = ''

for each_line in okt_list[:2000]:
    okt_text = okt_text + each_line + '\n'

# %%
tokens_ko = t.morphs(okt_text)
tokens_ko
# Out:
# ['넷플',
#  '공포영화',
#  '추천',
#  '좀',
#  '\n',
#  '좀비',
#  '개조',
#  '음',
#  '\n',
#  '킹덤',
#  '이틀',
#  '만에',
#  '클리어',
#  '\n',
#  '솔까말',
#  '...',
#  '미하',
#  '수준',
#  '이고',
#  ',',
#  '이',
#  '정도',
#  '로',
#  '바로',
#  '넷플',
#  '공개',
#  '면',
#  '난',
#  '차기작',
#  '결제',
#  '할',
#  '것',
#  '같지',
#  '않음',
#  '.',
#  '넷플',
#  '정기',
#  '결제',
#  '인지',
#  '라',
#  '(...)',
#  '\n',
#  '넷플',
#  '왓챠',
#  '에',
#  '비',
#  '하면',
#  '넘',
#  '기본',
#  '이',
#  '안',
#  '되어',
#  '있다고밖엔',
#  '..',
#  '\n',
#  '애플',
#  ',',
#  '디즈니',
#  ',',
#  'HBO',
#  '맥스',
#  '국내',
#  '진출',
#  '준비',
#  'https://t.co/psuP63YJsK',
#  '\n',
#  '곧',
#  '넷플',
#  '에',
#  '있는',
#  '워너',
#  'IP',
#  '들도',
#  '다',
#  '내리겠네',
#  '.....;;;;;',
#  '\n',
#  'OTT',
#  '가',
#  '너무',
#  '많아지는',
#  '거',
#  '아냐',
#  '?',
#  '\n',
#  '넷플',
#  '은',
#  '만화',
#  '읍',
#  '냐',
#  '\n',
#  '@cafe_yotsuba',
#  'HBO',
#  '에서',
#  '제',
#  '작',
#  '한',
#  '거',
#  '라',
#  '넷플',
#  '엔',
#  '안',
#  '올라',
#  '올',
#  '듯',
#  '하고',
#  '저',
#  '는',
#  '웹하드',
#  '에서',
#  '다운',
#  '받아',
#  '봤어요',
#  '\n',
#  '부산',
#  '에',
#  '왔지만',
#  '집',
#  '밖에',
#  '나가지',
#  '않는',
#  '이',
#  '시국',
#  '집콕러',
#  '\n',
#  '나',
#  '왜',
#  '부산',
#  '왔더라',
#  '?',
#  'ㅋㅋ',
#  '넷플',
#  '이나',
#  '봐야지',
#  'ㅋㅋ',
#  'https://t.co/COCVJfiGiU',
#  '\n',
#  '보고싶은대',
#  '...',
#  '\n',
#  '이',
#  '거',
#  '하',
#  '나',
#  '때문',
#  '에',
#  '...',
#  '\n',
#  '넷플',
#  '질러야하나',
#  '?',
#  'ㅠㅠ',
#  'https://t.co/Ht6FSNsL7R',
#  '\n',
#  '보건',
#  '교사',
#  '안은영',
#  '넷플',
#  '로',
#  '보기전에',
#  '책',
#  '으로',
#  '먼저',
#  '읽고',
#  '싶어서',
#  '충',
#  '동',
#  '구매',
#  '했는데',
#  '...',
#  '모야',
#  '생각',
#  '보다',
#  '잘',
#  '읽혀',
#  '...!!',
#  '너무',
#  '조차',
#  '나',
#  '...??',
#  'https://t.co/KrXOnM8q58',
#  '\n',
#  '안은엳',
#  '재밋나',
#  '여',
#  '여',
#  '새',
#  '넷플',
#  '볼',
#  '게',
#  '없어',
#  '\n',
#  '넷플',
#  '도',
#  '없어서',
#  '비숲',
#  '도',
#  '못',
#  '본단',
#  '말',
#  '여',
#  'ㅠ',
#  '\n',
#  '넷플',
#  '에서',
#  '파우다',
#  ':',
#  '혼돈',
#  '보는',
#  '중',
#  '인데',
#  '..',
#  '순교자',
#  '많이',
#  '나오던데',
#  '..',
#  '\n',
#  '넷플',
#  '에서',
#  '래치드',
#  '주행',
#  '시작',
#  '했는데',
#  '벌써',
#  '맘',
#  '에',
#  '든다',
#  '화면',
#  '구성',
#  '컬러',
#  '감',
#  '하며',
#  '배우',
#  '들',
#  '소재',
#  '까지',
#  '....',
#  '간만',
#  '에',
#  '볼',
#  '만',
#  '한',
#  '게',
#  '생겨서',
#  '너무',
#  '조음',
#  '\n',
#  '넷플',
#  '끊고',
#  '왓챠',
#  '로',
#  '갈까봐',
#  '넷플',
#  '에',
#  '없는',
#  '한드',
#  '사극',
#  '많네',
#  '독립영화',
#  '도',
#  '많고',
#  '2',
#  '주',
#  '무료',
#  '로',
#  '보고',
#  '있는데',
#  '탐색',
#  '하면서',
#  '이',
#  '게',
#  '있다고',
#  '??',
#  '연발',
#  '중',
#  'ㅋㅋㅋㅋㅋ',
#  '\n',
#  '#본사람_다하기',
#  '\n',
#  '이름',
#  ':',
#  '남구',
#  '\n',
#  '나이',
#  ':',
#  '99년',
#  '생',
#  '\n',
#  '키',
#  ':',
#  '157',
#  '\n',
#  '몸무게',
#  ':',
#  '43',
#  '\n',
#  '통장',
#  '잔고',
#  ':',
#  '십만',
#  '엔',
#  '\n',
#  '지갑',
#  '잔고',
#  ':',
#  '백',
#  '엔',
#  '\n',
#  '거주지',
#  ':',
#  '도쿄',
#  '\n',
#  '폰',
#  '기',
#  '종',
#  ':',
#  '사과',
#  '폰',
#  '\n',
#  '취미',
#  ':',
#  '넷플',
#  '보기',
#  '\n',
#  '직업',
#  ':',
#  '유학생',
#  '겸',
#  '매국',
#  '클로',
#  '스탭',
#  '\n',
#  '부란',
#  '당',
#  '넷플',
#  '파티',
#  '있었구나',
#  '...',
#  '재미있었겠다',
#  '...',
#  '\n',
#  '아니',
#  '그땐',
#  '분명',
#  '손절',
#  '한',
#  '이유',
#  '가',
#  '있었을텐데',
#  '소장',
#  '할',
#  '정도',
#  '까진',
#  '아니라고',
#  '생각',
#  '했을',
#  '거란',
#  '말',
#  '이지',
#  'ㅜㅠㅋ',
#  '근데',
#  '넷플',
#  '로',
#  '도깨비',
#  '다시',
#  '보기',
#  '하는데',
#  '재밌네',
#  '재밌어',
#  '불쾌한',
#  '골짜기',
#  '같은데',
#  '재밌긴',
#  '해',
#  '\n',
#  '아',
#  '놔',
#  '넷플',
#  '봤으니',
#  '끝난',
#  '줄',
#  '알았는데',
#  '유튜브',
#  '는',
#  '인터뷰',
#  '에',
#  '비하인',
#  '드',
#  '에',
#  '난리',
#  '났',
#  '...',
#  '\n',
#  '&',
#  'lt',
#  ';',
#  '보건',
#  '교사',
#  '안은영',
#  '&',
#  'gt',
#  ';',
#  '넷플',
#  '드라마',
#  '.',
#  '원작',
#  '은',
#  '안',
#  '읽어',
#  '보고',
#  '봤는데',
#  '1',
#  ',',
#  '2',
#  '편',
#  '만',
#  '영화로',
#  '만들었으면',
#  '딱',
#  '좋은',
#  '느낌이었고',
#  ',',
#  '3',
#  '편',
#  '~',
#  '6',
#  '편',
#  '은',
#  '다음',
#  '시즌',
#  '을',
#  '위',
#  '한',
#  '복선',
#  '을',
#  '보여주는',
#  '이야기',
#  '였을텐데',
#  '전개',
#  '가',
#  '불친절해서',
#  '그래서',
#  '대체',
#  '그',
#  '…',
#  'https://t.co/8IcgOECm3d',
#  '\n',
#  '일본',
#  '넷플',
#  '에',
#  '있습니다',
#  '?',
#  '\n',
#  '@stellajoon912',
#  '저',
#  '도',
#  '원래',
#  '넷플',
#  '로',
#  '보는데',
#  '오늘',
#  '만',
#  'tv',
#  '로',
#  '..',
#  '\n',
#  '뜨면',
#  '바로',
#  '보셔요',
#  '\n',
#  '여러분',
#  '넷플',
#  '시작',
#  '하시는',
#  '분들',
#  '주변',
#  '에',
#  '있으시다면',
#  '이건',
#  '제',
#  '가',
#  '권',
#  '해드리는',
#  '리스',
#  '트입니다',
#  '.',
#  '\n',
#  '여기',
#  '서',
#  '하나',
#  '라도',
#  '재밌게',
#  '보시',
#  '면',
#  ',',
#  '다',
#  '재밌데',
#  '보실',
#  '\n',
#  '아',
#  'Umbrella',
#  'Academy',
#  '깜빡',
#  '했다',
#  '.',
#  'https://t.co/iW5f2YNWTz',
#  '\n',
#  '@_kook2_W',
#  '동',
#  '재',
#  ',,,,',
#  '정답',
#  '을',
#  '말',
#  '해조',
#  '.....',
#  '\n',
#  '힛',
#  '넷플',
#  '로',
#  '달려갑니다아',
#  '\n',
#  '나나',
#  '님',
#  '굿뱀',
#  '??',
#  '\n',
#  '@harunobear',
#  '꺄악',
#  '넷플',
#  '달려갑니',
#  '닼',
#  'ㅋㅋㅋ',
#  '\n',
#  '서',
#  '검사',
#  '님',
#  '때매',
#  '본방',
#  '사수',
#  '함',
#  '휴',
#  '우',
#  '~~~',
#  '글',
#  '두',
#  '비숲',
#  '은',
#  '넷플',
#  '자막',
#  '버전',
#  '이',
#  '최고',
#  '!!',
#  '다시',
#  '봐야지',
#  '~~',
#  '\n',
#  '비숲',
#  '10시',
#  '에',
#  '시작',
#  '하는',
#  '줄',
#  '알',
#  '고',
#  '13',
#  '화',
#  '9시',
#  '에',
#  '시작',
#  '했는데',
#  ',,',
#  '하',
#  ',,',
#  '넷플',
#  '에',
#  '뜨려면',
#  '11시',
#  '까지',
#  '기다려야',
#  '하고',
#  ',,',
#  '1시간',
#  '뜨는거',
#  '넘',
#  '고통',
#  '이야',
#  ',,!!!!',
#  '\n',
#  '넷플릭스',
#  '&',
#  'lt',
#  ';',
#  '플레이',
#  '북',
#  ':',
#  '게임',
#  '의',
#  '법칙',
#  '&',
#  'gt',
#  ';',
#  '추천',
#  '.',
#  '스포츠',
#  '감독',
#  '들',
#  '이',
#  '말',
#  '하는',
#  '자신',
#  '들',
#  '만의',
#  '‘',
#  'Rule',
#  '’',
#  '에',
#  '대한',
#  '이야기',
#  '.',
#  '모리뉴',
#  '편',
#  '부터',
#  '봤는데',
#  '꼭',
#  '스포츠',
#  '가',
#  '아닌',
#  '대부분',
#  '조직',
#  '에도',
#  '적용',
#  '될만',
#  '한',
#  '이야기',
#  '가',
#  '많아서',
#  '좋았다',
#  '.',
#  '대단한',
#  '팀',
#  '…',
#  'https://t.co/nTSOGDyfg6',
#  '\n',
#  '보는',
#  '작품',
#  '마다',
#  '은은하게',
#  '사라',
#  '폴슨',
#  '자주',
#  '나오네',
#  '...',
#  '넷플',
#  '에서',
#  '요',
#  '번',
#  '에',
#  '나온것도',
#  '봐',
#  '야하는디',
#  '\n',
#  '넷플',
#  '에',
#  '오페라',
#  '의',
#  '떼쟁이',
#  '하네',
#  '\n',
#  '노래',
#  '잘',
#  '한다',
#  '\n',
#  '지금',
#  '저녁',
#  '먹으며',
#  '랜선',
#  '회식',
#  '켜서',
#  '이번',
#  '엔',
#  '진짜',
#  '밥',
#  '먹으며',
#  '인',
#  '라',
#  '보는데',
#  '...',
#  '진짜',
#  '내',
#  '가',
#  '넷플',
#  '이',
#  '라면',
#  '이런',
#  '느낌',
#  '일까',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '짝궁',
#  '엔',
#  '터',
#  '회식',
#  '아니라',
#  '그냥',
#  '넷플',
#  '감상',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '\n',
#  '잼는',
#  '..',
#  '왓챠',
#  '나',
#  '..',
#  '넷플',
#  '영화',
#  '추천',
#  '해주실',
#  '분',
#  '..?',
#  '\n',
#  '저',
#  '도',
#  '추천',
#  '해드리겠어요',
#  '\n',
#  '다이버전트',
#  '-',
#  '얼리전트',
#  '(??)-',
#  '인서전트',
#  '시리즈',
#  '작',
#  '넘',
#  '잼',
#  '써용',
#  '...',
#  '여성',
#  '서사',
#  '...',
#  '\n',
#  '글구',
#  '진격',
#  '거',
#  '..',
#  '정말',
#  '잼',
#  '써요',
#  '...',
#  '\n',
#  '@H_Summer_66',
#  '왕',
#  '나도',
#  '유튭',
#  '이랑',
#  '넷플',
#  '은',
#  '되는데',
#  '브이',
#  '앱',
#  '은',
#  '모르겟당',
#  '\n',
#  '주먹',
#  '왕',
#  '랄프',
#  '를',
#  '방금',
#  '넷플',
#  '로',
#  '봤는데',
#  '\n',
#  '그냥',
#  '동화',
#  '가',
#  '아니라',
#  '레디',
#  '플레이어',
#  '원',
#  '같은',
#  '옛날',
#  '게임',
#  '많이',
#  '하던',
#  '키덜트',
#  '용',
#  '영화',
#  '였네',
#  '\n',
#  'RT',
#  '@zz_sewoon',
#  ':',
#  '미친',
#  '넷플',
#  '에',
#  '정',
#  '새운',
#  '검색',
#  '하면',
#  '폰',
#  '요',
#  '나와',
#  'ㅋㅋㅋㅋㅋ',
#  '기절',
#  'https://t.co/uaIYcfwXoK',
#  '\n',
#  '@rabbit_cat__',
#  '그건',
#  '...',
#  '뭐',
#  '죠',
#  '?',
#  '추석',
#  '지나고',
#  '넷플',
#  '정',
#  '주행',
#  '할',
#  '예정',
#  '추석',
#  '담날',
#  '출근',
#  '했다가',
#  '\n',
#  '탐라',
#  '에',
#  '안은영',
#  '넘쳐나는데',
#  '넷플',
#  '없어서',
#  '못',
#  '본다',
#  '.??',
#  '\n',
#  '@momocathy',
#  '넷플',
#  '올라왔어',
#  '?',
#  '\n',
#  '넷플',
#  '보건',
#  '교사',
#  '안은영',
#  '드라마',
#  '재밋어',
#  '서',
#  '책',
#  '사러',
#  '갈라구',
#  'https://t.co/cKs3VRqJyR',
#  '\n',
#  'RT',
#  '@Bookistak',
#  ':',
#  '보건',
#  '교사',
#  '안은영',
#  '넷플',
#  '에',
#  '풀리',
#  '기를',
#  '막',
#  '고대',
#  '하고',
#  '있었는데',
#  '막상',
#  '풀리고',
#  '나니',
#  '아끼느라',
#  '못',
#  '보고',
#  '있다',
#  '.',
#  '특별히',
#  '괴로운',
#  '어떤',
#  '날',
#  '스스로',
#  '에게',
#  '선물',
#  '하',
#  '듯이',
#  '봐야지',
#  '.',
#  '\n',
#  '도',
#  '은씨',
#  '랑',
#  '넷플',
#  '이',
#  '만나서',
#  '레즈',
#  '물',
#  '을',
#  '찍어',
#  '야한다',
#  '이거야',
#  '\n',
#  '넷플',
#  '안은영',
#  '3',
#  '화',
#  '까지',
#  '봤는데',
#  '재밌다',
#  '별로',
#  '라는',
#  '평이',
#  '많아서',
#  '걱정',
#  '했는데',
#  '사건',
#  '을',
#  '에피소드',
#  '별로',
#  '끊지',
#  '않고',
#  '서로',
#  '물려서',
#  '진행',
#  '되는',
#  '게',
#  '처음',
#  '엔',
#  '이상했는데',
#  '2',
#  '화',
#  '지나면서',
#  '자연',
#  '스럽게',
#  '녹아',
#  '드는',
#  '듯',
#  '다음',
#  '화로',
#  '계속',
#  '보게',
#  '되는',
#  '효과',
#  '도',
#  '있고',
#  '아',
#  '음악',
#  '이',
#  '진짜',
#  '좋다',
#  'ㅋㅋ',
#  '\n',
#  '윈도우',
#  '업데이트',
#  '했는데',
#  '다시',
#  '엣지',
#  '소리',
#  '출력',
#  '설정',
#  '제대로',
#  '작동',
#  '한',
#  '다',
#  '!',
#  '\n',
#  '더',
#  '이상',
#  '엣지',
#  '로',
#  '넷플',
#  '볼',
#  '때',
#  '모든',
#  '출력',
#  '을',
#  '스피커',
#  '에서',
#  '티비',
#  '로',
#  '바꿀',
#  '필요',
#  '가',
#  '없어',
#  '!',
#  '\n',
#  '안은영',
#  '은',
#  '넷플',
#  '오',
#  '리지',
#  '널',
#  '이니까',
#  '느긋하게',
#  '봐야지',
#  '\n',
#  '아니',
#  '진짜',
#  '넷플',
#  '볼',
#  '리스트',
#  '너무',
#  '많은데',
#  '이',
#  ...]

# %%
ko = nltk.Text(tokens_ko)
ko.vocab().most_common(100)    # 가장 많이 나온 단어 100개
# Out:
# [('\n', 723),
#  ('넷플', 549),
#  ('에', 230),
#  ('이', 167),
#  ('...', 161),
#  ('.', 122),
#  ('가', 121),
#  ('도', 106),
#  ('..', 102),
#  ('로', 97),
#  ('에서', 81),
#  ('은', 80),
#  ('을', 71),
#  ('의', 71),
#  ('들', 69),
#  ('다', 67),
#  ('?', 67),
#  (',', 62),
#  ('는', 61),
#  (':', 56),
#  ('나', 55),
#  ('를', 55),
#  ('안', 52),
#  ('만', 48),
#  ('보고', 48),
#  ('한', 46),
#  ('…', 45),
#  ('거', 44),
#  ('왓챠', 40),
#  ('으로', 39),
#  ('2', 38),
#  ('아', 38),
#  ('드라마', 38),
#  ('너무', 37),
#  ('하고', 37),
#  ('고', 37),
#  ('저', 36),
#  ('??', 36),
#  ('볼', 35),
#  ('안은영', 34),
#  ('영화', 34),
#  ('(', 32),
#  ('추천', 29),
#  ('좀', 29),
#  ('내', 29),
#  (')', 29),
#  ('중', 28),
#  ('오늘', 28),
#  ('요', 28),
#  ('결제', 27),
#  ('ㅠㅠ', 27),
#  ('보건', 27),
#  ('교사', 27),
#  ('!', 27),
#  ('ㅋㅋ', 26),
#  ('뭐', 26),
#  ('봤는데', 25),
#  ('RT', 25),
#  ('게', 24),
#  ('못', 24),
#  ('다시', 24),
#  ('1', 24),
#  ('하는', 24),
#  ('것', 23),
#  ('보는', 23),
#  ('진짜', 23),
#  ('ㅋㅋㅋ', 22),
#  ('사람', 22),
#  ('라', 21),
#  ('왜', 21),
#  ('더', 21),
#  ('ㅋ', 21),
#  ('해서', 21),
#  ('했는데', 19),
#  (';', 19),
#  ('부터', 19),
#  ('티비', 19),
#  ('수', 19),
#  ('말', 18),
#  ('까지', 18),
#  ('....', 18),
#  ('해', 18),
#  ('!!', 18),
#  ('한국', 18),
#  ('과', 18),
#  ('이나', 17),
#  ('생각', 17),
#  ('제', 16),
#  ('엔', 16),
#  ('집', 16),
#  ('봐야지', 16),
#  ('시작', 16),
#  ('근데', 16),
#  ('시즌', 16),
#  ('보는데', 16),
#  ('서', 16),
#  ('에도', 16),
#  ('랑', 16),
#  ('라고', 16),
#  ('하', 15)]

# %%
# 불용어 : 인터넷 검색 시 검색 용어로 사용하지 않는 단어. 관사, 전치사, 조사, 접속사 등 검색 색인 단어로 의미가 없는 단어
stop_words = [')','?','1','"(', '_', ')/','\n','.',',', '<','!','(','(', '??','..', '4', '|', '>', '?(', '"…', '#', '&', '・', "']",'.',' ','/',"'",'’','”','“','·', '[','!','\n','·','‘','"','\n ',']',':','…',')','(','-', 'nan','가','요','답변','...','을','수','에','질문','제','를','이','도',
                      '좋','1','는','로','으로','2','것','은','다',',','니다','대','들',
                      '2017','들','데','..','의','때','겠','고','게','네요','한','일','할',
                      '10','?','하는','06','주','려고','인데','거','좀','는데','~','ㅎㅎ',
                      '하나','이상','20','뭐','까','있는','잘','습니다','다면','했','주려',
                      '지','있','못','후','중','줄','6','과','어떤','기본','!!',
                      '단어','라고','중요한','합','가요','....','보이','네','무지']

tokens_ko = [each_word for each_word in tokens_ko
             if each_word not in stop_words]

ko = nltk.Text(tokens_ko)
ko.vocab().most_common(100)
# Out:
# [('넷플', 549),
#  ('에서', 81),
#  ('나', 55),
#  ('안', 52),
#  ('만', 48),
#  ('보고', 48),
#  ('왓챠', 40),
#  ('아', 38),
#  ('드라마', 38),
#  ('너무', 37),
#  ('하고', 37),
#  ('저', 36),
#  ('볼', 35),
#  ('안은영', 34),
#  ('영화', 34),
#  ('추천', 29),
#  ('내', 29),
#  ('오늘', 28),
#  ('결제', 27),
#  ('ㅠㅠ', 27),
#  ('보건', 27),
#  ('교사', 27),
#  ('ㅋㅋ', 26),
#  ('봤는데', 25),
#  ('RT', 25),
#  ('다시', 24),
#  ('보는', 23),
#  ('진짜', 23),
#  ('ㅋㅋㅋ', 22),
#  ('사람', 22),
#  ('라', 21),
#  ('왜', 21),
#  ('더', 21),
#  ('ㅋ', 21),
#  ('해서', 21),
#  ('했는데', 19),
#  (';', 19),
#  ('부터', 19),
#  ('티비', 19),
#  ('말', 18),
#  ('까지', 18),
#  ('해', 18),
#  ('한국', 18),
#  ('이나', 17),
#  ('생각', 17),
#  ('엔', 16),
#  ('집', 16),
#  ('봐야지', 16),
#  ('시작', 16),
#  ('근데', 16),
#  ('시즌', 16),
#  ('보는데', 16),
#  ('서', 16),
#  ('에도', 16),
#  ('랑', 16),
#  ('하', 15),
#  ('보다', 15),
#  ('비숲', 15),
#  ('기', 15),
#  ('와', 15),
#  ('면', 14),
#  ('화', 14),
#  ('이랑', 14),
#  ('ㅋㅋㅋㅋ', 14),
#  ('주말', 14),
#  ('야', 14),
#  ('책', 13),
#  ('ㅠ', 13),
#  ('많이', 13),
#  ('ㅋㅋㅋㅋㅋ', 13),
#  ('gt', 13),
#  ('그', 13),
#  ('넷플릭스', 13),
#  ('지금', 13),
#  ('분', 13),
#  ('전', 13),
#  ('애니', 13),
#  ('걸', 13),
#  ('난', 12),
#  ('없어서', 12),
#  ('보기', 12),
#  ('아니', 12),
#  ('게임', 12),
#  ('유튭', 12),
#  ('같은', 12),
#  ('흑', 12),
#  ('이제', 12),
#  ('아직', 12),
#  ('에는', 12),
#  ('공개', 11),
#  ('인지', 11),
#  ('넘', 11),
#  ('있는데', 11),
#  ('님', 11),
#  ('자막', 11),
#  ('꼭', 11),
#  ('봐', 11),
#  ('오', 11),
#  ('돈', 11),
#  ('함께', 11)]

# %% [markdown]
# ## 여기까지

# %%
content_new=[]
for i in range(len(df)):
    content_new.append(str(df["content"][i]))
content_new[:1]
df["content_new"]=content_new

# %% [markdown]
# # 일단 해야 하는 것
#     #전처리
#     #str.replace([정규표현식]) 영문 제외 나머지 지워야 해서 넣음 : 공백으로 대체해!
#     #한글자 짜리인 것들 도 삭제
#     #소문자로 변환
#     #공백으로 토큰화, 문장 하나하나의 각각의 토큰이 리스트로 들어감
#     #불용어 제거

# %%
import re 
# '한글'을 제외한 다른 문자 모두 제거
remove_except_ko = re.compile(r"[^가-힣ㄱ-ㅎㅏ-ㅣ\\s|A-Za-z]")
def preprocess(text):
    text = re.sub(remove_except_ko,' ',text).strip()
    return text

df['clean_doc'] = df['content_new'].map(lambda x : preprocess(x))
df.head(5)
# Out:
#                                              content  \
# 0                                        넷플 공포영화 추천좀
# 1                                             좀비 개조음
# 2                                        킹덤 이틀만에 클리어
# 3  솔까말...미하 수준이고, 이 정도로 바로 넷플 공개면 난 차기작 결제할 것 같지않...
# 4                      넷플 왓챠에 비하면 넘 기본이 안 되어 있다고밖엔..
#
#                                          content_new  \
# 0                                        넷플 공포영화 추천좀
# 1                                             좀비 개조음
# 2                                        킹덤 이틀만에 클리어
# 3  솔까말...미하 수준이고, 이 정도로 바로 넷플 공개면 난 차기작 결제할 것 같지않...
# 4                      넷플 왓챠에 비하면 넘 기본이 안 되어 있다고밖엔..
#
#                                            clean_doc
# 0                                        넷플 공포영화 추천좀
# 1                                             좀비 개조음
# 2                                        킹덤 이틀만에 클리어
# 3  솔까말   미하 수준이고  이 정도로 바로 넷플 공개면 난 차기작 결제할 것 같지않...
# 4                        넷플 왓챠에 비하면 넘 기본이 안 되어 있다고밖엔

# %%
from konlpy.tag import Okt
m=Okt()

# %%
stop_word = [')','?','1','"(', '_', ')/','\n','.',',', '<','!','(','(', '??','..', '4', '|', '>', '?(', '"…', '#', '&', '・', "']",'.',' ','/',"'",'’','”','“','·', '[','!','\n','·','‘','"','\n ',']',
             ':','…',')','(','-', 'nan','가','요','답변','...','을','수','에','질문','제','를','이','도','좋','1','는','로','으로','2','것','은','다',',','니다','대','들',
            '2017','들','데','..','의','때','겠','고','게','네요','한','일','할','10','?','하는','06','주','려고','인데','거','좀','는데','~','ㅎㅎ',
             '하나','이상','20','뭐','까','있는','잘','습니다','다면','했','주려','지','있','못','후','중','줄','6','과','어떤','기본','!!',
             '단어','라고','중요한','합','가요','....','보이','네','무지','안녕하세요','께서','에서','이다','에게','으로','이랑','까지','부터','하다','습니다','https','com',')',
             '?','1','"(', '_', ')/','\n','.',',', '<','!','(','(', '??','..', '4', '|', '>', '?(', '"…', '#', 
             '&', '・', "']",'.',' ','/',"'",'’','”','“','·', '[','!','\n','·','‘','"','\n ',']',':','…',')',
             '(','-', 'nan','가','요','답변','...','을','수','에','질문','제','를','이','도',
             '좋','1','는','로','으로','2','것','은','다',',','니다','대','들',
             '2017','들','데','..','의','때','겠','고','게','네요','한','일','할',
             '10','?','하는','06','주','려고','인데','거','좀','는데','~','ㅎㅎ','때문','없어',
             '하나','이상','20','뭐','까','있는','잘','습니다','다면','했','주려','되어','하면','싶어서','미하','Name','FSNsL','했는데','먼저','이고','만에','읽혀','Ht','dtype','있다고밖엔','클리어','co','보다','않음',
             '지','있','못','후','중','줄','6','과','어떤','기본','!!','에서','나','만','안','아','라','왜','더','같지',
             '단어','라고','중요한','합','가요','....','보이','네','무지','께서','에서','이다','에게','으로','이랑','까지','부터','하다','습니다','https','com',
            '안녕','수목','이루어지','새로이','이것','비디오','컨텐츠','배경','이용권','배경','재밌','형식','웨이브','이벤트','결합','드디어',
             '근래','차일피일','wavve','우리','하세','oksus','끝나','코로나','모드','세포','보시','이야기','맞추','po','Name','작품','추석','빙상','준비',
             '언급','포함','많이','무료','보내','찾아오','부가','챙기','오늘','소비','진행','모든','oksusu','이미', '자기','관심','방송','서비스','통하','배우',
             '오랜만','스마트','모아','제공','챙기','시간','dtype','부가세','통하','오랜만','계시','소개','정말','아니','기웃거','따지','보리','진행하',
             '보내','이렇','안되','두고','끝나','다라','까먹','돌리'',ㅠㅠ,''남기','오랜만','안녕','유독','진행하','다음주','과의','아름','까먹','kcl','이렇',
             '진짜','쐐면','오진','그러','반하','정말','독하','금인','몸살','지나','미리','세사','abject','naver','다가오','그동안','나중','그렇','아쉽','이리',
             '여리','갈대','직무','바로','예방','보리','주사','독감','대통령','기준','돌리','요즘','얼마','미리','렌즈','갈대','아름','문제','결국','드디어','못하','하세','ㅠㅠ',
             'Length','tokens','ㅎㅎ','ㅋㅋㅋ','고르','그렇','평소','진짜','이후','다시','즐기','비교','높이','이렇','보통','object','챙기','기사','엄청','고민','vs','dtype','현재',
             '안녕','Name','알아보','바벨','바디','진행','여러분','와이','하자','그렇','어느','앳되','끝내','이런','해소','해보','직전','말하','얼마','질리','확인','울리','기다리','한지','누르',
             '빠지','궁금하','ㅠㅠ','요금','버튼','하기','경보','저번','저의','하세','크리','알아보','직전','오래되','일보','object','dtype','Name','Length','JJ','dtype','Name','squale','youtu',
             '그동안','length','Play','KIMU','object','net','그동안','ㅋㅋㅋ','status','hwanair','saintpain','andy','ndminialbum','weibo','twitter',
             'theqoo','XHhni','나의','안녕', 'tokens','KrXOnM','Length']
stopPos = ['JKS','JKC','JKG','JKO','JKM','JKI','JKQ','JC','JX','EPH','EPT'
           ,'EPP','EFN','EFQ','EFO','EFA','EFI','EFR','ECE','ECS','ECD','ETN','ETD','XPN','XPV',
            'XSN','XSV','XSA','XR','SF','SE','SS','SP','SO','SW','OH','ON','UN','MAC',"NNB","NNM","VXV","VV"]
def token_mecab(text):
    text = m.pos(text)
    text = [i for i in text if len(i[0])>1]
    text = [i for i in text if i[0] not in stop_word]
    text = [i[0] for i in text if i[1] not in stopPos]
    return text

# %%
df.head(5)
# Out:
#                                              content  \
# 0                                        넷플 공포영화 추천좀
# 1                                             좀비 개조음
# 2                                        킹덤 이틀만에 클리어
# 3  솔까말...미하 수준이고, 이 정도로 바로 넷플 공개면 난 차기작 결제할 것 같지않...
# 4                      넷플 왓챠에 비하면 넘 기본이 안 되어 있다고밖엔..
#
#                                          content_new  \
# 0                                        넷플 공포영화 추천좀
# 1                                             좀비 개조음
# 2                                        킹덤 이틀만에 클리어
# 3  솔까말...미하 수준이고, 이 정도로 바로 넷플 공개면 난 차기작 결제할 것 같지않...
# 4                      넷플 왓챠에 비하면 넘 기본이 안 되어 있다고밖엔..
#
#                                            clean_doc  \
# 0                                        넷플 공포영화 추천좀
# 1                                             좀비 개조음
# 2                                        킹덤 이틀만에 클리어
# 3  솔까말   미하 수준이고  이 정도로 바로 넷플 공개면 난 차기작 결제할 것 같지않...
# 4                        넷플 왓챠에 비하면 넘 기본이 안 되어 있다고밖엔
#
#                                tokens
# 0                          넷플 공포영화 추천
# 1                               좀비 개조
# 2                               킹덤 이틀
# 3  솔까말 수준 정도 넷플 공개 차기작 결제 넷플 정기 결제 인지
# 4                               넷플 왓챠

# %%
# 토큰화 + 토큰리스트 생성 
def make_tokens(df):
    df['tokens'] = ''
    tokens_list=[]
    for i, row in df.iterrows():
        if i%10000==0:
            print(i,'/',len(df))
        token = token_mecab(df['clean_doc'][i])
        df['tokens'][i] = ' '.join(token)
    return df

# %%
df = make_tokens(df)
# Out:
# 0 / 753

# %%
df.head(3)
# Out:
#        content  content_new    clean_doc      tokens
# 0  넷플 공포영화 추천좀  넷플 공포영화 추천좀  넷플 공포영화 추천좀  넷플 공포영화 추천
# 1       좀비 개조음       좀비 개조음       좀비 개조음       좀비 개조
# 2  킹덤 이틀만에 클리어  킹덤 이틀만에 클리어  킹덤 이틀만에 클리어       킹덤 이틀

# %%
tokenized_doc=df["tokens"].apply(lambda x: x.split());tokenized_doc
tokenized_docs=tokenized_doc.apply(lambda x : ' '.join ([item for item in x if item not in stop_word]))

# %%
type(tokenized_docs)
# Out:
# pandas.core.series.Series

# %%
from wordcloud import WordCloud

# %%
df["tokens"]
# Out:
# 0                               넷플 공포영화 추천
# 1                                    좀비 개조
# 2                                    킹덤 이틀
# 3       솔까말 수준 정도 넷플 공개 차기작 결제 넷플 정기 결제 인지
# 4                                    넷플 왓챠
#                       ...
# 748                                  보고싶은대
# 749
# 750                               넷플 질러야하나
# 751    보건 교사 안은영 넷플 보기전에 읽고 구매 모야 생각 너무 조차
# 752                             안은영 재밋나 넷플
# Name: tokens, Length: 753, dtype: object

# %%
for i in range(len(df)):
    b=str(df['tokens'])

# %%
b
# Out:
# '0                               넷플 공포영화 추천\n1                                    좀비 개조\n2                                    킹덤 이틀\n3       솔까말 수준 정도 넷플 공개 차기작 결제 넷플 정기 결제 인지\n4                                    넷플 왓챠\n                      ...                 \n748                                  보고싶은대\n749                                       \n750                               넷플 질러야하나\n751    보건 교사 안은영 넷플 보기전에 읽고 구매 모야 생각 너무 조차\n752                             안은영 재밋나 넷플\nName: tokens, Length: 753, dtype: object'

# %%
wordcloud = WordCloud(font_path='malgun.ttf',max_font_size=100,background_color='white').generate(b)

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(13,13))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)
