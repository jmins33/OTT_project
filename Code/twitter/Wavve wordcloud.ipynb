# %%
import pandas as pd
import numpy as np
from konlpy.tag import Okt
import nltk
m=Okt()

# %%
df=pd.read_csv('C:/Users/jminw/Desktop/media/twitterwavve.csv', encoding='CP949')

# %%
df.head(5)
# Out:
#                                              content
# 0           @yitian_L: 비주얼합 쩔고 티키타카는 덤인 민국기탐 plz....
# 1                                       일단 수입부터.....
# 2                                   #중드맛집_웨이브_지금_영업중
# 3  #路? #民?奇探 #HuYiTian #胡一天 #호일천 https://t.co/qZw...
# 4  @wavve_official 중드 여주는 성격이 다 똑같아...눈 희번득 뜨는 거는...

# %%
okt_test = df['content']; okt_test
# Out:
# 0               @yitian_L: 비주얼합 쩔고 티키타카는 덤인 민국기탐 plz....
# 1                                           일단 수입부터.....
# 2                                       #중드맛집_웨이브_지금_영업중
# 3      #路? #民?奇探 #HuYiTian #胡一天 #호일천 https://t.co/qZw...
# 4      @wavve_official 중드 여주는 성격이 다 똑같아...눈 희번득 뜨는 거는...
#                              ...
# 268                               웨이브 찾아보니까 20화밖에 없던데..
# 269                                     혹시 중간에 짤린건가요????
# 270                                      웨이브 써볼만 하겠네&lt;
# 271    웨이브는... 너무 사용하기 불편하던데... 팝업 왔다 갔다 하다 보면 재생 초기화...
# 272                      @Xo_Hooon 왜샀어 ㅠㅠㅠㅠㅠ 나 웨이브 쓰고있눈데
# Name: content, Length: 273, dtype: object

# %%
okt_list = okt_test.values.tolist()

print(len(okt_list))
okt_list
# Out:
# 273
# ['@yitian_L: 비주얼합 쩔고 티키타카는 덤인 민국기탐 plz....',
#  '일단 수입부터.....',
#  '#중드맛집_웨이브_지금_영업중',
#  '#路? #民?奇探 #HuYiTian #胡一天 #호일천 https://t.co/qZwRRnbJ1q',
#  '@wavve_official 중드 여주는 성격이 다 똑같아...눈 희번득 뜨는 거는 누가 일부러 가르치나ㅋㅋㅋㅋㅋ',
#  'RT @Piksari_kick: 중국 최대의 명절 중추절이 모래부터 시작입니다.',
#  '우한 헬게이트 포함 모든 해외발 입국은 발열체크수준에서 그치기에 무증상감염자들을 거리지 못합니다.',
#  '변이된 중국코로나 전국재살포를 위해 노력하는 문th벌 덕분에 10월…',
#  '중국판 노다메 노잼폭망했다던데 그걸 독점이라고 하다뇨... 웨이브 실망이야??',
#  "온라인 동영상 플랫폼 '웨이브'가 출범 1년 만에 가입자 1000만명을 돌파했다. 꾸준한 성장세를 이어가고 있는 웨이브는 연중 서비스 개편 프로젝트를 통해 카테고리별 강화된 '개인화'로 경쟁력을 키운다는 전… https://t.co/bY5bUS6JzW",
#  '리듬게임 라인업(2020년 1월 기준) - No.1 #SportsTecBot',
#  '-유비트 페스토 3대 : 라이트 500원/스탠다드 1,000원/프리미엄 1,500원',
#  '-사운드 볼텍스 비비드 웨이브(3대) : 라이… https://t.co/SkQxfzcQvB',
#  'RT @ATEEZofficial: [#여상] 사랑하는 에이티니!',
#  '일루젼과 웨이브 둘 중에 뭐가 좋을지 고민이 많죠????',
#  '저는 이미 골랐어요! 바로바로~ ',
#  '에이티니가 골라주는거ㅎㅎ',
#  '#ATEEZ #에이티즈 https://t.co/fM5fMMnFtF',
#  '웨이브에 구독해놓은거 봐야하긴 한데 요즘 안보고 있는.. 근데 내 남동생이 내 계정으로 잘봄',
#  '웨이브 정신차려 오늘 계속 렉걸려 ㅠㅠㅜㅜㅜㅜ. 첫 단추부터 잘못됐어 ㅜㅜㅜㅜㅜㅜㅜ 다시 봐야지.......',
#  '아 웨이브 티비로 좀 보겠다는데 로그인부터 잘 안 되서 너무 빡치는 중 나보고 어쩌라는 건데',
#  '@SALMON_613 다나 안무 지미니 웨이브 그 때 같은뎅 도포 블랙스완 또 보고싶은 마음에 ㅠ ㅎㅎ',
#  'RT @lunamoth: 온라인동영상서비스(OTT) 월간활성이용자(MAU) 순위 (닐슨코리안클릭, 2020년 8월 기준 https://t.co/HcozccBu0U)',
#  '1. 넷플릭스 : 755만8천292명',
#  '2. 웨이브 : 387만9천730명',
#  '3. 티빙…',
#  'RT @lunamoth: "애플TV나 디즈니플러스, HBO맥스가 들어올 준비를 하고 있고 아마존 프라임은 벌써 들어와있다."',
#  '아마존 프라임 국내에서 볼 수 있었군요. 지금 알았네요',
#  '[종합] 웨이브 출범 1주년→1000만뷰 유료가입자 3배 성장..…',
#  'RT @ATEEZofficial: [#민기] 민기의 하루 끝!! 웨이브 막방이라서 오늘 하루는 에이티니한테 제 일상을?전부 공유하고 싶었어요 ㅎㅎ 잘했죠? 사랑하는 에이티니 이번 활동 너무 고맙구 내가 많이 사랑합니당 잘 자고 내 꿈꿔요 ♡♡',
#  '#AT…',
#  '@drywriting 웨이브 그리고 애거서크리스티전집과 함께 할 예정입니다 ??',
#  '@dhrskckf11 와아 쪼아요 ㅋㅋㅋ?????',
#  '웨이브 찾아보니까 20화밖에 없던데.. ',
#  '혹시 중간에 짤린건가요????',
#  '웨이브 써볼만 하겠네&lt;',
#  '콘텐츠웨이브, "웨이브 회원 1000만 시대, 오리지널 콘텐츠·개인화 주력할 것" https://t.co/eRjEvfHtp3',
#  '@TrieTrois 웨이브랑 하우스는 모야??',
#  '#디스코군 업데이트',
#  '- 드래곤 퀘스트 1,2',
#  '- 와리오랜드 2',
#  '- 동키콩… https://t.co/Ms1jOjtqRu',
#  '웨이브 메인 ',
#  '행복해보이는 백현이???(????? ? ????)??? https://t.co/o4nJdtoGP3',
#  'RT @ATEEZofficial: [#민기] 민기의 하루 끝!! 웨이브 막방이라서 오늘 하루는 에이티니한테 제 일상을?전부 공유하고 싶었어요 ㅎㅎ 잘했죠? 사랑하는 에이티니 이번 활동 너무 고맙구 내가 많이 사랑합니당 잘 자고 내 꿈꿔요 ♡♡',
#  '[종합] 웨이브 출범 1주년→1000만뷰 유료가… https://t.co/VN8SdAgWlw',
#  'RT @RmRei7: 흐억 ',
#  '#방문자커플 크로스 웨이브',
#  '윤기야아이야이아아앜 @BTS_twt https://t.co/TlC2mEoHBm',
#  '(LEAD) Local streaming service provider Wavve tops 10 mln subscribers https://t.co/lMjK4fxRK4',
#  '언젠가 꼭 가보고싶읏 톈샨산맥과 샹글릴라!!',
#  '125회 트레킹노트 세상을 걷다',
#  '웨이브는... 너무 사용하기 불편하던데... 팝업 왔다 갔다 하다 보면 재생 초기화되고 ㅡㅡ; 심지어 작품 소개글도 없고..',
#  '@Xo_Hooon 왜샀어 ㅠㅠㅠㅠㅠ 나 웨이브 쓰고있눈데',
#  '@WOOZI_zini 혹시 엠카투표는 엠웨이브랑 지니중에 하나로 하면 되나요?',
#  'RT @iamfanboyforbw: 윈이 특집 - (틱톡주의)',
#  'RT @MasterWhite18: @turkeyfiend @Hanwoo_of_TX 122가 뭡니까. 미국 조금이라도 빠지는 각 나오면 기갑웨이브가...',
#  '#One_To_All #ILLUSION #WAVE #ATEEZ #에이티즈',
#  'RT @taetae_Pteryong: 웨이브와 시스루와 겟섬팍....ㅇㅁㅇ!!! https://t.co/U76NVzzU5P',
#  'RT @MHA_KR: #나의히어로아카데미아 #극장판',
#  '#나의히어로아카데미아더무비 #히어로즈라이징',
#  'VOD 최초공개 절찬 서비스 중!',
#  'RT @ATEEZofficial: [#윤호] 웨이브 첫 방송 리허설 전에 찍은 사진~~????',
#  '지민이는 웨이브가 천천히 들어가서 마치 뒤로 제끼듯 보이고. 정국이는 정석대로 안으로 감아.ㅠ',
#  '너네 너무 굿~믹스매치..??',
#  '@simnalamburt 한국은 티빙이나 웨이브로 되던기능이죠. UI는 잘만들었어요.  Fox TV VP아저씨 몇년전에 만났을 때 저 딜 관련되서 이야기 들었는데 구글이 계약하는라 고생꽤나 했더군요.',
#  "백현이 예능 넘넘 잘하구 ?'?'? 10월 되면 바로 웨이브 결제해서 엠토피아 봐야지!! https://t.co/OGCzNqHsJZ",
#  '@Belita_0105 웨이브앱에서 볼수 있어요 !',
#  '와 나 진촤 오늘 민윤기 시스루 와 진짜 미쳐 블랙스완+시스루+웨이브+민윤기=환장의 조합 https://t.co/WA5Wr6rlcm',
#  '이번 추석엔 바클라바를 사다 먹으며 위대한 세기를 집에서 보고 싶은데...',
#  '왜 왓챠랑 웨이브에선 지원하는데 넷플릭스엔 없나요... tv로 보고싶은데... 넷플릭스밖에 지원을 안해 우리집 기가지니는...(；ω；) 타블렛 밖에 없다규',
#  '@ex_s00zeen ㅋㅋㅋㅋㅋ 대충 짐작하면서 시즌2 재밌게 보고 있었어요. 웨이브에 유코짱 드라마 작품이 없네요. 영화만 몇편 있고.ㅠㅜㅠㅜㅜㅠ',
#  '상당히 재미있는데 티빙에서만 볼 수 있다니...웨이브에라도 풀어주세요...',
#  '트위터도 UI 바뀔 때 마다 이게 제정신인가 했는데, wavve 이번 업데이트는... 이건 그냥 쓰지 말라 하는거같다. 야구만 아니면 iptv 끊어버릴, 아니 야구도 이제 송출하니 정말 iptv 안 쓸까 했… https://t.co/cymGDoG1hZ',
#  '웨이브에서 맥북에 드라마 다운 받으려니까 왜 안되지 ㅜㅜㅜ혹시 아시는분 있으면 좀 알려주세요 ㅠㅠㅠㅠ',
#  '웨이브 홈바 안없어지네....업데이트 안하나....????',
#  '지상파 겁나 웨이브 밀어줌~',
#  '여러분 엘리스 재밌나유? 타임슬립 드라마 라구 해서 솔깃 해서유 ',
#  '보시는 님들 있나유? 웨이브 들어가 말오',
#  '넷플 왓챠 아마존프라임 웨이브 라프텔까지 구독하고 있는데, 신작 편 수야 말로 플랫폼 전쟁의 핵심인 듯하다. 작품당 퀄은 아마존이 더 낫지 않나 싶은데 매주 무식한 수의 신작이 쏟아져 들어오는 넷플릭스가 너… https://t.co/I3GDnYHlJv',
#  '제작 : 웨이브',
#  '2021년 1월 발매예정??',
#  '#슈타게 #마키세크리스 https://t.c…',
#  '어제 앨리스 볼려고 웨이브 들어갔는데',
#  '시스템 구조 바껴있어서 클났다 싶어서.. 스브스앱으로 봤어..ㅋㅋ',
#  '내가 wavve 결제를 했단말임 화질 좋게 보려고 프리미엄으로 했지 동생이 커프다큐할 때 부산mbc는 다른방송하길래 웨이브라이브로 봤단말임 내 아이디로 근데 어제 동생이 이용권이 없다고 구매해야된다고 그런다… https://t.co/nHOdvzUHeA',
#  '내일은 사랑...은 안 해주나 싶었는데 웨이브에 있네',
#  '웨이브 등 ott에서 할 수 있는데 유튜브 멤버십으로 d2c를 또 하는구나',
#  'XSX가 SKT와 손을 잡아서 한국어화를 기대한다지만 나로서 회의적인 이유.',
#  '1. MS는 한국을 취급 안 함. 주력 상품인 윈도우의 한국어 검수도 제대로 안 하고 출시 안 하는 제품도 많음.',
#  '2. SKT… https://t.co/LvBCch1Wrd',
#  '@itmeansadverb 아니네요. wavve에서도 개별구매해야 되네요.',
#  '근데 작탐 막 그릏게 웨이브를 타시면서.... 녹마이클 난잡한 춤은 그렇게 질색을 하는거에요 ㅎㅎㅎㅎㅎㅎ',
#  '@bloveb_56 저 본방사수 못해서 다시보기 보려구하는데 ㅠT -Ving아이디두 없구 M토피아는 Wavve아이디 없어서 못보네요ㅠㅠㅠ본방사수하고시픈데ㅠ',
#  '@B_hundred_Hyun 아앙 징짜 Wavve아이디없어서 M토피아 못보구ㅠT-ving아이디 없어서 원하는대로 다시보기두 못보구ㅠㅠㅠㅠ누가 좀 빌려쥬세여ㅓㅠㅠㅠㅠㅠㅠ',
#  '@itmeansadverb wavve에 있어요. 첫달 100원 이벤이 있던데... ^^',
#  'RT @Baiyu_Honey: 야..이런 건 수입해도 될 것 같지 않닝. 웨이브나 티빙에서 보게 해 줘.',
#  '야..이런 건 수입해도 될 것 같지 않닝. 웨이브나 티빙에서 보게 해 줘.',
#  '와 보검이 덕질하면서 일드는 거의 안보게 됐는데  요금제 바꾸면서 웨이브 무료사용할 수 있게 되서 예전에 덕질하던 일드 최신시즌을 봐보니 정말  못 보겠다 ㅋㅋㅋㅋㅋㅋㅋㅋ 연기도 연출도 스토리도 노답이야...??',
#  '@wintersoundbook 들어온지 얼마 안됐어요!ㅋㅋㅋㅋㅋㅋ 웨이브 온갖 불만을 갖고 쓰다가 드디어 보상 받아 싶었어욬ㅋㅋㅋㅋㅋㅋ',
#  'RT @MHA_KR: #나의히어로아카데미아 #극장판',
#  '#나의히어로아카데미아더무비 #히어로즈라이징',
#  'VOD 최초공개 절찬 서비스 중!',
#  '??여기서 볼 수 있어요??',
#  '#KT #SK #LG #Homechoice #Naver #Laftel #Wavve #SKYL…',
#  '@popopoddball 웨이브에 올라와있어요?? 저도 결제해야겠음ㅋㅋㅋㅋ',
#  '웨이브 업데이트 왜 이렇게 그지같이 된 거니ㅠㅠ',
#  '@Sarudammi_ 네~ 재밌죠~ ㅠ?!??? 웨이브에서 꼬박꼬박 일주일마다 업뎃하는 거 챙겨보고 있는데 이부키X시마 페어 너무 좋아요 ㅠㅠ 거기에 둘 본체 성격이 반대인 것도 좋은ㅋㅋㅋ',
#  '@Jinseyeon 세연님 뭐하고 계세요? 심심하시면 그림 시즌3. 6회 함 챙겨보세요 wavve 같은 곳에서 볼수있는것 아시죠 나근한 오후시간 시간있으시면 함 챙겨보세요 뭐하고 계실지 모르지만 역시 좋은시간 보내세요 ^^',
#  '웨이브 사 말아',
#  '@NaSeul_ 나 웨이브. . .  볼꺼많은거같아 지금 100이벤트 하는거같은데',
#  '갑자기 오소마츠 보고 싶었는데 뜻밖에 웨이브에 있었다',
#  '역시 쭈니미녁은 춤을 정말 예쁘게 잘춰????',
#  '웨이브가 너무 섹시해??',
#  '근데 오늘 캐슷이 그래서 그런지 유독 더 작소였다??',
#  '너무 예쁘고 귀여운데 형들한테 맞서는 장면 마다 걱정이 돼서...??...ㅋㅋㅋㅋ',
#  '그리고… https://t.co/Jd62yK6Gbe',
#  '@esfp_dory 웨이브는 조선로코 녹두전이죠',
#  '오늘의 힐링은 M토피아. 내가 웨이브를 결재하다니?? 그러나 태민이만 봐도 스트레스 풀리기에',
#  '웨이브분할친구님들 쪼금남는건 저 까까사먹을게요?? 2개월금액 다시알려드렸으니 확인해주세요??',
#  '으앗 카드 안가져왔네ㅠ',
#  '이따 집가서 웨이브결제해야겠다ㅠㅠ',
#  '웨이브 4인팟 결제하려고하는데',
#  '같이하실분계신가요??',
#  '엑소엘우선으로 구합니다????',
#  '#웨이브분할',
#  '웨이브 분할 구해요 ㅜㅜㅜ 디엠 주세요 ㅜㅜ  #웨이브분할  웨이브',
#  '아이폰 쓰시는 분들은 pc로 들어가서 웨이브 100원 결제 하신 다음 폰으로 넘어와서 이용권 옆에 있는 자동 결제 해지 누르시면 한달이용 가능해요!',
#  '넷플릭스는 진정령을 내놔라..!!!! 내가 왓챠랑 웨이브랑 다 결제하면서 봐야겠냐!!!!',
#  '일단',
#  '넷플 왓차 웨이브',
#  '스팀 *픽 유플레이 오리진 ',
#  '등',
#  '근데 게임불따나 영화드라마 불따 저걸로 정당화하는애들이 있나',
#  '웨이브에서 저번부터 계속 보이던 sf8. 미루고 미루다 이제 보기 시작.',
#  '근데 웨이브는 대체 자막 제공 언제할건지..',
#  '영국 코비드 세컨 웨이브로 아직 위험하긴 하지만 그래도 촬영할 때 만큼은 마스크 쓰고 진단검사하고 이런 안전 수칙 지키는 게 뉴노멀 되는 거 같아서 조금은 안심?? 후유증도 적지 않으니...코로롱 절대 피해 가',
#  '@wavve_official ㅂ',
#  '헐 뭐야 나 웨이브 구독 해지됐네....ㅋㅋㅋ',
#  '웨이브 첫달 100원이니까 10월에 결제해야겠다! 1,2주차는 좀 늦게보구 딱 한달만 결제해야지이!',
#  '구글 크롬캐스트3 스마트폰 미러링 유튜브 넷플릭스 티비연결 웨이브 미라캐스트 TV연결 크롬캐스트 국내정품AS  https://t.co/kYH9hg4Qgp',
#  '요근래 머겜 관심이 줄어듦',
#  '이럴 때 딱 다시 봐야하는데',
#  '티빙 결제하긴 싫단 말야',
#  '이미 넷플 왓챠 웨이브 자주 보지도',
#  '않는데 작품 몇개땜에 끊었단 말야',
#  '@TAEMIN6v6TAEMIN 웨이브앱으로 볼수 있지 않나요?',
#  '@PGI_1126 웨이브에는 스트리밍 있는 드라마 추천',
#  '이 남자는 인생최대실수입니다: 초병맛 로코물 오글거림 살짝있음. 오직 여주에게 직진형 남주를 보고싶다면 이 드라마를 추천',
#  '사랑은 계속 될거야 어디까지나… https://t.co/WRDjjfFnfP',
#  '요즘 유튜브랑 웨이브에 빠져서 넷플릭스는 볼 시간이 없길래 구독 끊을까 하고 들어갔더니 알림해뒀던게 뜨네. 이래서 넷플릭스 못끊는거 몇번째냐... 크리미널 시리즈 짧게짧게 다양한 유럽 언어 듣는 것도 재밌었… https://t.co/sdKA0Wy3lJ',
#  '@Dundunny_O3O 웨이브 너무 이쁘당',
#  'RT @BBO_OH: 비숲즌투 끝났으니, 모두 녹두꽃을 보세요~!!',
#  '@NetflixKR  근데 왜 넷플릭스에는 녹두꽃이 없나요? 이렇게 한국적이고 고증 철저하고 연출 연기 모두 좋은 대작이~!!',
#  '웨이브, sbs있어요 모두 보세요~!  그 어느 드…',
#  '리듬게임 라인업(2020년 1월 기준) - No.1 #SportsTecBot',
#  '-유비트 페스토 3대 : 라이트 500원/스탠다드 1,000원/프리미엄 1,500원',
#  '-사운드 볼텍스 비비드 웨이브(3대) : 라이… https://t.co/bSmUETsfdP',
#  'RT @ATEEZofficial: [#민기] 민기의 하루 끝!! 웨이브 막방이라서 오늘 하루는 에이티니한테 제 일상을?전부 공유하고 싶었어요 ㅎㅎ 잘했죠? 사랑하는 에이티니 이번 활동 너무 고맙구 내가 많이 사랑합니당 잘 자고 내 꿈꿔요 ♡♡',
#  '세계 최대, 아시아 최초 도심형 인공서핑 웨이브파크 7일 부분 개장 https://t.co/sOOyYswXJh',
#  "RT @datastaion: 골드만삭스 바이든의 '블루 웨이브' 경제 성장 촉진https://t.co/y1DnEgRyfQ",
#  '이런 지출 증가는 최소 기업과 고소득자의 장기 세금 증가분과 일치할 것',
#  '연준이 경제가 완전 고용에 도달하고 인플레이션이 2%를…',
#  '#슈퍼엠 #슈퍼M #M토피아 #엠토피아 #아이돌리얼리티 #아이돌예능 #예능 #태민 #백현 #카이  #태용 #텐 #마크 #루카스 #엑소 #샤이니 #NCT127 #wavve #웨이브 #웨이브오리지널 #웨이브엠토피아',
#  '문샤인 곡은 또 웨이브이 일려나... 웨이브이 다른 모습도 보고싶은데요..',
#  '@sunflowerkyon: 어바웃타임 | 모집공고 | 유노윤호 | wavve | 어바웃타임쇼 https://t.co/UWCGrzV9rY @YouTubeより',
#  '#남우현 #우현 #잡지 #싱글즈 #kwave #양도 https://t.co/wrUr7X…',
#  "골드만삭스 바이든의 '블루 웨이브' 경제 성장 촉진https://t.co/y1DnEgRyfQ",
#  '보이시나요? ',
#  '원하는 건 모두 다 부르면서 하는 ',
#  '저 어깨 웨이브~ ?? https://t.co/LbyCoHz5xN',
#  'RT @ATEEZofficial: [??] 에이티즈, 일루젼-웨이브 퍼포먼스 포스터로 자랑한 ‘키치함VS소년미’',
#  '#One_To_All #ILLUSION #WAVE #ATEEZ #에이티즈',
#  'RT @ATEEZofficial: [??] 에이티즈, ‘일루젼 VS 웨이브’ 댄스 미리보기 영상 공개 “팬 투표 반영”',
#  '#One_To_All #ILLUSION #WAVE #ATEEZ #에이티즈',
#  'RT @ATEEZofficial: [#여상] 사랑하는 에이티니!',
#  '일루젼과 웨이브 둘 중에 뭐가 좋을지 고민이 많죠????',
#  '저는 이미 골랐어요! 바로바로~ ',
#  '에이티니가 골라주는거ㅎㅎ',
#  '#ATEEZ #에이티즈 https://t.co/fM5fMMnFtF',
#  'RT @happy26yh: 난 윤호랑 100분 못있음. 그 전에 죽을듯..',
#  '스타와 나, 단둘만의 시간. 웨이브 오리지널 예능 &lt;어바웃 타임&gt; 여기서 신청하세요!  (출처 : wavve 웨이브 | 네이버 포스트) https://t.co/Qu78Br…\r\nRT @sunflowerkyon: 어바웃타임 | 모집공고 | 유노윤호 | wavve | 어바웃타임쇼 https://t.co/UWCGrzV9rY @YouTube\r\nRT @ATEEZofficial: [??] 에이티즈, \'웨이브\' MV 티저로 전한 청량감..오늘(10일) 미니앨범 공개\r\n케이웨이브, 그날들 플북 거래중\r\n웨이브 업뎃 되니깐 적응 안되는건 뭐지\r\n대신 읽어줌 특수필터는 TiO₂가 채워진거고 거기다 웨이브랭스 250~300nm정도 되는 빛을 쬐어주면 코로나바이러스의 스파이크 단백질이 모조리 산화되게 만드는 필터라는것 https://t.co/YBzRaZeeIX\r\nRT @orBackInTime: 웨이브 후박사 자막 너무 충격적인데 https://t.co/Cc4uhEPdVE\r\n@kimluon_1213 그니까요 웨이브가 어우 팔뚝이 어우 허벅지 쓰담쓰담\r\n워어어ㅓ- 비벼비벼할때 머리촬-랑거리면서 웨이브...o&lt;-&lt; https://t.co/5Spl4d5qwR\r\n갑자기 궁금해졌다 웨이브에선 로즈가 에클닥을 뭐라고 부르고 있는가....... 에클닥이 아저씨여도 난 되게 좀 어 좀 https://t.co/inUZJ7eYj7\r\n@happy26yh: 난 윤호랑 100분 못있음. 그 전에 죽을듯..\r\n@bee_be_n 웨이브ㅋㅋㅋ큐ㅠㅠ 너모 귀여벙ㅠ\r\n엠토피아는 외국에서 어떻게 보는지..웨이브에서만 볼수 있다고 해서 다운 받으니 해외는 막혔다..아니 이런 애들을 데리고 국내에서만 보여주다니요ㅜㅜ 유투브에서 하이라이트만 보는거 부족하다고ㅠㅠ\r\n우미화-이연-김보민 &amp; 한제이 감독의 정통 퀴어 멜로 드라마 &lt;담쟁이&gt;, 2020.10 개봉 확정!\r\n올해 제21회 전주국제영화제에서 한국경쟁으로 초청되어 온오프 동시 상영이라는 관람 시스템에서 ‘웨이브(w… https://t.co/u0srDvz32X\r\n자...아무튼 10월도됐으니 이제슬슬 정글파티+본가웨이브 달릴준비를 슬슬해볼까\r\n웨이브, 김정은의 안방극장 복귀작… ‘나의 위험한 아내’ 독점 공개 https://t.co/Ky6kH5BEEC\r\n월 3만원 \'순삭\'!"...가랑비에 옷 젖는\'동영상 구독\'',
#  '넷플릭스, 웨이브, 티빙, 씨즌, 내년에는 디즈니까지 국내 OTT는 춘추전국시대인데, 멀티 유저들도 정말 많아지고',
#  '@mys_gggh 이거 웨이브wavve만 될걸요??',
#  '옛날푹pooq',
#  '동영상 뉴스 닷새 동안 이어진 추석 연휴가 오늘로 마무리됩니다 . ',
#  '기존 강자인 넷플릭스와 왓챠에 더해 웨이브 티빙 시즌 등 다양한 장르와 접목을 시도하며 종합예술가적 면모를 드러냈다 . ',
#  '앞서 kbs는 강 장관의 배우자이기 때문에 출발 전 여행을 취',
#  '원래 게임-덕질-게임-덕질 무브 타는 사람인데 딱 요즘 게임 웨이브에 올라가 있어서.. 그림 그릴 짬이 안난다 ㅋㅋㅋㅜㅜ 퇴근하면 8시쯤부터 파판 전장-&gt;10시부터 동방불패 일퀘-&gt;취침??',
#  '암튼 엄니가 또 영화 없냐고 흥미를 보이시길래 이런저런 생각하다 웨이브 유료결제를 다시 하는 걸로 결정했다. 드라마 좋아하는 엄니한텐 그게 취향에 가장 맞을 것 같아서.',
#  'RT @BBO_OH: 웨이브 첫달 100원 결제하고 다운받아도 되요~!!  ',
#  '널리널리 알려도 이롭고 또 이로운 #녹두꽃 https://t.co/wMKo4COKBA',
#  '추석내내 웨이브로 진정령 틀어놓고',
#  '이북으로 마도조사 전편 다읽은사람',
#  '나야나',
#  '내일 왜 월요일?',
#  '웨이브가 없어도 존중스럽게 예쁘다?? https://t.co/EUQaT0cGdC',
#  '웨이브 계정쉐어 1자리 남아요 -프리미엄화질 -월 4천원 웨이브4인팟',
#  '#최진혁 #ChoiJinHyuk #ZombieDetective #좀비탐정',
#  '@hnunu__ 근데 제가 웨이브가 페북연동이라서 일단 페북 걸로 알려드릴게요!',
#  '@hnunu__ 제 웨이브 아이디 빌드릴까요?',
#  '웨이브 성우진 장난아니네...전부터 관심 좀 있긴 했는데 지금 장르도 제대로 파악못하는데 장르늘리긴 좀 ㅜㅜㅜ',
#  '웨이브에 있슴돠. 마지막화 보시면 이게 뭐지 장난하나 싶으실 수도 있는데 외전으로 영화가 있습니다! 영화는 아이치이에 가면 있구요! 영화가 마지막화라고 생각하시면 됩니다! 남주 여주 둘다 연기를 너무 잘해서… https://t.co/JW8fzHafci',
#  '독가기억 정말 재미있는데 3.3 일촌상사에 나오는 여배우도 나오구요 현대극 잘 안보는데 웨이브에서 이 드라마는 뭐지?하고 봤다가 3일만에 정주행한 아주 재밌는 드라마라우 ???? https://t.co/vENxfZrimR',
#  '웨이브 지우ㅜㅆ는데 다시 깔아야지 https://t.co/YSZzx58CUM',
#  '구독료....일단 웨이브랑 티빙은 이번달 까지만 볼꺼고 넷플릭스는....계속가는걸로...유튜브프리미엄은 종신구독하기로 결정함 ㅋㅋㅋㅋㅋ',
#  '한강 서울 웨이브에 생긴 스타벅스 가 보고싶다',
#  'RT @hs9350: [메이킹] 선지의 꼬물꼬물 웨이브부터 모든 배우들이 열정 가득했던 단식원 비하인드☆ [좀비탐정] https://t.co/b7lHSOuB3s - @YouTube',
#  '[메이킹] 선지의 꼬물꼬물 웨이브부터 모든 배우들이 열정 가득했던 단식원 비하인드☆ [좀비탐정] https://t.co/b7lHSOuB3s - @YouTube',
#  '아무나 분당선 안내방송 압축파일로 보내주실 분 없으신가용...',
#  '근데 문특 본방 할 때 보니까 웨이브에는 시청률 2위 정도로 떠있었는데',
#  '혹시 웨이브 사용하시는 분들 10월 2일 나혼자산다 올라왔어요?? 이 새끼들 옥수수때부터 ㅈㄴ 일을 개양아치처럼 함. 통신사 이동해버릴까 싶을 정도임',
#  '웨이브 시청률에 안들어가????',
#  '전세계최호적니 3일남았어,, 도대체 언제 한번더 정주행할거야,, 12시 지나면 2일 남아,, 웨이브에 언제 들어올지도 모르고 시즌 아시아팩에 언제 풀릴지도 몰라,, 빨랑 정주행해 바보야!!',
#  '(나 자신에게 하는말 ㅇㅇ',
#  '@waguuu_ 엌 와구님도!!!! ㅋㅋㅋㅋ 저진짜 칭구다뺏겨서 오기로도 드라마 안밧거든요ㅋㅋㅋㅋㅋ 조만간 웨이브 결제해보깨요..♡',
#  '20. 나 넷플릭스 티빙 웨이브 유튭프리미엄 다 있음 필요할 때 말하면 아이디비번 빌려줌',
#  '음 그냥 못보나 웨이브에서',
#  '아니 웨이브에 이게 잇다니ㅋㅋ 허광한을 위해 미리 예습한다ㅋㅋㅋ 국내개봉 ..시급...ㅜㅜ https://t.co/i5Oj7EUFfj',
#  'Wavve 아 개짜증나 왜 자꾸 멈춰?',
#  '추석효도 스마트 버전. 안방에 크롬캐스트 설치 &amp; 엄마한테 웨이브, 티빙 설치 사용 안내. 재미있게 보떼엽.',
#  '@orange6324 흑흑 진짜 꼭 보고시퍼요??',
#  '어르신페어 웨이브??',
#  '웨이브를 그렇게....웨이브가......더보기 https://t.co/LvM0r7pb8j',
#  '넷플 왓챠 티빙 웨이브 곧 디즈니플러스까지 ;;; 엔빵 진지하게 고민해봐야겠다',
#  '웨이브 결제완료!! 엠토피아 고고',
#  '#치아문난난적소시광 ',
#  '#우리의따뜻했던시절에게',
#  '번외편이 있을줄이야!!!',
#  '넷플에는 없고 wavve에는 있다!!',
#  '1.구웨이이와 쓰투모의 혼인신고서',
#  '2.집안일 다해야한다니깐 “그럼 넌?”',
#  '   “네 마누라” ㅋㅋ…',
#  '추석연휴때 망무 왕샤 몰아그리려고했는데',
#  '막상하는거 -&gt; 먹고 자고 누워서 넷플 웨이브 라프텔보기????',
#  '카카오페이지와 네이버 시리즈가, 웨이브와 지니가 컨텐츠 플랫폼으로서 적정한 대가를 손에 쥐어야 한다면 플레이 스토어와 앱 스토어도 당연히 그래야 한다.',
#  '@tomato_lover_me 아ㅏㅠㅠ 근뎅 웨이브로 보면 화질이 좋지는 않아ㅠㅠ',
#  '@tomato_lover_me 웨이브로 로그인만 하면 볼수는 있오!! 라이브로!',
#  '넷플에서 보건교사 안은영 보고싶지만 지금 wavve쓰고있어서 못보기에 책을 샀다ㅋㅋㅋㅋㅋ 책 먼저 읽어야지ㅋㅋ',
#  '평소에 TV를 웨이브로 봐서',
#  '이런 짤막한 홍보영상 오늘 처음 봤네ㅠㅠ',
#  '겁나 반가워서 웨이브로 녹화뜬거',
#  '시롸냨ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '@triangle_dark 나 웨이브ㅋㅋㅋㅋㅋㅋㅋ 무료로 볼 수 잇엉',
#  '@gwak2pal 웨이브도 야구함까??',
#  '왓챠 3일 무료면 머하나고 울집은 이미 돈 내고 있음..심지어 넷플도 있음....웨이브에 티빙도 있지만 그런거 볼 시간이 없어...ㅜㅜㅜㅜ',
#  'RT @estima7: 웨이브 출범 1년, 이용자 아직 넷플릭스의 절반 https://t.co/ReINhboTcX 토종 OTT플랫폼의 회원수가 출범 1년만에 1천만명 돌파. 굉장히 잘되는 것 같은데도 넷플릭스와 MAU(월간사용자) 격차는 더 커지고…',
#  '@nouk0716 오랜만이에요!',
#  '저는 첫화부터 봐야하는 병에 걸려서ㅋㅋㅋ',
#  '저도 제대로 된 한글자막 보고 싶어요ㅠㅠ일단은 영자막으로 다 보긴 했는데??',
#  '최대한 웨이브나 티빙같은데 빨리 올라오기를 기다리는 중이에… https://t.co/BUiAOYLWhN',
#  '웨이브에 슢엠만 보기 아까워서 샤이니 치니까',
#  '샤어멋이랑,별바라기 나온당..샤어멋 보면서 추억여행이나 해야징',
#  '옛날 영화 진짜 좋아하는데 왜 바람과 함께 사라지다는 어디에도 없는건가 ㅜㅅ ㅜ  넷플에도 없고  wavve에도 없어 ㅜㅅ ㅜ 딥디를 사야하는가',
#  'RT @lemalogos1: @rjceo0 그렇군요.  앱솔님! 저대로 했다가 폭망일테니까요. 어쨌든 NWO가 대선에서 치명타를.. 2차 웨이브도 안되겠죠? 외계인 침공설 나올려나요?????',
#  '#중드맛집_웨이브_지금_영업중',
#  '#路? #民?奇探 #HuYiTian #胡一天 #호일천 https://t.co/qZwRRnbJ1q',
#  'RT @good_PJM: 가끔 멀리 돌아가도???? 웨이브 넣을때 간지보소 #우리지민 무대천재야 #JIMIN 아 멋있다 ',
#  '#중드맛집_웨이브_지금_영업중',
#  '#路? #民?奇探 #HuYiTian #胡一天 #호일천 https://t.co/qZwRRnbJ1q',
#  '와 나 왓챠 넷플릭스 웨이브 다 볼 수있음 볼거 개많아',
#  '넷플릭스를 받아볼까... 이미 티빙, 웨이브를 구독하고 있어서 구독은 그렇고 한달만 보고말까.',
#  '내가 쉬는 날 더 바쁘다고 하면 도대체 집구석에서 뭐하냐고들 하는데 나는 고영 2마리와 함께 살고 넷플, 왓챠, 웨이브를 구독중에 있으며 안 읽은 책이 더 많고 아이패드와 노트북과 4개의 외장하드를 가진 오타쿠라고요',
#  '웨이브에 구독해놓은거 봐야하긴 한데 요즘 안보고 있는.. 근데 내 남동생이 내 계정으로 잘봄',
#  '웨이브 정신차려 오늘 계속 렉걸려 ㅠㅠㅜㅜㅜㅜ. 첫 단추부터 잘못됐어 ㅜㅜㅜㅜㅜㅜㅜ 다시 봐야지.......',
#  '웨이브 티비로 좀 보겠다는데 로그인부터 잘 안 되서 너무 빡치는 중 나보고 어쩌라는 건데',
#  '@drywriting 웨이브 그리고 애거서크리스티전집과 함께 할 예정입니다 ??',
#  '@dhrskckf11 와아 쪼아요 ㅋㅋㅋ?????',
#  '웨이브 찾아보니까 20화밖에 없던데.. ',
#  '혹시 중간에 짤린건가요????',
#  '웨이브 써볼만 하겠네&lt;',
#  '웨이브는... 너무 사용하기 불편하던데... 팝업 왔다 갔다 하다 보면 재생 초기화되고 ㅡㅡ; 심지어 작품 소개글도 없고..',
#  '@Xo_Hooon 왜샀어 ㅠㅠㅠㅠㅠ 나 웨이브 쓰고있눈데']

# %%
import nltk
from konlpy.tag import Okt; t = Okt()

# %%
# 리스트 중 str 타입이 아닌 요소들이 존재함을 확인
for i in okt_list:
    if type(i) == float:
        i = str(i)
        print(i)

# %%
# str 타입이 아닌 요소들이 있으면 전부 str 타입으로 바꿔라!
for i in range(len(okt_list)):
    if type(okt_list[i]) != str:
        okt_list[i] = str(okt_list[i])

# %%
okt_text = ''

for each_line in okt_list[:2000]:
    okt_text = okt_text + each_line + '\n'

# %%
tokens_ko = t.morphs(okt_text)
tokens_ko
# Out:
# ['@yitian_L',
#  ':',
#  '비주',
#  '얼합',
#  '쩔고',
#  '티키타카',
#  '는',
#  '덤',
#  '인',
#  '민국',
#  '기',
#  '탐',
#  'plz',
#  '....',
#  '\n',
#  '일단',
#  '수입',
#  '부터',
#  '.....',
#  '\n',
#  '#중드맛집_웨이브_지금_영업중',
#  '\n',
#  '#路',
#  '?',
#  '#民',
#  '?',
#  '奇探',
#  '#HuYiTian',
#  '#胡一天',
#  '#호일천',
#  'https://t.co/qZwRRnbJ1q',
#  '\n',
#  '@wavve_official',
#  '중드',
#  '여주',
#  '는',
#  '성격',
#  '이',
#  '다',
#  '똑같아',
#  '...',
#  '눈',
#  '희',
#  '번득',
#  '뜨는',
#  '거',
#  '는',
#  '누가',
#  '일부러',
#  '가르치나',
#  'ㅋㅋㅋㅋㅋ',
#  '\n',
#  'RT',
#  '@Piksari_kick',
#  ':',
#  '중국',
#  '최대',
#  '의',
#  '명절',
#  '중추절',
#  '이',
#  '모래',
#  '부터',
#  '시작',
#  '입니다',
#  '.',
#  '\n',
#  '우한',
#  '헬',
#  '게이트',
#  '포함',
#  '모든',
#  '해외',
#  '발',
#  '입국',
#  '은',
#  '발열',
#  '체크',
#  '수준',
#  '에서',
#  '그치기에',
#  '무증상',
#  '감염',
#  '자',
#  '들',
#  '을',
#  '거리',
#  '지',
#  '못',
#  '합니다',
#  '.',
#  '\n',
#  '변',
#  '이',
#  '된',
#  '중국',
#  '코로나',
#  '전',
#  '국재',
#  '살포',
#  '를',
#  '위해',
#  '노력',
#  '하는',
#  '문',
#  'th',
#  '벌',
#  '덕분',
#  '에',
#  '10월',
#  '…',
#  '\n',
#  '중국',
#  '판',
#  '노다메',
#  '노잼',
#  '폭',
#  '망했다던데',
#  '그걸',
#  '독점',
#  '이라고',
#  '하다뇨',
#  '...',
#  '웨이브',
#  '실망',
#  '이야',
#  '??',
#  '\n',
#  '온라인',
#  '동영상',
#  '플랫폼',
#  "'",
#  '웨이브',
#  "'",
#  '가',
#  '출범',
#  '1년',
#  '만에',
#  '가입자',
#  '1000만',
#  '명을',
#  '돌파',
#  '했다',
#  '.',
#  '꾸준한',
#  '성장',
#  '세',
#  '를',
#  '이',
#  '어가',
#  '고',
#  '있는',
#  '웨이브',
#  '는',
#  '연중',
#  '서비스',
#  '개편',
#  '프로젝트',
#  '를',
#  '통해',
#  '카테고리',
#  '별',
#  '강화',
#  '된',
#  "'",
#  '개인화',
#  "'",
#  '로',
#  '경쟁력',
#  '을',
#  '키운다는',
#  '전',
#  '…',
#  'https://t.co/bY5bUS6JzW',
#  '\n',
#  '리듬게임',
#  '라인업',
#  '(',
#  '2020년',
#  '1월',
#  '기준',
#  ')',
#  '-',
#  'No',
#  '.',
#  '1',
#  '#SportsTecBot',
#  '\n',
#  '-',
#  '유비트',
#  '페스',
#  '토',
#  '3',
#  '대',
#  ':',
#  '라이트',
#  '500원',
#  '/',
#  '스탠다드',
#  '1,000원',
#  '/',
#  '프리미엄',
#  '1,500원',
#  '\n',
#  '-',
#  '사운드',
#  '볼텍스',
#  '비비드',
#  '웨이브',
#  '(',
#  '3',
#  '대',
#  ')',
#  ':',
#  '라이',
#  '…',
#  'https://t.co/SkQxfzcQvB',
#  '\n',
#  'RT',
#  '@ATEEZofficial',
#  ':',
#  '[#여상',
#  ']',
#  '사랑',
#  '하는',
#  '에이',
#  '티니',
#  '!',
#  '\n',
#  '일루젼',
#  '과',
#  '웨이브',
#  '둘',
#  '중',
#  '에',
#  '뭐',
#  '가',
#  '좋을지',
#  '고민',
#  '이',
#  '많죠',
#  '????',
#  '\n',
#  '저',
#  '는',
#  '이미',
#  '골랐어요',
#  '!',
#  '바로바로',
#  '~',
#  '에이',
#  '티니',
#  '가',
#  '골라주는거',
#  'ㅎㅎ',
#  '\n',
#  '#ATEEZ',
#  '#에이티즈',
#  'https://t.co/fM5fMMnFtF',
#  '\n',
#  '웨이브',
#  '에',
#  '구독',
#  '해놓은',
#  '거',
#  '봐',
#  '야하긴',
#  '한데',
#  '요즘',
#  '안보',
#  '고',
#  '있는',
#  '..',
#  '근데',
#  '내',
#  '남동생',
#  '이',
#  '내',
#  '계정',
#  '으로',
#  '잘',
#  '봄',
#  '\n',
#  '웨이브',
#  '정신차려',
#  '오늘',
#  '계속',
#  '렉',
#  '걸려',
#  'ㅠㅠㅜㅜㅜㅜ',
#  '.',
#  '첫',
#  '단추',
#  '부터',
#  '잘',
#  '못',
#  '됐어',
#  'ㅜㅜㅜㅜㅜㅜㅜ',
#  '다시',
#  '봐야지',
#  '.......',
#  '\n',
#  '아',
#  '웨이브',
#  '티비',
#  '로',
#  '좀',
#  '보겠다는데',
#  '로그인',
#  '부터',
#  '잘',
#  '안',
#  '되서',
#  '너무',
#  '빡치는',
#  '중',
#  '나',
#  '보고',
#  '어쩌',
#  '라는',
#  '건데',
#  '\n',
#  '@SALMON_613',
#  '다나',
#  '안무',
#  '지미니',
#  '웨이브',
#  '그',
#  '때',
#  '같은',
#  '뎅',
#  '도포',
#  '블랙스완',
#  '또',
#  '보고싶은',
#  '마음',
#  '에',
#  'ㅠ',
#  'ㅎㅎ',
#  '\n',
#  'RT',
#  '@lunamoth',
#  ':',
#  '온라인',
#  '동영상',
#  '서비스',
#  '(',
#  'OTT',
#  ')',
#  '월간',
#  '활',
#  '성',
#  '이용자',
#  '(',
#  'MAU',
#  ')',
#  '순위',
#  '(',
#  '닐슨',
#  '코리안',
#  '클릭',
#  ',',
#  '2020년',
#  '8월',
#  '기준',
#  'https://t.co/HcozccBu0U',
#  ')',
#  '\n',
#  '1',
#  '.',
#  '넷플릭스',
#  ':',
#  '755만',
#  '8천',
#  '292',
#  '명',
#  '\n',
#  '2',
#  '.',
#  '웨이브',
#  ':',
#  '387만',
#  '9천',
#  '730',
#  '명',
#  '\n',
#  '3',
#  '.',
#  '티빙',
#  '…',
#  '\n',
#  'RT',
#  '@lunamoth',
#  ':',
#  '"',
#  '애플',
#  'TV',
#  '나',
#  '디즈니',
#  '플러스',
#  ',',
#  'HBO',
#  '맥스',
#  '가',
#  '들어올',
#  '준비',
#  '를',
#  '하고',
#  '있고',
#  '아마존',
#  '프라임',
#  '은',
#  '벌써',
#  '들어와있다',
#  '."',
#  '\n',
#  '아마존',
#  '프라임',
#  '국내',
#  '에서',
#  '볼',
#  '수',
#  '있었군요',
#  '.',
#  '지금',
#  '알았네요',
#  '\n',
#  '[',
#  '종합',
#  ']',
#  '웨이브',
#  '출범',
#  '1',
#  '주년',
#  '→',
#  '1000만',
#  '뷰',
#  '유료',
#  '가입자',
#  '3',
#  '배',
#  '성장',
#  '..…',
#  '\n',
#  'RT',
#  '@ATEEZofficial',
#  ':',
#  '[#민기',
#  ']',
#  '민기',
#  '의',
#  '하루',
#  '끝',
#  '!!',
#  '웨이브',
#  '막',
#  '방이',
#  '라서',
#  '오늘',
#  '하루',
#  '는',
#  '에이',
#  '티니',
#  '한테',
#  '제',
#  '일상',
#  '을',
#  '?',
#  '전부',
#  '공유',
#  '하고',
#  '싶었어요',
#  'ㅎㅎ',
#  '잘',
#  '했죠',
#  '?',
#  '사랑',
#  '하는',
#  '에이',
#  '티니',
#  '이번',
#  '활동',
#  '너무',
#  '고맙구',
#  '내',
#  '가',
#  '많이',
#  '사랑',
#  '합니당',
#  '잘',
#  '자고',
#  '내',
#  '꿈꿔요',
#  '♡♡',
#  '\n',
#  '#AT',
#  '…',
#  '\n',
#  '@drywriting',
#  '웨이브',
#  '그리고',
#  '애거',
#  '서',
#  '크리스',
#  '티',
#  '전집',
#  '과',
#  '함께',
#  '할',
#  '예정',
#  '입니다',
#  '??',
#  '\n',
#  '@dhrskckf11',
#  '와아',
#  '쪼아',
#  '요',
#  'ㅋㅋㅋ',
#  '?????',
#  '\n',
#  '웨이브',
#  '찾아보니까',
#  '20',
#  '화',
#  '밖에',
#  '없던데',
#  '..',
#  '혹시',
#  '중간',
#  '에',
#  '짤린',
#  '건가',
#  '요',
#  '????',
#  '\n',
#  '웨이브',
#  '써',
#  '볼',
#  '만',
#  '하겠네',
#  '&',
#  'lt',
#  ';',
#  '\n',
#  '콘텐츠',
#  '웨이브',
#  ',',
#  '"',
#  '웨이브',
#  '회원',
#  '1000만',
#  '시대',
#  ',',
#  '오',
#  '리지',
#  '널',
#  '콘텐츠',
#  '·',
#  '개인화',
#  '주력',
#  '할',
#  '것',
#  '"',
#  'https://t.co/eRjEvfHtp3',
#  '\n',
#  '@TrieTrois',
#  '웨이브',
#  '랑',
#  '하우스',
#  '는',
#  '모야',
#  '??',
#  '\n',
#  '#디스코군',
#  '업데이트',
#  '\n',
#  '-',
#  '드래곤',
#  '퀘스트',
#  '1',
#  ',',
#  '2',
#  '\n',
#  '-',
#  '와리오',
#  '랜드',
#  '2',
#  '\n',
#  '-',
#  '동키콩',
#  '…',
#  'https://t.co/Ms1jOjtqRu',
#  '\n',
#  '웨이브',
#  '메인',
#  '행복해',
#  '보이는',
#  '백현',
#  '이',
#  '???(?????',
#  '?',
#  '????)???',
#  'https://t.co/o4nJdtoGP3',
#  '\n',
#  'RT',
#  '@ATEEZofficial',
#  ':',
#  '[#민기',
#  ']',
#  '민기',
#  '의',
#  '하루',
#  '끝',
#  '!!',
#  '웨이브',
#  '막',
#  '방이',
#  '라서',
#  '오늘',
#  '하루',
#  '는',
#  '에이',
#  '티니',
#  '한테',
#  '제',
#  '일상',
#  '을',
#  '?',
#  '전부',
#  '공유',
#  '하고',
#  '싶었어요',
#  'ㅎㅎ',
#  '잘',
#  '했죠',
#  '?',
#  '사랑',
#  '하는',
#  '에이',
#  '티니',
#  '이번',
#  '활동',
#  '너무',
#  '고맙구',
#  '내',
#  '가',
#  '많이',
#  '사랑',
#  '합니당',
#  '잘',
#  '자고',
#  '내',
#  '꿈꿔요',
#  '♡♡',
#  '\n',
#  '[',
#  '종합',
#  ']',
#  '웨이브',
#  '출범',
#  '1',
#  '주년',
#  '→',
#  '1000만',
#  '뷰',
#  '유료',
#  '가',
#  '…',
#  'https://t.co/VN8SdAgWlw',
#  '\n',
#  'RT',
#  '@RmRei7',
#  ':',
#  '흐억',
#  '#방문자커플',
#  '크로스',
#  '웨이브',
#  '\n',
#  '윤기',
#  '야',
#  '아이야',
#  '이',
#  '아아',
#  '앜',
#  '@BTS_twt',
#  'https://t.co/TlC2mEoHBm',
#  '\n',
#  '(',
#  'LEAD',
#  ')',
#  'Local',
#  'streaming',
#  'service',
#  'provider',
#  'Wavve',
#  'tops',
#  '10',
#  'mln',
#  'subscribers',
#  'https://t.co/lMjK4fxRK4',
#  '\n',
#  '언젠가',
#  '꼭',
#  '가보고싶',
#  '읏',
#  '톈샨산맥',
#  '과',
#  '샹글릴',
#  '라',
#  '!!',
#  '\n',
#  '125회',
#  '트레킹',
#  '노트',
#  '세상',
#  '을',
#  '걷다',
#  '\n',
#  '웨이브',
#  '는',
#  '...',
#  '너무',
#  '사용',
#  '하기',
#  '불편하던데',
#  '...',
#  '팝업',
#  '왔다',
#  '갔다',
#  '하다',
#  '보면',
#  '재생',
#  '초기',
#  '화',
#  '되고',
#  'ㅡㅡ',
#  ';',
#  '심지어',
#  '작품',
#  '소개',
#  '글',
#  '도',
#  '없고',
#  '..',
#  '\n',
#  '@Xo_Hooon',
#  '왜',
#  '샀어',
#  'ㅠㅠㅠㅠㅠ',
#  '나',
#  '웨이브',
#  '쓰고있',
#  '눈데',
#  '\n',
#  '@WOOZI_zini',
#  '혹시',
#  '엠카',
#  '투표',
#  '는',
#  '엠',
#  '웨이브',
#  '랑',
#  '지니',
#  '중',
#  '에',
#  '하나로',
#  '하면',
#  '되나요',
#  '?',
#  '\n',
#  'RT',
#  '@iamfanboyforbw',
#  ':',
#  '윈',
#  '이',
#  '특집',
#  '-',
#  '(',
#  '틱톡',
#  '주의',
#  ')',
#  '\n',
#  'RT',
#  '@MasterWhite18',
#  ':',
#  '@turkeyfiend',
#  '@Hanwoo_of_TX',
#  '122',
#  '가',
#  '뭡',
#  '니까',
#  '.',
#  '미국',
#  '조금',
#  '이라도',
#  '빠지는',
#  '각',
#  '나오면',
#  '기갑',
#  '웨이브',
#  '가',
#  '...',
#  '\n',
#  '#One_To_All',
#  '#ILLUSION',
#  '#WAVE',
#  '#ATEEZ',
#  '#에이티즈',
#  '\n',
#  'RT',
#  '@taetae_Pteryong',
#  ':',
#  '웨이브',
#  '와',
#  '시스루',
#  '와',
#  '겟섬팍',
#  '....',
#  'ㅇㅁㅇ',
#  '!!!',
#  'https://t.co/U76NVzzU5P',
#  '\n',
#  'RT',
#  '@MHA_KR',
#  ':',
#  '#나의히어로아카데미아',
#  '#극장판',
#  '\n',
#  '#나의히어로아카데미아더무비',
#  '#히어로즈라이징',
#  '\n',
#  'VOD',
#  '최초',
#  '공개',
#  '절찬',
#  '서비스',
#  '중',
#  '!',
#  '\n',
#  'RT',
#  '@ATEEZofficial',
#  ':',
#  '[#윤호',
#  ']',
#  '웨이브',
#  '첫',
#  '방송',
#  '리허설',
#  '전',
#  '에',
#  '찍은',
#  '사진',
#  '~~????',
#  '\n',
#  '지민',
#  '이',
#  '는',
#  '웨이브',
#  '가',
#  '천천히',
#  '들어가서',
#  '마치',
#  '뒤',
#  '로',
#  '제',
#  '끼듯',
#  '보이',
#  '고',
#  '.',
#  '정국',
#  '이',
#  '는',
#  '정석',
#  '대로',
#  '안',
#  '으로',
#  '감아',
#  '.',
#  'ㅠ',
#  '\n',
#  '너',
#  '네',
#  '너무',
#  '굿',
#  '~',
#  '믹스',
#  '매치',
#  '..??',
#  '\n',
#  '@simnalamburt',
#  '한국',
#  '은',
#  '티빙',
#  '이나',
#  '웨이브',
#  '로',
#  '되던',
#  '기능',
#  '이',
#  '죠',
#  '.',
#  'UI',
#  '는',
#  '잘',
#  '만들었어요',
#  '.',
#  'Fox',
#  'TV',
#  'VP',
#  '아저씨',
#  '몇',
#  '년전',
#  '에',
#  '만났을',
#  '때',
#  '저',
#  '딜',
#  '관련',
#  '되서',
#  '이야기',
#  '들었는데',
#  '구글',
#  '이',
#  '계약',
#  '하는라',
#  '고생',
#  '꽤',
#  '나',
#  '했더군요',
#  '.',
#  '\n',
#  '백현',
#  '이',
#  '예능',
#  '넘',
#  '넘',
#  '잘',
#  '하구',
#  "?'?'?",
#  '10월',
#  '되면',
#  '바로',
#  '웨이브',
#  '결제',
#  '해서',
#  '엠',
#  '토피아',
#  '봐야지',
#  '!!',
#  'https://t.co/OGCzNqHsJZ',
#  '\n',
#  '@Belita_0105',
#  '웨이브',
#  '앱',
#  '에서',
#  '볼수',
#  '있어요',
#  '!',
#  '\n',
#  '와',
#  '나',
#  '진촤',
#  '오늘',
#  '민윤기',
#  '시스루',
#  '와',
#  '진짜',
#  '미쳐',
#  '블랙스완',
#  '+',
#  '시스루',
#  '+',
#  '웨이브',
#  '+',
#  '민윤기',
#  '=',
#  '환',
#  '장',
#  '의',
#  '조합',
#  'https://t.co/WA5Wr6rlcm',
#  '\n',
#  '이번',
#  '추석',
#  '엔',
#  '바클라바',
#  '를',
#  '사다',
#  '먹으며',
#  '위대한',
#  '세기',
#  '를',
#  '집',
#  '에서',
#  '보고',
#  '싶은데',
#  '...',
#  '\n',
#  '왜',
#  '왓챠',
#  ...]

# %%
ko = nltk.Text(tokens_ko)
ko.vocab().most_common(100)    # 가장 많이 나온 단어 100개
# Out:
# [('\n', 257),
#  ('웨이브', 165),
#  ('.', 64),
#  ('이', 58),
#  ('에', 47),
#  ('는', 43),
#  (':', 41),
#  ('가', 40),
#  (',', 30),
#  ('RT', 29),
#  ('를', 27),
#  ('…', 27),
#  ('로', 27),
#  ('도', 27),
#  ('?', 26),
#  ('...', 26),
#  ('??', 24),
#  ('-', 24),
#  ('..', 23),
#  ('을', 22),
#  ('나', 22),
#  ('의', 21),
#  ('에서', 20),
#  ('!', 20),
#  ('은', 18),
#  ('와', 18),
#  ('잘', 17),
#  ('안', 17),
#  ('넷플릭스', 17),
#  ('\r\n', 17),
#  ('내', 15),
#  ('티빙', 15),
#  ('하고', 15),
#  ('요', 15),
#  ('결제', 15),
#  ('못', 14),
#  ('(', 14),
#  ('너무', 14),
#  ('부터', 13),
#  ("'", 13),
#  (')', 13),
#  ('에이', 13),
#  ('으로', 13),
#  (';', 13),
#  ('들', 12),
#  (']', 12),
#  ('때', 12),
#  ('2', 12),
#  ('wavve', 12),
#  ('오늘', 11),
#  ('할', 11),
#  ('만', 11),
#  ('랑', 11),
#  ('드라마', 11),
#  ('하는', 10),
#  ('1', 10),
#  ('사랑', 10),
#  ('티니', 10),
#  ('????', 10),
#  ('저', 10),
#  ('구독', 10),
#  ('근데', 10),
#  ('넷플', 10),
#  ('....', 9),
#  ('다', 9),
#  ('전', 9),
#  ('@ATEEZofficial', 9),
#  ('중', 9),
#  ('뭐', 9),
#  ('좀', 9),
#  ('볼', 9),
#  ('!!', 9),
#  ('제', 9),
#  ('화', 9),
#  ('&', 9),
#  ('것', 9),
#  ('왜', 9),
#  ('왓챠', 9),
#  ('|', 9),
#  ('3', 8),
#  ('과', 8),
#  ('다시', 8),
#  ('보고', 8),
#  ('ㅠ', 8),
#  ('야', 8),
#  ('ㅠㅠ', 8),
#  ('한', 8),
#  ('고', 7),
#  ('~', 7),
#  ('첫', 7),
#  ('수', 7),
#  ('서', 7),
#  ('ㅋㅋㅋ', 7),
#  ('영화', 7),
#  ('더', 7),
#  ('아이디', 7),
#  ('달', 7),
#  ('있음', 7),
#  ('인', 6),
#  ('거', 6)]

# %%
# 불용어 : 인터넷 검색 시 검색 용어로 사용하지 않는 단어. 관사, 전치사, 조사, 접속사 등 검색 색인 단어로 의미가 없는 단어
stop_words = [')','?','1','"(', '_', ')/','\n','.',',', '<','!','(','(', '??','..', '4', '|', '>', '?(', '"…', '#', '&', '・', "']",'.',' ','/',"'",'’','”','“','·', '[','!','\n','·','‘','"','\n ',']',':','…',')','(','-', 'nan','가','요','답변','...','을','수','에','질문','제','를','이','도',
                      '좋','1','는','로','으로','2','것','은','다',',','니다','대','들',
                      '2017','들','데','..','의','때','겠','고','게','네요','한','일','할',
                      '10','?','하는','06','주','려고','인데','거','좀','는데','~','ㅎㅎ',
                      '하나','이상','20','뭐','까','있는','잘','습니다','다면','했','주려',
                      '지','있','못','후','중','줄','6','과','어떤','기본','!!',
                      '단어','라고','중요한','합','가요','....','보이','네','무지']

tokens_ko = [each_word for each_word in tokens_ko
             if each_word not in stop_words]

ko = nltk.Text(tokens_ko)
ko.vocab().most_common(100)
# Out:
# [('웨이브', 165),
#  ('RT', 29),
#  ('나', 22),
#  ('에서', 20),
#  ('와', 18),
#  ('안', 17),
#  ('넷플릭스', 17),
#  ('\r\n', 17),
#  ('내', 15),
#  ('티빙', 15),
#  ('하고', 15),
#  ('결제', 15),
#  ('너무', 14),
#  ('부터', 13),
#  ('에이', 13),
#  (';', 13),
#  ('wavve', 12),
#  ('오늘', 11),
#  ('만', 11),
#  ('랑', 11),
#  ('드라마', 11),
#  ('사랑', 10),
#  ('티니', 10),
#  ('????', 10),
#  ('저', 10),
#  ('구독', 10),
#  ('근데', 10),
#  ('넷플', 10),
#  ('전', 9),
#  ('@ATEEZofficial', 9),
#  ('볼', 9),
#  ('화', 9),
#  ('왜', 9),
#  ('왓챠', 9),
#  ('3', 8),
#  ('다시', 8),
#  ('보고', 8),
#  ('ㅠ', 8),
#  ('야', 8),
#  ('ㅠㅠ', 8),
#  ('첫', 7),
#  ('서', 7),
#  ('ㅋㅋㅋ', 7),
#  ('영화', 7),
#  ('더', 7),
#  ('아이디', 7),
#  ('달', 7),
#  ('있음', 7),
#  ('인', 6),
#  ('프리미엄', 6),
#  ('하루', 6),
#  ('이번', 6),
#  ('lt', 6),
#  ('토피아', 6),
#  ('함', 6),
#  ('보기', 6),
#  ('이런', 6),
#  ('시간', 6),
#  ('에는', 6),
#  ('일단', 5),
#  ('ㅋㅋㅋㅋㅋ', 5),
#  ('10월', 5),
#  ('출범', 5),
#  ('이미', 5),
#  ('#ATEEZ', 5),
#  ('#에이티즈', 5),
#  ('계속', 5),
#  ('아', 5),
#  ('그', 5),
#  ('또', 5),
#  ('국내', 5),
#  ('한테', 5),
#  ('티', 5),
#  ('밖에', 5),
#  ('혹시', 5),
#  ('사용', 5),
#  ('작품', 5),
#  ('하면', 5),
#  ('공개', 5),
#  ('해서', 5),
#  ('추석', 5),
#  ('시즌', 5),
#  ('정말', 5),
#  ('적', 5),
#  ('gt', 5),
#  ('입니다', 4),
#  ('자', 4),
#  ('된', 4),
#  ('동영상', 4),
#  ('플랫폼', 4),
#  ('1000만', 4),
#  ('성장', 4),
#  ('서비스', 4),
#  ('일루젼', 4),
#  ('봐', 4),
#  ('요즘', 4),
#  ('되서', 4),
#  ('TV', 4),
#  ('아마존', 4),
#  ('지금', 4)]

# %%
content_new=[]
for i in range(len(df)):
    content_new.append(str(df["content"][i]))
content_new[:1]
df["content_new"]=content_new

# %%
import re 
# '한글'을 제외한 다른 문자 모두 제거
remove_except_ko = re.compile(r"[^가-힣ㄱ-ㅎㅏ-ㅣ\\s|A-Za-z]")
def preprocess(text):
    text = re.sub(remove_except_ko,' ',text).strip()
    return text

df['clean_doc'] = df['content_new'].map(lambda x : preprocess(x))
df.head(5)
# Out:
#                                              content  \
# 0           @yitian_L: 비주얼합 쩔고 티키타카는 덤인 민국기탐 plz....
# 1                                       일단 수입부터.....
# 2                                   #중드맛집_웨이브_지금_영업중
# 3  #路? #民?奇探 #HuYiTian #胡一天 #호일천 https://t.co/qZw...
# 4  @wavve_official 중드 여주는 성격이 다 똑같아...눈 희번득 뜨는 거는...
#
#                                          content_new  \
# 0           @yitian_L: 비주얼합 쩔고 티키타카는 덤인 민국기탐 plz....
# 1                                       일단 수입부터.....
# 2                                   #중드맛집_웨이브_지금_영업중
# 3  #路? #民?奇探 #HuYiTian #胡一天 #호일천 https://t.co/qZw...
# 4  @wavve_official 중드 여주는 성격이 다 똑같아...눈 희번득 뜨는 거는...
#
#                                            clean_doc
# 0                yitian L  비주얼합 쩔고 티키타카는 덤인 민국기탐 plz
# 1                                            일단 수입부터
# 2                                    중드맛집 웨이브 지금 영업중
# 3         HuYiTian       호일천 https   t co qZwRRnbJ q
# 4  wavve official 중드 여주는 성격이 다 똑같아   눈 희번득 뜨는 거는 ...

# %%
from konlpy.tag import Okt
m=Okt()

# %%
stop_word = [')','?','1','"(', '_', ')/','\n','.',',', '<','!','(','(', '??','..', '4', '|', '>', '?(', '"…', '#', '&', '・', "']",'.',' ','/',"'",'’','”','“','·', '[','!','\n','·','‘','"','\n ',']',
             ':','…',')','(','-', 'nan','가','요','답변','...','을','수','에','질문','제','를','이','도','좋','1','는','로','으로','2','것','은','다',',','니다','대','들',
            '2017','들','데','..','의','때','겠','고','게','네요','한','일','할','10','?','하는','06','주','려고','인데','거','좀','는데','~','ㅎㅎ',
             '하나','이상','20','뭐','까','있는','잘','습니다','다면','했','주려','지','있','못','후','중','줄','6','과','어떤','기본','!!',
             '단어','라고','중요한','합','가요','....','보이','네','무지','안녕하세요','께서','에서','이다','에게','으로','이랑','까지','부터','하다','습니다','https','com',')',
             '?','1','"(', '_', ')/','\n','.',',', '<','!','(','(', '??','..', '4', '|', '>', '?(', '"…', '#', 
             '&', '・', "']",'.',' ','/',"'",'’','”','“','·', '[','!','\n','·','‘','"','\n ',']',':','…',')',
             '(','-', 'nan','가','요','답변','...','을','수','에','질문','제','를','이','도',
             '좋','1','는','로','으로','2','것','은','다',',','니다','대','들',
             '2017','들','데','..','의','때','겠','고','게','네요','한','일','할',
             '10','?','하는','06','주','려고','인데','거','좀','는데','~','ㅎㅎ','때문','없어',
             '하나','이상','20','뭐','까','있는','잘','습니다','다면','했','주려','되어','하면','싶어서','미하','Name','FSNsL','했는데','먼저','이고','만에','읽혀','Ht','dtype','있다고밖엔','클리어','co','보다','않음',
             '지','있','못','후','중','줄','6','과','어떤','기본','!!','에서','나','만','안','아','라','왜','더','같지',
             '단어','라고','중요한','합','가요','....','보이','네','무지','께서','에서','이다','에게','으로','이랑','까지','부터','하다','습니다','https','com',
            '안녕','수목','이루어지','새로이','이것','비디오','컨텐츠','배경','이용권','배경','재밌','형식','이벤트','결합','드디어',
             '근래','차일피일','우리','하세','oksus','끝나','코로나','모드','세포','보시','이야기','맞추','po','Name','작품','추석','빙상','준비',
             '언급','포함','많이','무료','보내','찾아오','부가','챙기','오늘','소비','진행','모든','oksusu','이미', '자기','관심','방송','서비스','통하','배우',
             '오랜만','스마트','모아','제공','챙기','시간','dtype','부가세','통하','오랜만','계시','소개','정말','아니','기웃거','따지','보리','진행하',
             '보내','이렇','안되','두고','끝나','다라','까먹','돌리'',ㅠㅠ,''남기','오랜만','안녕','유독','진행하','다음주','과의','아름','까먹','kcl','이렇',
             '진짜','쐐면','오진','그러','반하','정말','독하','금인','몸살','지나','미리','세사','abject','naver','다가오','그동안','나중','그렇','아쉽','이리',
             '여리','갈대','직무','바로','예방','보리','주사','독감','대통령','기준','돌리','요즘','얼마','미리','렌즈','갈대','아름','문제','결국','드디어','못하','하세','ㅠㅠ',
             'Length','tokens','ㅎㅎ','ㅋㅋㅋ','고르','그렇','평소','진짜','이후','다시','즐기','비교','높이','이렇','보통','object','챙기','기사','엄청','고민','vs','dtype','현재',
             '안녕','Name','알아보','바벨','바디','진행','여러분','와이','하자','그렇','어느','앳되','끝내','이런','해소','해보','직전','말하','얼마','질리','확인','울리','기다리','한지','누르',
             '빠지','궁금하','ㅠㅠ','요금','버튼','하기','경보','저번','저의','하세','크리','알아보','직전','오래되','일보','object','dtype','Name','Length','JJ','dtype','Name','squale','youtu',
             '그동안','length','Play','KIMU','object','net','그동안','ㅋㅋㅋ','status','hwanair','saintpain','andy','ndminialbum','weibo','twitter',
             'theqoo','XHhni','나의','안녕', 'tokens','KrXOnM','Length','대해','becici','Staff','이야','텐데요','궁금하셨을','MqlklfFGR','입니다','tfZee',
            'tFZee','해줘요','하신거라','정액', '풀어주세요','lunamoth','RT','걸려서','중딩','onj','이에요','rSWFad','에요','WGWorldCafe','nouk','만이','MAU','BUiAOYLWhN','HcozccBu',
            '야하는','에도','없어서','몰라도','이라도','분만','인지','싶은게','메이','기는데','할수','이나','해주세요','yitian','qZwRRnbj','민국','얼합']

stopPos = ['JKS','JKC','JKG','JKO','JKM','JKI','JKQ','JC','JX','EPH','EPT'
           ,'EPP','EFN','EFQ','EFO','EFA','EFI','EFR','ECE','ECS','ECD','ETN','ETD','XPN','XPV',
            'XSN','XSV','XSA','XR','SF','SE','SS','SP','SO','SW','OH','ON','UN','MAC',"NNB","NNM","VXV","VV"]
def token_mecab(text):
    text = m.pos(text)
    text = [i for i in text if len(i[0])>1]
    text = [i for i in text if i[0] not in stop_word]
    text = [i[0] for i in text if i[1] not in stopPos]
    return text

# %%
df.head(5)
# Out:
#                                              content  \
# 0           @yitian_L: 비주얼합 쩔고 티키타카는 덤인 민국기탐 plz....
# 1                                       일단 수입부터.....
# 2                                   #중드맛집_웨이브_지금_영업중
# 3  #路? #民?奇探 #HuYiTian #胡一天 #호일천 https://t.co/qZw...
# 4  @wavve_official 중드 여주는 성격이 다 똑같아...눈 희번득 뜨는 거는...
#
#                                          content_new  \
# 0           @yitian_L: 비주얼합 쩔고 티키타카는 덤인 민국기탐 plz....
# 1                                       일단 수입부터.....
# 2                                   #중드맛집_웨이브_지금_영업중
# 3  #路? #民?奇探 #HuYiTian #胡一天 #호일천 https://t.co/qZw...
# 4  @wavve_official 중드 여주는 성격이 다 똑같아...눈 희번득 뜨는 거는...
#
#                                            clean_doc  \
# 0                yitian L  비주얼합 쩔고 티키타카는 덤인 민국기탐 plz
# 1                                            일단 수입부터
# 2                                    중드맛집 웨이브 지금 영업중
# 3         HuYiTian       호일천 https   t co qZwRRnbJ q
# 4  wavve official 중드 여주는 성격이 다 똑같아   눈 희번득 뜨는 거는 ...
#
#                                           tokens
# 0                                 비주 쩔고 티키타카 plz
# 1                                          일단 수입
# 2                                    중드 맛집 지금 영업
# 3                           HuYiTian 호일 qZwRRnbJ
# 4  official 중드 여주 성격 똑같아 번득 뜨는 누가 일부러 가르치나 ㅋㅋㅋㅋㅋ

# %%
# 토큰화 + 토큰리스트 생성 
def make_tokens(df):
    df['tokens'] = ''
    tokens_list=[]
    for i, row in df.iterrows():
        if i%10000==0:
            print(i,'/',len(df))
        token = token_mecab(df['clean_doc'][i])
        df['tokens'][i] = ' '.join(token)
    return df

# %%
df = make_tokens(df)
# Out:
# 0 / 273

# %%
df.head(3)
# Out:
#                                     content  \
# 0  @yitian_L: 비주얼합 쩔고 티키타카는 덤인 민국기탐 plz....
# 1                              일단 수입부터.....
# 2                          #중드맛집_웨이브_지금_영업중
#
#                                 content_new  \
# 0  @yitian_L: 비주얼합 쩔고 티키타카는 덤인 민국기탐 plz....
# 1                              일단 수입부터.....
# 2                          #중드맛집_웨이브_지금_영업중
#
#                              clean_doc           tokens
# 0  yitian L  비주얼합 쩔고 티키타카는 덤인 민국기탐 plz   비주 쩔고 티키타카 plz
# 1                              일단 수입부터            일단 수입
# 2                      중드맛집 웨이브 지금 영업중  중드 맛집 웨이브 지금 영업

# %%
tokenized_doc=df["tokens"].apply(lambda x: x.split());tokenized_doc
tokenized_docs=tokenized_doc.apply(lambda x : ' '.join ([item for item in x if item not in stop_word]))

# %%
type(tokenized_docs)
# Out:
# pandas.core.series.Series

# %%
from wordcloud import WordCloud

# %%
df["tokens"]
# Out:
# 0                                         비주 쩔고 티키타카 plz
# 1                                                  일단 수입
# 2                                        중드 맛집 웨이브 지금 영업
# 3                                   HuYiTian 호일 qZwRRnbJ
# 4      wavve official 중드 여주 성격 똑같아 번득 뜨는 누가 일부러 가르치나 ...
#                              ...
# 268                                     웨이브 찾아보니까 밖에 없던데
# 269                                          혹시 중간 짤린 건가
# 270                                           웨이브 하겠네 lt
# 271       웨이브 너무 사용 불편하던데 팝업 왔다 갔다 보면 재생 초기 되고 ㅡㅡ 심지어 없고
# 272                         Xo Hooon 샀어 ㅠㅠㅠㅠㅠ 웨이브 쓰고있 눈데
# Name: tokens, Length: 273, dtype: object

# %%
for i in range(len(df)):
    b=str(df['tokens'])

# %%
b
# Out:
# '0                                         비주 쩔고 티키타카 plz\n1                                                  일단 수입\n2                                        중드 맛집 웨이브 지금 영업\n3                                   HuYiTian 호일 qZwRRnbJ\n4      wavve official 중드 여주 성격 똑같아 번득 뜨는 누가 일부러 가르치나 ...\n                             ...                        \n268                                     웨이브 찾아보니까 밖에 없던데\n269                                          혹시 중간 짤린 건가\n270                                           웨이브 하겠네 lt\n271       웨이브 너무 사용 불편하던데 팝업 왔다 갔다 보면 재생 초기 되고 ㅡㅡ 심지어 없고\n272                         Xo Hooon 샀어 ㅠㅠㅠㅠㅠ 웨이브 쓰고있 눈데\nName: tokens, Length: 273, dtype: object'

# %%
wordcloud = WordCloud(font_path='malgun.ttf',max_font_size=100,background_color='white').generate(b)

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(13,13))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)
