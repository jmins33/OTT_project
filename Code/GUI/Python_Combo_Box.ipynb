# %% [markdown]
# <a href="https://colab.research.google.com/github/jmins33/OTT_project/blob/master/Code/GUI/Python_Combo_Box.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # references
#
# - ref: https://076923.github.io/posts/Python-tkinter-26/
# - ref: http://blog.naver.com/PostView.nhn?blogId=sisosw&logNo=221411999658&parentCategoryNo=&categoryNo=13&viewDate=&isShowPopularPosts=true&from=search
#
#
# - 알고리즘 부여 ref: https://neverendinglearning.tistory.com/29
# - https://stackoverflow.com/questions/41522427/get-combobox-value-in-python
# - ref: https://hcr3066.tistory.com/96 (그래픽 넣기)
# - matplotlib graph 넣기
# - ref: https://matplotlib.org/3.1.0/gallery/user_interfaces/embedding_in_tk_sgskip.html
#
# - ref: https://blog.naver.com/sisosw/221411972022  (Canvas 넣기)

# %% [markdown]
# # GUI 구현 - 화면 구성
# - 알고리즘 적용 전 밑작업

# %% [markdown]
# # 알고리즘과 합치기 -- Real

# %%
# GUI 구현
from tkinter import *
from tkinter import ttk 
from tkinter import Tk
from tkinter import messagebox
from PIL import ImageTk, Image
import matplotlib.pyplot as plt
import pandas as pd
from pandas import DataFrame, Series


import matplotlib
import matplotlib.font_manager as fm
fm.get_fontconfig_fonts()
# font_location = '/usr/share/fonts/truetype/nanum/NanumGothicOTF.ttf'
font_location = 'C:/Windows/Fonts/malgun.ttf' # For Windows
font_name = fm.FontProperties(fname=font_location).get_name()
matplotlib.rc('font', family=font_name)
plt.rcParams["figure.figsize"]=(12,6)
plt.rcParams['font.size']=20

# TK 객체 인스턴스 생성하기
root=Tk()
root.title("나에게 맞는 OTT 서비스는?")
root.geometry("700x350")
root.configure(background='#EBD0F5')
root.resizable(True,True)


#콤보 1- 1순위
items_contents=["아이돌","지상파","독립영화","스포츠 중계","종편 및 CJ ENM"]

label1=Label(root, text="선호하는 장르 1순위는?(중복 선택 가능)", foreground="black", background='#EBD0F5')
label1.grid(row=0, column=0)

combobox1=ttk.Combobox(root, width=50, height=10, values=items_contents)
combobox1.set("선택")
combobox1.grid(row=0, column=1)

#콤보 2 -2순위
items_contents=["아이돌","지상파","독립영화","스포츠 중계","종편 및 CJ ENM"]

label2=Label(root, text="선호하는 장르 2순위는?(중복 선택 가능)",foreground="black",background='#EBD0F5')
label2.grid(row=1, column=0)

combobox2=ttk.Combobox(root, width=50, height=10, values=items_contents)
combobox2.set("선택")
combobox2.grid(row=1, column=1)

#콤보 3 -3순위
items_contents=["아이돌","지상파","독립영화","스포츠 중계","종편 및 CJ ENM"]

label3=Label(root, text="선호하는 장르 3순위는?(중복 선택 가능)",foreground="black",background='#EBD0F5')
label3.grid(row=2, column=0)

combobox3=ttk.Combobox(root, width=50, height=10, values=items_contents)
combobox3.set("선택")
combobox3.grid(row=2, column=1)

###########
# 콤보 4 다음 예시 중 보고 싶은 컨텐츠가 많은 보기를 골라주세요

items_contents_spec=["보건교사 안은영, 킹덤, 인간수업, 기묘한 이야기, 옥자",
                     "킬링 이브, 와이우먼킬, 이어즈&이어즈. 왕좌의 게임, 체르노빌",
                     "원앤투, 괜찮아요 프리랜서, 킹 리어, 신의 나라, 더 저니",
                     "녹두전, SF8, 앨리스, 좀비탐정, 나의 위험한 아내",
                     "놓지마 정신줄, 썸툰2020, 인어왕자, 김요한 이야기, 우웅우웅2"]

label4=Label(root, text="다음 예시 중 보고 싶은 컨텐츠가 많은 보기를 골라주세요",foreground="black",background='#EBD0F5')
label4.grid(row=3, column=0)

combobox4=ttk.Combobox(root, width=50, height=10, values=items_contents_spec)
combobox4.set("선택")
combobox4.grid(row=3, column=1)

###########

# 콤보 5 가격 탄력성 조사
items_price=["1","2","3","4","5"]

label5=Label(root, text="가격에 민감한 정도를 골라주세요(1~5점 사이)",foreground="black",background='#EBD0F5')
label5.grid(row=4, column=0)

combobox5=ttk.Combobox(root, width=50, height=10, values=items_price)
combobox5.set("선택")
combobox5.grid(row=4, column=1)

#콤보 6 -통신사
items_tel=["SKT","KT","LGU+"]

label6=Label(root, text="통신사가 어디입니까?",foreground="black",background='#EBD0F5')
label6.grid(row=5, column=0)

combobox6=ttk.Combobox(root, width=50, height=10, values=items_tel)
combobox6.set("선택")
combobox6.grid(row=5, column=1)

# 콤보 7 - 리뷰 열람
items_review=["Y","N"]

label7=Label(root, text="리뷰 열람하기를 좋아하십니까?",foreground="black",background='#EBD0F5')
label7.grid(row=6, column=0)

combobox7=ttk.Combobox(root, width=50, height=10, values=items_review)
combobox7.set("선택")
combobox7.grid(row=6, column=1)

# 콤보 8 - 추천서비스
items_recommend=["Y","N"]

label8=Label(root, text="개인 맞춤형 추천/분석서비스를 원하십니까?",foreground="black",background='#EBD0F5')
label8.grid(row=7, column=0)

combobox8=ttk.Combobox(root, width=50, height=10, values=items_recommend)
combobox8.set("선택")
combobox8.grid(row=7, column=1)

# 콤보 9 - 한국어자막
items_Korean=["Y","N"]

label9=Label(root, text="한국어 자막을 원하십니까?",foreground="black",background='#EBD0F5')
label9.grid(row=8, column=0)

combobox9=ttk.Combobox(root, width=50, height=10, values=items_Korean)
combobox9.set("선택")
combobox9.grid(row=8, column=1)

# 콤보 10 - 영어자막
items_flg=["Y","N"]

label10=Label(root, text="영어 자막을 원하십니까?",foreground="black",background='#EBD0F5')
label10.grid(row=9, column=0)

combobox10=ttk.Combobox(root, width=50, height=10, values=items_flg)
combobox10.set("선택")
combobox10.grid(row=9, column=1)

###########
# 콤보 11 아이와 함께 OTT 플랫폼을 이용하십니까?

items_kids=["Y","N"]

label11=Label(root, text="아이와 함께 OTT 플랫폼을 이용하십니까?",foreground="black",background='#EBD0F5')
label11.grid(row=10, column=0)

combobox11=ttk.Combobox(root, width=50, height=10, values=items_kids)
combobox11.set("선택")
combobox11.grid(row=10, column=1)

# 콤보 12 성별을 골라주세요
items_sex=["여성","남성"]

label12=Label(root, text="성별을 골라주세요",foreground="black",background='#EBD0F5')
label12.grid(row=11, column=0)

combobox12=ttk.Combobox(root, width=50, height=10, values=items_sex)
combobox12.set("선택")
combobox12.grid(row=11, column=1)

# 콤보 13 연령대를 골라주세요(만 나이)
items_age=["0-11","12-18","19-29",'30-39','40-49','50-59','60-']

label13=Label(root, text="연령대를 골라주세요(만 나이)",foreground="black",background='#EBD0F5')
label13.grid(row=12, column=0)

combobox13=ttk.Combobox(root, width=50, height=10, values=items_age)
combobox13.set("선택")
combobox13.grid(row=12, column=1)

###########

# # 화면배치
# # 콤보 last - mbti

# items_mbti=["INFJ, INFP, ENFP, ENFJ",
# "ISTP, ISFP, ESTP, ESFP",
# "ISTJ, ISFJ, ESTJ, ESFJ",
# "INTJ, INTP, ENTP, ENTJ"]

# label14=Label(root, text="다음 중 당신의 mbti를 골라주세요",foreground="black",background='#EBD0F5')
# label14.grid(row=13, column=0)

# combobox14=ttk.Combobox(root, width=50, height=10, values=items_mbti)
# combobox14.set("선택")
# combobox14.grid(row=13, column=1)


def score_contents():   #점수 가져오게 하는 함수
    score_watcha_contents = 0
    score_netflix_contents = 0
    score_wavve_contents = 0
    score_seezn_contents = 0
    score_tiving_contents = 0
    result_contents=[]
    
## 질문 1 -- 1순위

    if combobox1.get() == "아이돌":
        score_watcha_contents += 0
        result_contents.append(score_watcha_contents)
        score_netflix_contents += 0
        result_contents.append(score_netflix_contents)
        score_wavve_contents = 3.5
        result_contents.append(score_wavve_contents)
        score_seezn_contents += 5
        result_contents.append(score_seezn_contents)
        score_tiving_contents += 2
        result_contents.append(score_tiving_contents)

    elif combobox1.get() == "지상파":
        score_watcha_contents += 0
        result_contents.append(score_watcha_contents)
        score_netflix_contents += 0
        result_contents.append(score_netflix_contents)
        score_wavve_contents += 5
        result_contents.append(score_wavve_contents)
        score_seezn_contents += 0
        result_contents.append(score_seezn_contents)
        score_tiving_contents += 0
        result_contents.append(score_tiving_contents)

    elif combobox1.get() == "독립영화":
        score_watcha_contents += 4
        result_contents.append(score_watcha_contents)
        score_netflix_contents += 0
        result_contents.append(score_netflix_contents)
        score_wavve_contents += 5
        result_contents.append(score_wavve_contents)
        score_seezn_contents += 3
        result_contents.append(score_seezn_contents)
        score_tiving_contents += 0
        result_contents.append(score_tiving_contents)

    elif combobox1.get() == "스포츠 중계":
        score_watcha_contents += 0
        result_contents.append(score_watcha_contents)
        score_netflix_contents += 0
        result_contents.append(score_netflix_contents)
        score_wavve_contents += 4
        result_contents.append(score_wavve_contents)
        score_seezn_contents += 3
        result_contents.append(score_seezn_contents)
        score_tiving_contents += 0
        result_contents.append(score_tiving_contents)

    elif combobox1.get() == "종편 및 CJ ENM":
        score_watcha_contents += 0
        result_contents.append(score_watcha_contents)
        score_netflix_contents += 0
        result_contents.append(score_netflix_contents)
        score_wavve_contents += 0
        result_contents.append(score_wavve_contents)
        score_seezn_contents += 0
        result_contents.append(score_seezn_contents)
        score_tiving_contents += 5
        result_contents.append(score_tiving_contents)

# 질문 2 -- 2순위
    score_watcha_contents2 = 0
    score_netflix_contents2 = 0
    score_wavve_contents2 = 0
    score_seezn_contents2 = 0
    score_tiving_contents2 = 0
    result_contents2=[]
    
    if combobox2.get() == "아이돌":
        score_watcha_contents2 += 0
        result_contents2.append(score_watcha_contents2)
        score_netflix_contents2 += 0
        result_contents2.append(score_netflix_contents2)
        score_wavve_contents2 += 2.5
        result_contents2.append(score_wavve_contents2)
        score_seezn_contents2 += 4
        result_contents2.append(score_seezn_contents2)
        score_tiving_contents2 += 1
        result_contents2.append(score_tiving_contents2)

    elif combobox2.get() == "지상파":
        score_watcha_contents2 += 0
        result_contents2.append(score_watcha_contents2)
        score_netflix_contents2 += 0
        result_contents2.append(score_netflix_contents2)
        score_wavve_contents2 += 4
        result_contents2.append(score_wavve_contents2)
        score_seezn_contents2 += 0
        result_contents2.append(score_seezn_contents2)
        score_tiving_contents2 += 0
        result_contents2.append(score_tiving_contents2)

    elif combobox2.get() == "독립영화":
        score_watcha_contents2 += 3
        result_contents2.append(score_watcha_contents2)
        score_netflix_contents2 += 0
        result_contents2.append(score_netflix_contents2)
        score_wavve_contents2 += 4
        result_contents2.append(score_wavve_contents2)
        score_seezn_contents2 += 2
        result_contents2.append(score_seezn_contents2)
        score_tiving_contents2 += 0
        result_contents2.append(score_tiving_contents2)

    elif combobox2.get() == "스포츠 중계":
        score_watcha_contents2 += 0
        result_contents2.append(score_watcha_contents2)
        score_netflix_contents2 += 0
        result_contents2.append(score_netflix_contents2)
        score_wavve_contents2 += 3
        result_contents2.append(score_wavve_contents2)
        score_seezn_contents2 += 2
        result_contents2.append(score_seezn_contents2)
        score_tiving_contents2 += 0
        result_contents2.append(score_tiving_contents2)

    elif combobox2.get() == "종편 및 CJ ENM":
        score_watcha_contents2 += 0
        result_contents2.append(score_watcha_contents2)
        score_netflix_contents2 += 0
        result_contents2.append(score_netflix_contents2)
        score_wavve_contents2 += 0
        result_contents2.append(score_wavve_contents2)
        score_seezn_contents2 += 0
        result_contents2.append(score_seezn_contents2)
        score_tiving_contents2 += 4
        result_contents2.append(score_tiving_contents2)
# 질문 3 -- 3순위
    score_watcha_contents3 = 0
    score_netflix_contents3 = 0
    score_wavve_contents3 = 0
    score_seezn_contents3 = 0
    score_tiving_contents3 = 0
    result_contents3=[]
    
    if combobox3.get() == "아이돌":
        score_watcha_contents3 += 0
        result_contents3.append(score_watcha_contents3)
        score_netflix_contents3 += 0
        result_contents3.append(score_netflix_contents3)
        score_wavve_contents3 = 1.5
        result_contents3.append(score_wavve_contents3)
        score_seezn_contents3 += 3
        result_contents3.append(score_seezn_contents3)
        score_tiving_contents3 += 0
        result_contents3.append(score_tiving_contents3)

    elif combobox3.get() == "지상파":
        score_watcha_contents3 += 0
        result_contents3.append(score_watcha_contents3)
        score_netflix_contents3 += 0
        result_contents3.append(score_netflix_contents3)
        score_wavve_contents3 += 3
        result_contents3.append(score_wavve_contents3)
        score_seezn_contents3 += 0
        result_contents3.append(score_seezn_contents3)
        score_tiving_contents3 += 0
        result_contents3.append(score_tiving_contents3)

    elif combobox3.get() == "독립영화":
        score_watcha_contents3 += 2
        result_contents3.append(score_watcha_contents3)
        score_netflix_contents3 += 0
        result_contents3.append(score_netflix_contents3)
        score_wavve_contents3 += 3
        result_contents3.append(score_wavve_contents3)
        score_seezn_contents3 += 1
        result_contents3.append(score_seezn_contents3)
        score_tiving_contents3 += 0
        result_contents3.append(score_tiving_contents3)

    elif combobox3.get() == "스포츠 중계":
        score_watcha_contents3 += 0
        result_contents3.append(score_watcha_contents3)
        score_netflix_contents3 += 0
        result_contents3.append(score_netflix_contents3)
        score_wavve_contents3 += 2
        result_contents3.append(score_wavve_contents3)
        score_seezn_contents3 += 1
        result_contents3.append(score_seezn_contents3)
        score_tiving_contents3 += 0
        result_contents3.append(score_tiving_contents3)

    elif combobox3.get() == "종편 및 CJ ENM":
        score_watcha_contents3 += 0
        result_contents3.append(score_watcha_contents3)
        score_netflix_contents3 += 0
        result_contents3.append(score_netflix_contents3)
        score_wavve_contents3 += 0
        result_contents3.append(score_wavve_contents3)
        score_seezn_contents3 += 0
        result_contents3.append(score_seezn_contents3)
        score_tiving_contents3 += 3
        result_contents3.append(score_tiving_contents3)
        
# 질문 4 -- 다음 예시 중 보고 싶은 컨텐츠가 많은 보기를 골라주세요
    score_watcha_contents_spec = 0
    score_netflix_contents_spec = 0
    score_wavve_contents_spec = 0
    score_seezn_contents_spec = 0
    score_tiving_contents_spec = 0
    result_contents_spec=[]

    if combobox4.get() == "보건교사 안은영, 킹덤, 인간수업, 기묘한 이야기, 옥자":
        score_watcha_contents_spec += 0
        result_contents_spec.append(score_watcha_contents_spec)
        score_netflix_contents_spec += 3
        result_contents_spec.append(score_netflix_contents_spec)
        score_wavve_contents_spec += 1.5
        result_contents_spec.append(score_wavve_contents_spec)
        score_seezn_contents_spec += 0
        result_contents_spec.append(score_seezn_contents_spec)
        score_tiving_contents_spec += 0
        result_contents_spec.append(score_tiving_contents_spec)

    elif combobox4.get() == "킬링 이브, 와이우먼킬, 이어즈&이어즈. 왕좌의 게임, 체르노빌":
        score_watcha_contents_spec += 3
        result_contents_spec.append(score_watcha_contents_spec)
        score_netflix_contents_spec += 0
        result_contents_spec.append(score_netflix_contents_spec)
        score_wavve_contents_spec += 0
        result_contents_spec.append(score_wavve_contents_spec)
        score_seezn_contents_spec += 0
        result_contents_spec.append(score_seezn_contents_spec)
        score_tiving_contents_spec += 0
        result_contents_spec.append(score_tiving_contents_spec)

    elif combobox4.get() == "원앤투, 괜찮아요 프리랜서, 킹 리어, 신의 나라, 더 저니":
        score_watcha_contents_spec += 0
        result_contents_spec.append(score_watcha_contents_spec)
        score_netflix_contents_spec += 0
        result_contents_spec.append(score_netflix_contents_spec)
        score_wavve_contents_spec += 0
        result_contents_spec.append(score_wavve_contents_spec)
        score_seezn_contents_spec += 0
        result_contents_spec.append(score_seezn_contents_spec)
        score_tiving_contents_spec += 3
        result_contents_spec.append(score_tiving_contents_spec)

    elif combobox4.get() == "녹두전, SF8, 앨리스, 좀비탐정, 나의 위험한 아내":
        score_watcha_contents_spec += 0
        result_contents_spec.append(score_watcha_contents_spec)
        score_netflix_contents_spec += 0
        result_contents_spec.append(score_netflix_contents_spec)
        score_wavve_contents_spec += 3
        result_contents_spec.append(score_wavve_contents_spec)
        score_seezn_contents_spec += 0
        result_contents_spec.append(score_seezn_contents_spec)
        score_tiving_contents_spec += 0
        result_contents_spec.append(score_tiving_contents_spec)

    elif combobox4.get() == "놓지마 정신줄, 썸툰2020, 인어왕자, 김요한 이야기, 우웅우웅2":
        score_watcha_contents_spec += 0
        result_contents_spec.append(score_watcha_contents_spec)
        score_netflix_contents_spec += 0
        result_contents_spec.append(score_netflix_contents_spec)
        score_wavve_contents_spec += 0
        result_contents_spec.append(score_wavve_contents_spec)
        score_seezn_contents_spec += 3
        result_contents_spec.append(score_seezn_contents_spec)
        score_tiving_contents_spec += 0
        result_contents_spec.append(score_tiving_contents_spec)
        
# 질문 5 -- 가격에 민감한 정도를 골라주세요(1~5점 사이)  -- 6번과 연결
    score_price=0
    result_score_price=[]
    if combobox5.get() == "1":
        score_price+=0
        result_score_price.append(score_price)
    elif combobox5.get() == "2":
        score_price+=1
        result_score_price.append(score_price)  
    elif combobox5.get() == "3":
        score_price+=2
        result_score_price.append(score_price)  
    elif combobox5.get() == "4":
        score_price+=3
        result_score_price.append(score_price)  
    elif combobox5.get() == "5":
        score_price+=4
        result_score_price.append(score_price)
        
# 질문 6 -- 통신사가 어디입니까? cont'd 5
    score_watcha_tel = 0
    score_netflix_tel = 0
    score_wavve_tel = 0
    score_seezn_tel = 0
    score_tiving_tel = 0
    result_tel=[] 
    
    if combobox6.get() == "SKT":
        score_watcha_tel += 0
        result_tel.append(score_watcha_tel)
        score_netflix_tel += 0
        result_tel.append(score_netflix_tel)
        score_wavve_tel = result_score_price[0]
        result_tel.append(score_wavve_tel)
        score_seezn_tel += 0
        result_tel.append(score_seezn_tel)
        score_tiving_tel += 0
        result_tel.append(score_tiving_tel)
    elif combobox6.get() == "KT":
        score_watcha_tel += 0
        result_tel.append(score_watcha_tel)
        score_netflix_tel += 0
        result_tel.append(score_netflix_tel)
        score_wavve_tel += 0
        result_tel.append(score_wavve_tel)
        score_seezn_tel += result_score_price[0]
        result_tel.append(score_seezn_tel)
        score_tiving_tel += 0
        result_tel.append(score_tiving_tel)
    elif combobox6.get() == "LGU+":
        score_watcha_tel += 0
        result_tel.append(score_watcha_tel)
        score_netflix_tel += 0
        result_tel.append(score_netflix_tel)
        score_wavve_tel += 0
        result_tel.append(score_wavve_tel)
        score_seezn_tel += 0
        result_tel.append(score_seezn_tel)
        score_tiving_tel += 0
        result_tel.append(score_tiving_tel) 
    
# 질문 7 -- 리뷰 열람하기를 좋아하십니까?
    score_watcha_review = 0
    score_netflix_review = 0
    score_wavve_review = 0
    score_seezn_review = 0
    score_tiving_review = 0
    result_review=[] 
    
    if combobox7.get() == "Y":
        score_watcha_review += 4
        result_review.append(score_watcha_review)
        score_netflix_review += 0
        result_review.append(score_netflix_review)
        score_wavve_review += 0
        result_review.append(score_wavve_review)
        score_seezn_review += 0
        result_review.append(score_seezn_review)
        score_tiving_review += 0
        result_review.append(score_tiving_review)
        
    elif combobox7.get() == "N":
        score_watcha_review += 0
        result_review.append(score_watcha_review)
        score_netflix_review += 0
        result_review.append(score_netflix_review)
        score_wavve_review += 0
        result_review.append(score_wavve_review)
        score_seezn_review += 0
        result_review.append(score_seezn_review)
        score_tiving_review += 0
        result_review.append(score_tiving_review)

# 질문 8 -- 개인 맞춤형 추천/분석서비스를 원하십니까?
    score_watcha_recommend = 0
    score_netflix_recommend = 0
    score_wavve_recommend = 0
    score_seezn_recommend = 0
    score_tiving_recommend = 0
    result_recommend=[] 
    
    if combobox8.get() == "Y":
        score_watcha_recommend += 5
        result_recommend.append(score_watcha_recommend)
        score_netflix_recommend += 1
        result_recommend.append(score_netflix_recommend)
        score_wavve_recommend += 3
        result_recommend.append(score_wavve_recommend)
        score_seezn_recommend += 0
        result_recommend.append(score_seezn_recommend)
        score_tiving_recommend += 0
        result_recommend.append(score_tiving_recommend)
        
    elif combobox8.get() == "N":
        score_watcha_recommend += 0
        result_recommend.append(score_watcha_recommend)
        score_netflix_recommend += 0
        result_recommend.append(score_netflix_recommend)
        score_wavve_recommend += 0
        result_recommend.append(score_wavve_recommend)
        score_seezn_recommend += 0
        result_recommend.append(score_seezn_recommend)
        score_tiving_recommend += 0
        result_recommend.append(score_tiving_recommend)
        
# 질문 9 -- 국내컨텐츠의 한국어 자막 지원을 원하십니까?
    score_watcha_kor = 0
    score_netflix_kor= 0
    score_wavve_kor= 0
    score_seezn_kor = 0
    score_tiving_kor = 0
    result_kor=[] 
    
    if combobox9.get() == "Y":
        score_watcha_kor += 0
        result_kor.append(score_watcha_kor)
        score_netflix_kor += 3
        result_kor.append(score_netflix_kor)
        score_wavve_kor += 0
        result_kor.append(score_wavve_kor)
        score_seezn_kor += 0
        result_kor.append(score_seezn_kor)
        score_tiving_kor += 0
        result_kor.append(score_tiving_kor)
        
    elif combobox9.get() == "N":
        score_watcha_kor += 0
        result_kor.append(score_watcha_kor)
        score_netflix_kor += 0
        result_kor.append(score_netflix_kor)
        score_wavve_kor += 0
        result_kor.append(score_wavve_kor)
        score_seezn_kor += 0
        result_kor.append(score_seezn_kor)
        score_tiving_kor += 0
        result_kor.append(score_tiving_kor)
        
# 질문 10 -- 영어공부를 위한 영어 자막 지원을 원하십니까?
    score_watcha_flg = 0
    score_netflix_flg= 0
    score_wavve_flg = 0
    score_seezn_flg = 0
    score_tiving_flg = 0
    result_flg=[] 
    
    if combobox10.get() == "Y":
        score_watcha_flg += 2
        result_flg.append(score_watcha_flg)
        score_netflix_flg += 5
        result_flg.append(score_netflix_flg)
        score_wavve_flg += 0
        result_flg.append(score_wavve_flg)
        score_seezn_flg += 0
        result_flg.append(score_seezn_flg)
        score_tiving_flg += 0
        result_flg.append(score_tiving_flg)
        
    elif combobox10.get() == "N":
        score_watcha_flg += 0
        result_flg.append(score_watcha_flg)
        score_netflix_flg += 0
        result_flg.append(score_netflix_flg)
        score_wavve_flg += 0
        result_flg.append(score_wavve_flg)
        score_seezn_flg += 0
        result_flg.append(score_seezn_flg)
        score_tiving_flg += 0
        result_flg.append(score_tiving_flg)
        
# 질문 11 -- 아이와 함께 OTT 플랫폼을 이용하십니까? -- 추가
    score_watcha_kids = 0
    score_netflix_kids= 0
    score_wavve_kids = 0
    score_seezn_kids= 0
    score_tiving_kids = 0
    result_kids=[] 
    
    if combobox11.get() == "Y":
        score_watcha_kids += 1
        result_kids.append(score_watcha_kids)
        score_netflix_kids += 5
        result_kids.append(score_netflix_kids)
        score_wavve_kids += 0
        result_kids.append(score_wavve_kids)
        score_seezn_kids += 0
        result_kids.append(score_seezn_kids)
        score_tiving_kids += 3
        result_kids.append(score_tiving_kids)
        
    elif combobox11.get() == "N":
        score_watcha_kids += 0
        result_kids.append(score_watcha_kids)
        score_netflix_kids += 0
        result_kids.append(score_netflix_kids)
        score_wavve_kids += 0
        result_kids.append(score_wavve_kids)
        score_seezn_kids += 0
        result_kids.append(score_seezn_kids)
        score_tiving_kids += 0
        result_kids.append(score_tiving_kids)
             
# 콤보 12 성별을 골라주세요
# 콤보 13 연령대를 골라주세요(만 나이)
    score_watcha_age = 0
    score_netflix_age= 0
    score_wavve_age = 0
    score_seezn_age= 0
    score_tiving_age = 0
    result_age=[] 
    
    if combobox12.get()=="여성":
        if combobox13.get()=="0-11":
            score_watcha_age += 0
            result_age.append(score_watcha_age)
            score_netflix_age += 0
            result_age.append(score_netflix_age)
            score_wavve_age += 5
            result_age.append(score_wavve_age)
            score_seezn_age += 2
            result_age.append(score_seezn_age)
            score_tiving_age += 0
            result_age.append(score_tiving_age)
        elif combobox13.get()=="12-18":
            score_watcha_age += 2
            result_age.append(score_watcha_age)
            score_netflix_age += 5
            result_age.append(score_netflix_age)
            score_wavve_age += 0
            result_age.append(score_wavve_age)
            score_seezn_age += 0
            result_age.append(score_seezn_age)
            score_tiving_age += 3
            result_age.append(score_tiving_age)
        elif combobox13.get()=="19-29":
            score_watcha_age += 0
            result_age.append(score_watcha_age)
            score_netflix_age += 5
            result_age.append(score_netflix_age)
            score_wavve_age += 2
            result_age.append(score_wavve_age)
            score_seezn_age += 0
            result_age.append(score_seezn_age)
            score_tiving_age += 3
            result_age.append(score_tiving_age)
        elif combobox13.get()=='30-39':
            score_watcha_age += 2
            result_age.append(score_watcha_age)
            score_netflix_age += 5
            result_age.append(score_netflix_age)
            score_wavve_age += 0
            result_age.append(score_wavve_age)
            score_seezn_age += 0
            result_age.append(score_seezn_age)
            score_tiving_age += 3
            result_age.append(score_tiving_age)
        elif combobox13.get()=='40-49':
            score_watcha_age += 0
            result_age.append(score_watcha_age)
            score_netflix_age += 5
            result_age.append(score_netflix_age)
            score_wavve_age += 0
            result_age.append(score_wavve_age)
            score_seezn_age += 0
            result_age.append(score_seezn_age)
            score_tiving_age += 3
            result_age.append(score_tiving_age)
        elif combobox13.get()=='50-59':
            score_watcha_age += 1
            result_age.append(score_watcha_age)
            score_netflix_age += 5
            result_age.append(score_netflix_age)
            score_wavve_age += 0
            result_age.append(score_wavve_age)
            score_seezn_age += 0
            result_age.append(score_seezn_age)
            score_tiving_age += 3
            result_age.append(score_tiving_age)
        elif combobox13.get()=='60-':
            score_watcha_age += 0
            result_age.append(score_watcha_age)
            score_netflix_age += 5
            result_age.append(score_netflix_age)
            score_wavve_age += 0
            result_age.append(score_wavve_age)
            score_seezn_age += 0
            result_age.append(score_seezn_age)
            score_tiving_age += 2
            result_age.append(score_tiving_age)
        
    
    elif combobox12.get()=="남성":
        if combobox13.get()=="0-11":
            score_watcha_age += 3
            result_age.append(score_watcha_age)
            score_netflix_age += 5
            result_age.append(score_netflix_age)
            score_wavve_age += 0
            result_age.append(score_wavve_age)
            score_seezn_age += 0
            result_age.append(score_seezn_age)
            score_tiving_age += 0
            result_age.append(score_tiving_age)
        elif combobox13.get()=="12-18":
            score_watcha_age += 4.5
            result_age.append(score_watcha_age)
            score_netflix_age += 0
            result_age.append(score_netflix_age)
            score_wavve_age += 0
            result_age.append(score_wavve_age)
            score_seezn_age += 0
            result_age.append(score_seezn_age)
            score_tiving_age += 1
            result_age.append(score_tiving_age)
        elif combobox13.get()=="19-29":
            score_watcha_age += 3
            result_age.append(score_watcha_age)
            score_netflix_age += 5
            result_age.append(score_netflix_age)
            score_wavve_age += 0
            result_age.append(score_wavve_age)
            score_seezn_age += 0
            result_age.append(score_seezn_age)
            score_tiving_age += 1
            result_age.append(score_tiving_age)
        elif combobox13.get()=='30-39':
            score_watcha_age += 2
            result_age.append(score_watcha_age)
            score_netflix_age += 5
            result_age.append(score_netflix_age)
            score_wavve_age += 0
            result_age.append(score_wavve_age)
            score_seezn_age += 0
            result_age.append(score_seezn_age)
            score_tiving_age += 3
            result_age.append(score_tiving_age)
        elif combobox13.get()=='40-49':
            score_watcha_age += 2
            result_age.append(score_watcha_age)
            score_netflix_age += 5
            result_age.append(score_netflix_age)
            score_wavve_age += 2
            result_age.append(score_wavve_age)
            score_seezn_age += 0
            result_age.append(score_seezn_age)
            score_tiving_age += 2
            result_age.append(score_tiving_age)
        elif combobox13.get()=='50-59':
            score_watcha_age += 0
            result_age.append(score_watcha_age)
            score_netflix_age += 5
            result_age.append(score_netflix_age)
            score_wavve_age += 2
            result_age.append(score_wavve_age)
            score_seezn_age += 0
            result_age.append(score_seezn_age)
            score_tiving_age += 3
            result_age.append(score_tiving_age)
        elif combobox13.get()=='60-':
            score_watcha_age += 0
            result_age.append(score_watcha_age)
            score_netflix_age += 5
            result_age.append(score_netflix_age)
            score_wavve_age += 2
            result_age.append(score_wavve_age)
            score_seezn_age += 0
            result_age.append(score_seezn_age)
            score_tiving_age += 2
            result_age.append(score_tiving_age)

        
    result={"result_contents":result_contents,
            "result_contents2":result_contents2,
            "result_contents3":result_contents3,
            "result_contents_spec":result_contents_spec,
            "result_tel":result_tel,
           "result_review":result_review,
            "result_recommend":result_recommend,
            "result_kor":result_kor,
            "result_flg":result_flg,
            "result_kids":result_kids,
           "result_age":result_age}
    df=pd.DataFrame(data=result, index=["왓챠","넷플릭스","웨이브(wavve)","시즌(seezn)","티빙"])
    df1=df["result_contents"]+df["result_contents2"]+df["result_contents3"]+df["result_contents_spec"]+df["result_tel"]+df["result_review"]+df["result_recommend"]+df["result_kor"]+df["result_flg"]+df["result_kids"]+df["result_age"]
    plt.bar(df1.index,df1, color=["deeppink","red","blue","crimson","blueviolet"])
    plt.show()

btn = Button(root, text="완료!",command=score_contents)
btn.grid(row=13, column=1, sticky=W+E+N+S)

root.mainloop()

# %%
# 질문 1 -- 1순위
# 질문 2 -- 2순위
# 질문 3 -- 3순위
# 질문 4 -- 다음 예시 중 보고 싶은 컨텐츠가 많은 보기를 골라주세요
# 질문 5 -- 가격에 민감한 정도를 골라주세요(1~5점 사이)
# 질문 6 -- 통신사가 어디입니까? 
# 질문 7 -- 리뷰 열람하기를 좋아하십니까?
# 질문 8 -- 개인 맞춤형 추천/분석서비스를 원하십니까?
# 질문 9 -- 국내컨텐츠의 한국어 자막 지원을 원하십니까?
# 질문 10 -- 영어공부를 위한 영어 자막 지원을 원하십니까?
# 질문 11 -- 아이와 함께 OTT 플랫폼을 이용하십니까? -- 추가
# 질문 12 -- 당신의 MBTI는 무엇입니까?

# %% [markdown]
# # MBTI 넣은 버전

# %%
# GUI 구현
from tkinter import *
from tkinter import ttk 
from tkinter import Tk
from tkinter import messagebox
from PIL import ImageTk, Image
import matplotlib.pyplot as plt
import pandas as pd
from pandas import DataFrame, Series


import matplotlib
import matplotlib.font_manager as fm
fm.get_fontconfig_fonts()
# font_location = '/usr/share/fonts/truetype/nanum/NanumGothicOTF.ttf'
font_location = 'C:/Windows/Fonts/malgun.ttf' # For Windows
font_name = fm.FontProperties(fname=font_location).get_name()
matplotlib.rc('font', family=font_name)
plt.rcParams["figure.figsize"]=(12,6)
plt.rcParams['font.size']=20

# TK 객체 인스턴스 생성하기
root=Tk()
root.title("나에게 맞는 OTT 서비스는?")
root.geometry("700x350")
root.configure(background='#EBD0F5')
root.resizable(True,True)


#콤보 1- 1순위
items_contents=["아이돌","지상파","독립영화","스포츠 중계","종편 및 CJ ENM"]

label1=Label(root, text="선호하는 장르 1순위는?(중복 선택 가능)", foreground="black", background='#EBD0F5')
label1.grid(row=0, column=0)

combobox1=ttk.Combobox(root, width=50, height=10, values=items_contents)
combobox1.set("선택")
combobox1.grid(row=0, column=1)

#콤보 2 -2순위
items_contents=["아이돌","지상파","독립영화","스포츠 중계","종편 및 CJ ENM"]

label2=Label(root, text="선호하는 장르 2순위는?(중복 선택 가능)",foreground="black",background='#EBD0F5')
label2.grid(row=1, column=0)

combobox2=ttk.Combobox(root, width=50, height=10, values=items_contents)
combobox2.set("선택")
combobox2.grid(row=1, column=1)

#콤보 3 -3순위
items_contents=["아이돌","지상파","독립영화","스포츠 중계","종편 및 CJ ENM"]

label3=Label(root, text="선호하는 장르 3순위는?(중복 선택 가능)",foreground="black",background='#EBD0F5')
label3.grid(row=2, column=0)

combobox3=ttk.Combobox(root, width=50, height=10, values=items_contents)
combobox3.set("선택")
combobox3.grid(row=2, column=1)

###########
# 콤보 4 다음 예시 중 보고 싶은 컨텐츠가 많은 보기를 골라주세요

items_contents_spec=["보건교사 안은영, 킹덤, 인간수업, 기묘한 이야기, 옥자",
                     "킬링 이브, 와이우먼킬, 이어즈&이어즈. 왕좌의 게임, 체르노빌",
                     "원앤투, 괜찮아요 프리랜서, 킹 리어, 신의 나라, 더 저니",
                     "녹두전, SF8, 앨리스, 좀비탐정, 나의 위험한 아내",
                     "놓지마 정신줄, 썸툰2020, 인어왕자, 김요한 이야기, 우웅우웅2",
                    "없음"]

label4=Label(root, text="다음 예시 중 보고 싶은 컨텐츠가 많은 보기를 골라주세요",foreground="black",background='#EBD0F5')
label4.grid(row=3, column=0)

combobox4=ttk.Combobox(root, width=50, height=10, values=items_contents_spec)
combobox4.set("선택")
combobox4.grid(row=3, column=1)

###########

# 콤보 5 가격 탄력성 조사
items_price=["1","2","3","4","5"]

label5=Label(root, text="가격에 민감한 정도를 골라주세요(1~5점 사이)",foreground="black",background='#EBD0F5')
label5.grid(row=4, column=0)

combobox5=ttk.Combobox(root, width=50, height=10, values=items_price)
combobox5.set("선택")
combobox5.grid(row=4, column=1)

#콤보 6 -통신사
items_tel=["SKT","KT","LGU+"]

label6=Label(root, text="통신사가 어디입니까?",foreground="black",background='#EBD0F5')
label6.grid(row=5, column=0)

combobox6=ttk.Combobox(root, width=50, height=10, values=items_tel)
combobox6.set("선택")
combobox6.grid(row=5, column=1)

# 콤보 7 - 리뷰 열람
items_review=["Y","N"]

label7=Label(root, text="리뷰 열람하기를 좋아하십니까?",foreground="black",background='#EBD0F5')
label7.grid(row=6, column=0)

combobox7=ttk.Combobox(root, width=50, height=10, values=items_review)
combobox7.set("선택")
combobox7.grid(row=6, column=1)

# 콤보 8 - 추천서비스
items_recommend=["Y","N"]

label8=Label(root, text="개인 맞춤형 추천/분석서비스를 원하십니까?",foreground="black",background='#EBD0F5')
label8.grid(row=7, column=0)

combobox8=ttk.Combobox(root, width=50, height=10, values=items_recommend)
combobox8.set("선택")
combobox8.grid(row=7, column=1)

# 콤보 9 - 한국어자막
items_Korean=["Y","N"]

label9=Label(root, text="한국어 자막을 원하십니까?",foreground="black",background='#EBD0F5')
label9.grid(row=8, column=0)

combobox9=ttk.Combobox(root, width=50, height=10, values=items_Korean)
combobox9.set("선택")
combobox9.grid(row=8, column=1)

# 콤보 10 - 영어자막
items_flg=["Y","N"]

label10=Label(root, text="영어 자막을 원하십니까?",foreground="black",background='#EBD0F5')
label10.grid(row=9, column=0)

combobox10=ttk.Combobox(root, width=50, height=10, values=items_flg)
combobox10.set("선택")
combobox10.grid(row=9, column=1)

###########
# 콤보 11 아이와 함께 OTT 플랫폼을 이용하십니까?

items_kids=["Y","N"]

label11=Label(root, text="아이와 함께 OTT 플랫폼을 이용하십니까?",foreground="black",background='#EBD0F5')
label11.grid(row=10, column=0)

combobox11=ttk.Combobox(root, width=50, height=10, values=items_kids)
combobox11.set("선택")
combobox11.grid(row=10, column=1)

# 콤보 12 성별을 골라주세요
items_sex=["여성","남성"]

label12=Label(root, text="성별을 골라주세요",foreground="black",background='#EBD0F5')
label12.grid(row=11, column=0)

combobox12=ttk.Combobox(root, width=50, height=10, values=items_sex)
combobox12.set("선택")
combobox12.grid(row=11, column=1)

# 콤보 13 연령대를 골라주세요(만 나이)
items_age=["0-11","12-18","19-29",'30-39','40-49','50-59','60-']

label13=Label(root, text="연령대를 골라주세요(만 나이)",foreground="black",background='#EBD0F5')
label13.grid(row=12, column=0)

combobox13=ttk.Combobox(root, width=50, height=10, values=items_age)
combobox13.set("선택")
combobox13.grid(row=12, column=1)

###########

# # 화면배치
# # 콤보 last - mbti

items_mbti=["INFJ, INFP, ENFP, ENFJ",
"ISTP, ISFP, ESTP, ESFP",
"ISTJ, ISFJ, ESTJ, ESFJ",
"INTJ, INTP, ENTP, ENTJ",
           "모름"]

label14=Label(root, text="다음 중 당신의 mbti를 골라주세요",foreground="black",background='#EBD0F5')
label14.grid(row=13, column=0)

combobox14=ttk.Combobox(root, width=50, height=10, values=items_mbti)
combobox14.set("선택")
combobox14.grid(row=13, column=1)


def score_contents():   #점수 가져오게 하는 함수
    score_watcha_contents = 0
    score_netflix_contents = 0
    score_wavve_contents = 0
    score_seezn_contents = 0
    score_tiving_contents = 0
    result_contents=[]
    
## 질문 1 -- 1순위

    if combobox1.get() == "아이돌":
        score_watcha_contents += 0
        result_contents.append(score_watcha_contents)
        score_netflix_contents += 0
        result_contents.append(score_netflix_contents)
        score_wavve_contents = 3.5
        result_contents.append(score_wavve_contents)
        score_seezn_contents += 5
        result_contents.append(score_seezn_contents)
        score_tiving_contents += 2
        result_contents.append(score_tiving_contents)

    elif combobox1.get() == "지상파":
        score_watcha_contents += 0
        result_contents.append(score_watcha_contents)
        score_netflix_contents += 0
        result_contents.append(score_netflix_contents)
        score_wavve_contents += 5
        result_contents.append(score_wavve_contents)
        score_seezn_contents += 0
        result_contents.append(score_seezn_contents)
        score_tiving_contents += 0
        result_contents.append(score_tiving_contents)

    elif combobox1.get() == "독립영화":
        score_watcha_contents += 4
        result_contents.append(score_watcha_contents)
        score_netflix_contents += 0
        result_contents.append(score_netflix_contents)
        score_wavve_contents += 5
        result_contents.append(score_wavve_contents)
        score_seezn_contents += 3
        result_contents.append(score_seezn_contents)
        score_tiving_contents += 0
        result_contents.append(score_tiving_contents)

    elif combobox1.get() == "스포츠 중계":
        score_watcha_contents += 0
        result_contents.append(score_watcha_contents)
        score_netflix_contents += 0
        result_contents.append(score_netflix_contents)
        score_wavve_contents += 4
        result_contents.append(score_wavve_contents)
        score_seezn_contents += 3
        result_contents.append(score_seezn_contents)
        score_tiving_contents += 0
        result_contents.append(score_tiving_contents)

    elif combobox1.get() == "종편 및 CJ ENM":
        score_watcha_contents += 0
        result_contents.append(score_watcha_contents)
        score_netflix_contents += 0
        result_contents.append(score_netflix_contents)
        score_wavve_contents += 0
        result_contents.append(score_wavve_contents)
        score_seezn_contents += 0
        result_contents.append(score_seezn_contents)
        score_tiving_contents += 5
        result_contents.append(score_tiving_contents)

# 질문 2 -- 2순위
    score_watcha_contents2 = 0
    score_netflix_contents2 = 0
    score_wavve_contents2 = 0
    score_seezn_contents2 = 0
    score_tiving_contents2 = 0
    result_contents2=[]
    
    if combobox2.get() == "아이돌":
        score_watcha_contents2 += 0
        result_contents2.append(score_watcha_contents2)
        score_netflix_contents2 += 0
        result_contents2.append(score_netflix_contents2)
        score_wavve_contents2 += 2.5
        result_contents2.append(score_wavve_contents2)
        score_seezn_contents2 += 4
        result_contents2.append(score_seezn_contents2)
        score_tiving_contents2 += 1
        result_contents2.append(score_tiving_contents2)

    elif combobox2.get() == "지상파":
        score_watcha_contents2 += 0
        result_contents2.append(score_watcha_contents2)
        score_netflix_contents2 += 0
        result_contents2.append(score_netflix_contents2)
        score_wavve_contents2 += 4
        result_contents2.append(score_wavve_contents2)
        score_seezn_contents2 += 0
        result_contents2.append(score_seezn_contents2)
        score_tiving_contents2 += 0
        result_contents2.append(score_tiving_contents2)

    elif combobox2.get() == "독립영화":
        score_watcha_contents2 += 3
        result_contents2.append(score_watcha_contents2)
        score_netflix_contents2 += 0
        result_contents2.append(score_netflix_contents2)
        score_wavve_contents2 += 4
        result_contents2.append(score_wavve_contents2)
        score_seezn_contents2 += 2
        result_contents2.append(score_seezn_contents2)
        score_tiving_contents2 += 0
        result_contents2.append(score_tiving_contents2)

    elif combobox2.get() == "스포츠 중계":
        score_watcha_contents2 += 0
        result_contents2.append(score_watcha_contents2)
        score_netflix_contents2 += 0
        result_contents2.append(score_netflix_contents2)
        score_wavve_contents2 += 3
        result_contents2.append(score_wavve_contents2)
        score_seezn_contents2 += 2
        result_contents2.append(score_seezn_contents2)
        score_tiving_contents2 += 0
        result_contents2.append(score_tiving_contents2)

    elif combobox2.get() == "종편 및 CJ ENM":
        score_watcha_contents2 += 0
        result_contents2.append(score_watcha_contents2)
        score_netflix_contents2 += 0
        result_contents2.append(score_netflix_contents2)
        score_wavve_contents2 += 0
        result_contents2.append(score_wavve_contents2)
        score_seezn_contents2 += 0
        result_contents2.append(score_seezn_contents2)
        score_tiving_contents2 += 4
        result_contents2.append(score_tiving_contents2)
# 질문 3 -- 3순위
    score_watcha_contents3 = 0
    score_netflix_contents3 = 0
    score_wavve_contents3 = 0
    score_seezn_contents3 = 0
    score_tiving_contents3 = 0
    result_contents3=[]
    
    if combobox3.get() == "아이돌":
        score_watcha_contents3 += 0
        result_contents3.append(score_watcha_contents3)
        score_netflix_contents3 += 0
        result_contents3.append(score_netflix_contents3)
        score_wavve_contents3 = 1.5
        result_contents3.append(score_wavve_contents3)
        score_seezn_contents3 += 3
        result_contents3.append(score_seezn_contents3)
        score_tiving_contents3 += 0
        result_contents3.append(score_tiving_contents3)

    elif combobox3.get() == "지상파":
        score_watcha_contents3 += 0
        result_contents3.append(score_watcha_contents3)
        score_netflix_contents3 += 0
        result_contents3.append(score_netflix_contents3)
        score_wavve_contents3 += 3
        result_contents3.append(score_wavve_contents3)
        score_seezn_contents3 += 0
        result_contents3.append(score_seezn_contents3)
        score_tiving_contents3 += 0
        result_contents3.append(score_tiving_contents3)

    elif combobox3.get() == "독립영화":
        score_watcha_contents3 += 2
        result_contents3.append(score_watcha_contents3)
        score_netflix_contents3 += 0
        result_contents3.append(score_netflix_contents3)
        score_wavve_contents3 += 3
        result_contents3.append(score_wavve_contents3)
        score_seezn_contents3 += 1
        result_contents3.append(score_seezn_contents3)
        score_tiving_contents3 += 0
        result_contents3.append(score_tiving_contents3)

    elif combobox3.get() == "스포츠 중계":
        score_watcha_contents3 += 0
        result_contents3.append(score_watcha_contents3)
        score_netflix_contents3 += 0
        result_contents3.append(score_netflix_contents3)
        score_wavve_contents3 += 2
        result_contents3.append(score_wavve_contents3)
        score_seezn_contents3 += 1
        result_contents3.append(score_seezn_contents3)
        score_tiving_contents3 += 0
        result_contents3.append(score_tiving_contents3)

    elif combobox3.get() == "종편 및 CJ ENM":
        score_watcha_contents3 += 0
        result_contents3.append(score_watcha_contents3)
        score_netflix_contents3 += 0
        result_contents3.append(score_netflix_contents3)
        score_wavve_contents3 += 0
        result_contents3.append(score_wavve_contents3)
        score_seezn_contents3 += 0
        result_contents3.append(score_seezn_contents3)
        score_tiving_contents3 += 3
        result_contents3.append(score_tiving_contents3)
        
# 질문 4 -- 다음 예시 중 보고 싶은 컨텐츠가 많은 보기를 골라주세요
    score_watcha_contents_spec = 0
    score_netflix_contents_spec = 0
    score_wavve_contents_spec = 0
    score_seezn_contents_spec = 0
    score_tiving_contents_spec = 0
    result_contents_spec=[]

    if combobox4.get() == "보건교사 안은영, 킹덤, 인간수업, 기묘한 이야기, 옥자":
        score_watcha_contents_spec += 3
        result_contents_spec.append(score_watcha_contents_spec)
        score_netflix_contents_spec += 0
        result_contents_spec.append(score_netflix_contents_spec)
        score_wavve_contents_spec += 1.5
        result_contents_spec.append(score_wavve_contents_spec)
        score_seezn_contents_spec += 0
        result_contents_spec.append(score_seezn_contents_spec)
        score_tiving_contents_spec += 0
        result_contents_spec.append(score_tiving_contents_spec)

    elif combobox4.get() == "킬링 이브, 와이우먼킬, 이어즈&이어즈. 왕좌의 게임, 체르노빌":
        score_watcha_contents_spec += 3
        result_contents_spec.append(score_watcha_contents_spec)
        score_netflix_contents_spec += 0
        result_contents_spec.append(score_netflix_contents_spec)
        score_wavve_contents_spec += 0
        result_contents_spec.append(score_wavve_contents_spec)
        score_seezn_contents_spec += 0
        result_contents_spec.append(score_seezn_contents_spec)
        score_tiving_contents_spec += 0
        result_contents_spec.append(score_tiving_contents_spec)

    elif combobox4.get() == "원앤투, 괜찮아요 프리랜서, 킹 리어, 신의 나라, 더 저니":
        score_watcha_contents_spec += 0
        result_contents_spec.append(score_watcha_contents_spec)
        score_netflix_contents_spec += 0
        result_contents_spec.append(score_netflix_contents_spec)
        score_wavve_contents_spec += 0
        result_contents_spec.append(score_wavve_contents_spec)
        score_seezn_contents_spec += 0
        result_contents_spec.append(score_seezn_contents_spec)
        score_tiving_contents_spec += 3
        result_contents_spec.append(score_tiving_contents_spec)

    elif combobox4.get() == "녹두전, SF8, 앨리스, 좀비탐정, 나의 위험한 아내":
        score_watcha_contents_spec += 0
        result_contents_spec.append(score_watcha_contents_spec)
        score_netflix_contents_spec += 0
        result_contents_spec.append(score_netflix_contents_spec)
        score_wavve_contents_spec += 3
        result_contents_spec.append(score_wavve_contents_spec)
        score_seezn_contents_spec += 0
        result_contents_spec.append(score_seezn_contents_spec)
        score_tiving_contents_spec += 0
        result_contents_spec.append(score_tiving_contents_spec)

    elif combobox4.get() == "놓지마 정신줄, 썸툰2020, 인어왕자, 김요한 이야기, 우웅우웅2":
        score_watcha_contents_spec += 0
        result_contents_spec.append(score_watcha_contents_spec)
        score_netflix_contents_spec += 0
        result_contents_spec.append(score_netflix_contents_spec)
        score_wavve_contents_spec += 0
        result_contents_spec.append(score_wavve_contents_spec)
        score_seezn_contents_spec += 3
        result_contents_spec.append(score_seezn_contents_spec)
        score_tiving_contents_spec += 0
        result_contents_spec.append(score_tiving_contents_spec)
        
    elif combobox4.get() == "없음":
        score_watcha_contents_spec += 0
        result_contents_spec.append(score_watcha_contents_spec)
        score_netflix_contents_spec += 0
        result_contents_spec.append(score_netflix_contents_spec)
        score_wavve_contents_spec += 0
        result_contents_spec.append(score_wavve_contents_spec)
        score_seezn_contents_spec += 0
        result_contents_spec.append(score_seezn_contents_spec)
        score_tiving_contents_spec += 0
        result_contents_spec.append(score_tiving_contents_spec)
        
# 질문 5 -- 가격에 민감한 정도를 골라주세요(1~5점 사이)  -- 6번과 연결
    score_price=0
    result_score_price=[]
    if combobox5.get() == "1":
        score_price+=0
        result_score_price.append(score_price)
    elif combobox5.get() == "2":
        score_price+=1
        result_score_price.append(score_price)  
    elif combobox5.get() == "3":
        score_price+=2
        result_score_price.append(score_price)  
    elif combobox5.get() == "4":
        score_price+=3
        result_score_price.append(score_price)  
    elif combobox5.get() == "5":
        score_price+=4
        result_score_price.append(score_price)
        
# 질문 6 -- 통신사가 어디입니까? cont'd 5
    score_watcha_tel = 0
    score_netflix_tel = 0
    score_wavve_tel = 0
    score_seezn_tel = 0
    score_tiving_tel = 0
    result_tel=[] 
    
    if combobox6.get() == "SKT":
        score_watcha_tel += 0
        result_tel.append(score_watcha_tel)
        score_netflix_tel += 0
        result_tel.append(score_netflix_tel)
        score_wavve_tel = result_score_price[0]
        result_tel.append(score_wavve_tel)
        score_seezn_tel += 0
        result_tel.append(score_seezn_tel)
        score_tiving_tel += 0
        result_tel.append(score_tiving_tel)
    elif combobox6.get() == "KT":
        score_watcha_tel += 0
        result_tel.append(score_watcha_tel)
        score_netflix_tel += 0
        result_tel.append(score_netflix_tel)
        score_wavve_tel += 0
        result_tel.append(score_wavve_tel)
        score_seezn_tel += result_score_price[0]
        result_tel.append(score_seezn_tel)
        score_tiving_tel += 0
        result_tel.append(score_tiving_tel)
    elif combobox6.get() == "LGU+":
        score_watcha_tel += 0
        result_tel.append(score_watcha_tel)
        score_netflix_tel += 0
        result_tel.append(score_netflix_tel)
        score_wavve_tel += 0
        result_tel.append(score_wavve_tel)
        score_seezn_tel += 0
        result_tel.append(score_seezn_tel)
        score_tiving_tel += 0
        result_tel.append(score_tiving_tel) 
    
# 질문 7 -- 리뷰 열람하기를 좋아하십니까?
    score_watcha_review = 0
    score_netflix_review = 0
    score_wavve_review = 0
    score_seezn_review = 0
    score_tiving_review = 0
    result_review=[] 
    
    if combobox7.get() == "Y":
        score_watcha_review += 4
        result_review.append(score_watcha_review)
        score_netflix_review += 0
        result_review.append(score_netflix_review)
        score_wavve_review += 0
        result_review.append(score_wavve_review)
        score_seezn_review += 0
        result_review.append(score_seezn_review)
        score_tiving_review += 0
        result_review.append(score_tiving_review)
        
    elif combobox7.get() == "N":
        score_watcha_review += 0
        result_review.append(score_watcha_review)
        score_netflix_review += 0
        result_review.append(score_netflix_review)
        score_wavve_review += 0
        result_review.append(score_wavve_review)
        score_seezn_review += 0
        result_review.append(score_seezn_review)
        score_tiving_review += 0
        result_review.append(score_tiving_review)

# 질문 8 -- 개인 맞춤형 추천/분석서비스를 원하십니까?
    score_watcha_recommend = 0
    score_netflix_recommend = 0
    score_wavve_recommend = 0
    score_seezn_recommend = 0
    score_tiving_recommend = 0
    result_recommend=[] 
    
    if combobox8.get() == "Y":
        score_watcha_recommend += 5
        result_recommend.append(score_watcha_recommend)
        score_netflix_recommend += 1
        result_recommend.append(score_netflix_recommend)
        score_wavve_recommend += 3
        result_recommend.append(score_wavve_recommend)
        score_seezn_recommend += 0
        result_recommend.append(score_seezn_recommend)
        score_tiving_recommend += 0
        result_recommend.append(score_tiving_recommend)
        
    elif combobox8.get() == "N":
        score_watcha_recommend += 0
        result_recommend.append(score_watcha_recommend)
        score_netflix_recommend += 0
        result_recommend.append(score_netflix_recommend)
        score_wavve_recommend += 0
        result_recommend.append(score_wavve_recommend)
        score_seezn_recommend += 0
        result_recommend.append(score_seezn_recommend)
        score_tiving_recommend += 0
        result_recommend.append(score_tiving_recommend)
        
# 질문 9 -- 국내컨텐츠의 한국어 자막 지원을 원하십니까?
    score_watcha_kor = 0
    score_netflix_kor= 0
    score_wavve_kor= 0
    score_seezn_kor = 0
    score_tiving_kor = 0
    result_kor=[] 
    
    if combobox9.get() == "Y":
        score_watcha_kor += 0
        result_kor.append(score_watcha_kor)
        score_netflix_kor += 3
        result_kor.append(score_netflix_kor)
        score_wavve_kor += 0
        result_kor.append(score_wavve_kor)
        score_seezn_kor += 0
        result_kor.append(score_seezn_kor)
        score_tiving_kor += 0
        result_kor.append(score_tiving_kor)
        
    elif combobox9.get() == "N":
        score_watcha_kor += 0
        result_kor.append(score_watcha_kor)
        score_netflix_kor += 0
        result_kor.append(score_netflix_kor)
        score_wavve_kor += 0
        result_kor.append(score_wavve_kor)
        score_seezn_kor += 0
        result_kor.append(score_seezn_kor)
        score_tiving_kor += 0
        result_kor.append(score_tiving_kor)
        
# 질문 10 -- 영어공부를 위한 영어 자막 지원을 원하십니까?
    score_watcha_flg = 0
    score_netflix_flg= 0
    score_wavve_flg = 0
    score_seezn_flg = 0
    score_tiving_flg = 0
    result_flg=[] 
    
    if combobox10.get() == "Y":
        score_watcha_flg += 2
        result_flg.append(score_watcha_flg)
        score_netflix_flg += 5
        result_flg.append(score_netflix_flg)
        score_wavve_flg += 0
        result_flg.append(score_wavve_flg)
        score_seezn_flg += 0
        result_flg.append(score_seezn_flg)
        score_tiving_flg += 0
        result_flg.append(score_tiving_flg)
        
    elif combobox10.get() == "N":
        score_watcha_flg += 0
        result_flg.append(score_watcha_flg)
        score_netflix_flg += 0
        result_flg.append(score_netflix_flg)
        score_wavve_flg += 0
        result_flg.append(score_wavve_flg)
        score_seezn_flg += 0
        result_flg.append(score_seezn_flg)
        score_tiving_flg += 0
        result_flg.append(score_tiving_flg)
        
# 질문 11 -- 아이와 함께 OTT 플랫폼을 이용하십니까? -- 추가
    score_watcha_kids = 0
    score_netflix_kids= 0
    score_wavve_kids = 0
    score_seezn_kids= 0
    score_tiving_kids = 0
    result_kids=[] 
    
    if combobox11.get() == "Y":
        score_watcha_kids += 1
        result_kids.append(score_watcha_kids)
        score_netflix_kids += 5
        result_kids.append(score_netflix_kids)
        score_wavve_kids += 0
        result_kids.append(score_wavve_kids)
        score_seezn_kids += 0
        result_kids.append(score_seezn_kids)
        score_tiving_kids += 3
        result_kids.append(score_tiving_kids)
        
    elif combobox11.get() == "N":
        score_watcha_kids += 0
        result_kids.append(score_watcha_kids)
        score_netflix_kids += 0
        result_kids.append(score_netflix_kids)
        score_wavve_kids += 0
        result_kids.append(score_wavve_kids)
        score_seezn_kids += 0
        result_kids.append(score_seezn_kids)
        score_tiving_kids += 0
        result_kids.append(score_tiving_kids)
             
# 콤보 12 성별을 골라주세요
# 콤보 13 연령대를 골라주세요(만 나이)
    score_watcha_age = 0
    score_netflix_age= 0
    score_wavve_age = 0
    score_seezn_age= 0
    score_tiving_age = 0
    result_age=[] 
    
    if combobox12.get()=="여성":
        if combobox13.get()=="0-11":
            score_watcha_age += 0
            result_age.append(score_watcha_age)
            score_netflix_age += 0
            result_age.append(score_netflix_age)
            score_wavve_age += 5
            result_age.append(score_wavve_age)
            score_seezn_age += 2
            result_age.append(score_seezn_age)
            score_tiving_age += 0
            result_age.append(score_tiving_age)
        elif combobox13.get()=="12-18":
            score_watcha_age += 2
            result_age.append(score_watcha_age)
            score_netflix_age += 5
            result_age.append(score_netflix_age)
            score_wavve_age += 0
            result_age.append(score_wavve_age)
            score_seezn_age += 0
            result_age.append(score_seezn_age)
            score_tiving_age += 3
            result_age.append(score_tiving_age)
        elif combobox13.get()=="19-29":
            score_watcha_age += 0
            result_age.append(score_watcha_age)
            score_netflix_age += 5
            result_age.append(score_netflix_age)
            score_wavve_age += 2
            result_age.append(score_wavve_age)
            score_seezn_age += 0
            result_age.append(score_seezn_age)
            score_tiving_age += 3
            result_age.append(score_tiving_age)
        elif combobox13.get()=='30-39':
            score_watcha_age += 2
            result_age.append(score_watcha_age)
            score_netflix_age += 5
            result_age.append(score_netflix_age)
            score_wavve_age += 0
            result_age.append(score_wavve_age)
            score_seezn_age += 0
            result_age.append(score_seezn_age)
            score_tiving_age += 3
            result_age.append(score_tiving_age)
        elif combobox13.get()=='40-49':
            score_watcha_age += 0
            result_age.append(score_watcha_age)
            score_netflix_age += 5
            result_age.append(score_netflix_age)
            score_wavve_age += 0
            result_age.append(score_wavve_age)
            score_seezn_age += 0
            result_age.append(score_seezn_age)
            score_tiving_age += 3
            result_age.append(score_tiving_age)
        elif combobox13.get()=='50-59':
            score_watcha_age += 1
            result_age.append(score_watcha_age)
            score_netflix_age += 5
            result_age.append(score_netflix_age)
            score_wavve_age += 0
            result_age.append(score_wavve_age)
            score_seezn_age += 0
            result_age.append(score_seezn_age)
            score_tiving_age += 3
            result_age.append(score_tiving_age)
        elif combobox13.get()=='60-':
            score_watcha_age += 0
            result_age.append(score_watcha_age)
            score_netflix_age += 5
            result_age.append(score_netflix_age)
            score_wavve_age += 0
            result_age.append(score_wavve_age)
            score_seezn_age += 0
            result_age.append(score_seezn_age)
            score_tiving_age += 2
            result_age.append(score_tiving_age)
        
    
    elif combobox12.get()=="남성":
        if combobox13.get()=="0-11":
            score_watcha_age += 3
            result_age.append(score_watcha_age)
            score_netflix_age += 5
            result_age.append(score_netflix_age)
            score_wavve_age += 0
            result_age.append(score_wavve_age)
            score_seezn_age += 0
            result_age.append(score_seezn_age)
            score_tiving_age += 0
            result_age.append(score_tiving_age)
        elif combobox13.get()=="12-18":
            score_watcha_age += 4.5
            result_age.append(score_watcha_age)
            score_netflix_age += 0
            result_age.append(score_netflix_age)
            score_wavve_age += 0
            result_age.append(score_wavve_age)
            score_seezn_age += 0
            result_age.append(score_seezn_age)
            score_tiving_age += 1
            result_age.append(score_tiving_age)
        elif combobox13.get()=="19-29":
            score_watcha_age += 3
            result_age.append(score_watcha_age)
            score_netflix_age += 5
            result_age.append(score_netflix_age)
            score_wavve_age += 0
            result_age.append(score_wavve_age)
            score_seezn_age += 0
            result_age.append(score_seezn_age)
            score_tiving_age += 1
            result_age.append(score_tiving_age)
        elif combobox13.get()=='30-39':
            score_watcha_age += 2
            result_age.append(score_watcha_age)
            score_netflix_age += 5
            result_age.append(score_netflix_age)
            score_wavve_age += 0
            result_age.append(score_wavve_age)
            score_seezn_age += 0
            result_age.append(score_seezn_age)
            score_tiving_age += 3
            result_age.append(score_tiving_age)
        elif combobox13.get()=='40-49':
            score_watcha_age += 2
            result_age.append(score_watcha_age)
            score_netflix_age += 5
            result_age.append(score_netflix_age)
            score_wavve_age += 2
            result_age.append(score_wavve_age)
            score_seezn_age += 0
            result_age.append(score_seezn_age)
            score_tiving_age += 2
            result_age.append(score_tiving_age)
        elif combobox13.get()=='50-59':
            score_watcha_age += 0
            result_age.append(score_watcha_age)
            score_netflix_age += 5
            result_age.append(score_netflix_age)
            score_wavve_age += 2
            result_age.append(score_wavve_age)
            score_seezn_age += 0
            result_age.append(score_seezn_age)
            score_tiving_age += 3
            result_age.append(score_tiving_age)
        elif combobox13.get()=='60-':
            score_watcha_age += 0
            result_age.append(score_watcha_age)
            score_netflix_age += 5
            result_age.append(score_netflix_age)
            score_wavve_age += 2
            result_age.append(score_wavve_age)
            score_seezn_age += 0
            result_age.append(score_seezn_age)
            score_tiving_age += 2
            result_age.append(score_tiving_age)
        # mbti
    score_watcha_mbti = 0
    score_netflix_mbti= 0
    score_wavve_mbti = 0
    score_seezn_mbti= 0
    score_tiving_mbti = 0
    result_mbti=[] 
    
    if combobox14.get()== "INFJ, INFP, ENFP, ENFJ":
            score_watcha_mbti += 0.5
            result_mbti.append(score_watcha_mbti)
            score_netflix_mbti += 0
            result_mbti.append(score_netflix_mbti)
            score_wavve_mbti += 0
            result_mbti.append(score_wavve_mbti)
            score_seezn_mbti += 0
            result_mbti.append(score_seezn_mbti)
            score_tiving_mbti += 0
            result_mbti.append(score_tiving_mbti)
    elif combobox14.get()== "ISTP, ISFP, ESTP, ESFP":
            score_watcha_mbti += 0.5
            result_mbti.append(score_watcha_mbti)
            score_netflix_mbti += 0
            result_mbti.append(score_netflix_mbti)
            score_wavve_mbti += 0
            result_mbti.append(score_wavve_mbti)
            score_seezn_mbti += 0
            result_mbti.append(score_seezn_mbti)
            score_tiving_mbti += 0
            result_mbti.append(score_tiving_mbti)
    elif combobox14.get()== "ISTJ, ISFJ, ESTJ, ESFJ": 
            score_watcha_mbti += 0.5
            result_mbti.append(score_watcha_mbti)
            score_netflix_mbti += 0.5
            result_mbti.append(score_netflix_mbti)
            score_wavve_mbti += 0.5
            result_mbti.append(score_wavve_mbti)
            score_seezn_mbti += 0
            result_mbti.append(score_seezn_mbti)
            score_tiving_mbti += 0
            result_mbti.append(score_tiving_mbti)
    elif combobox14.get()== "INTJ, INTP, ENTP, ENTJ":
            score_watcha_mbti += 0.5
            result_mbti.append(score_watcha_mbti)
            score_netflix_mbti += 0.5
            result_mbti.append(score_netflix_mbti)
            score_wavve_mbti += 0
            result_mbti.append(score_wavve_mbti)
            score_seezn_mbti += 0
            result_mbti.append(score_seezn_mbti)
            score_tiving_mbti += 0
            result_mbti.append(score_tiving_mbti)
    elif combobox14.get()== "모름":
            score_watcha_mbti += 0
            result_mbti.append(score_watcha_mbti)
            score_netflix_mbti += 0
            result_mbti.append(score_netflix_mbti)
            score_wavve_mbti += 0
            result_mbti.append(score_wavve_mbti)
            score_seezn_mbti += 0
            result_mbti.append(score_seezn_mbti)
            score_tiving_mbti += 0
            result_mbti.append(score_tiving_mbti)
        
    result={"result_contents":result_contents,
            "result_contents2":result_contents2,
            "result_contents3":result_contents3,
            "result_contents_spec":result_contents_spec,
            "result_tel":result_tel,
           "result_review":result_review,
            "result_recommend":result_recommend,
            "result_kor":result_kor,
            "result_flg":result_flg,
            "result_kids":result_kids,
           "result_age":result_age,
           "result_mbti":result_mbti}
    df=pd.DataFrame(data=result, index=["왓챠","넷플릭스","웨이브(wavve)","시즌(seezn)","티빙"])
    df1=df["result_contents"]+df["result_contents2"]+df["result_contents3"]+df["result_contents_spec"]+df["result_tel"]+df["result_review"]+df["result_recommend"]+df["result_kor"]+df["result_flg"]+df["result_kids"]+df["result_age"]+df["result_mbti"]
    plt.bar(df1.index,df1, color=["deeppink","red","blue","crimson","blueviolet"])
    plt.show()

btn = Button(root, text="완료!",command=score_contents)
btn.grid(row=14, column=1, sticky=W+E+N+S)

root.mainloop()
